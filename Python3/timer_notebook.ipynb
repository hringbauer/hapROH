# %% [markdown]
# # Do interactively time code

# %%
from hmm_inference import HMM_Analyze

# %%
### Without Cython Speed UP
hmm = HMM_Analyze(folder="../Simulated/Test2r/", output=False, cython=False)
# %timeit hmm.calc_posterior(save=False)


### With Cython Speed UP
hmm = HMM_Analyze(folder="../Simulated/Test2r/", output=False, cython=1)
# %timeit hmm.calc_posterior(save=False)

### With Cython linear Speed UP
hmm = HMM_Analyze(folder="../Simulated/Test2r/", output=False, cython=2)
# %timeit  hmm.calc_posterior(save=False)
# Out:
# No Genetic Map found. Defaulting...
# Minimum Genetic Map: 0
# Maximum Genetic Map: 999
# Successfully loaded Data from: ../Simulated/Test2r/
# Loaded Transition Model: model
# Loaded Emission Model: haploid
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# Total Log likelihood fwd: -258.596
# 1.18 s ± 12.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# No Genetic Map found. Defaulting...
# Minimum Genetic Map: 0
# Maximum Genetic Map: 999
# Successfully loaded Data from: ../Simulated/Test2r/
# Loaded Transition Model: model
# Loaded Emission Model: haploid
# Total Log likelihood: -258.596
# Total Log likelihood: -258.596
# Total Log likelihood: -258.596
# Total Log likelihood: -258.596
# Total Log likelihood: -258.596
# Total Log likelihood: -258.596
# ...

# %%
### Without Cython Speed UP
hmm = HMM_Analyze(folder="../Simulated/Test2r/", output=False, cython=False)
# %timeit hmm.calc_viterbi_path(save=False)
# Out:
# Successfully loaded Data from: ../Simulated/Test2r/
# Loaded Transition Model: model
# Loaded Emission Model: haploid
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# ...

# %%
hmm = HMM_Analyze(folder="../Simulated/Test2r/", output=False, cython=True)
# %timeit hmm.calc_viterbi_path(save=False)
# Out:
# Successfully loaded Data from: ../Simulated/Test2r/
# Loaded Transition Model: model
# Loaded Emission Model: haploid
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# Log likelihood Path: -293.436
# ...
