# %% [markdown]
# # Apply Summary Statistic to whole data
# Goal: Identify offspring of first cousins or closer

# %%
import numpy as np
import os as os
import sys as sys
import multiprocessing as mp
import pandas as pd
import socket
import matplotlib.pyplot as plt

### Pick the right path (whether on cluster or at home)
socket_name = socket.gethostname()
print(socket_name)
if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)

sys.path.append("./Python3/")  # Since now we are in the Root Directory
from hmm_inference import HMM_Analyze   # Do not move. Should be after sys.path..
#sys.path.append("./Python3/create1000G_Mosaic/")  # Since now we are in the Root Directory
#from createMosaicsMulti import Mosaic_1000G_Multi  # Import the object that can create the Multiruns

print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")
# Out:
# VioletQueen
# /home/harald/git/HAPSBURG
# CPU Count: 4

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("./Empirical/roh_all_inds.csv", sep='\t')

# %%
# frac = 0.65    # The fraction of the short ROH substraction
# min_stat = 0.8 # The Minimum Stat
def calc_statistic(df, frac=0.65, cm = [4,8,12] ):
    """Calculate the statistic from cutoff.
    cm: Cutoffs [in centiMorgan]
    frac: Fraction of the lower category to substract"""
    statistic = df[f"sum_roh>{cm[2]}"] - frac * ((df[f"sum_roh>{cm[0]}"]) - df[f"sum_roh>{cm[1]}"])
    return statistic

def plot_statistic_hist(statistic, cut_off=70, bins=np.arange(-400,400,5),
                   figsize=(8,4), xlim=[-400,400]):
    """Plot histogram of Statistic"""
    plt.figure(figsize=figsize)
    ax=plt.gca()
    ax.hist(statistic, bins=bins, ec="k")
    ax.set_xlim(xlim)
    ax.set_ylim([0,200])
    ax.set_title("Distribution Summary Statistic")
    ax.axvline(x=cut_off, color="red")
    plt.show()
    
def print_statistic(statistic, cutoff=[70,100,150,200]):
    """Print # Values of statistic bigger than cutoff"""
    n = len(statistic)
    for c in cutoff:
        n1 = np.sum(statistic>c)
        print(f"Bigger than {c}: {n1}/{n}")

# %%
statistic = calc_statistic(df)
plot_statistic_hist(statistic, xlim=[-200,500], cut_off=70)
print_statistic(statistic)
# Out:
# Bigger than 70: 216/3232
# Bigger than 100: 152/3232
# Bigger than 150: 92/3232
# Bigger than 200: 60/3232

# %%
df_m = df[df["age"]==0].copy()
statistic = calc_statistic(df_m)
plot_statistic_hist(statistic, cut_off=70, xlim=[-200,500])
print_statistic(statistic)
# Out:
# Bigger than 70: 179/1941
# Bigger than 100: 127/1941
# Bigger than 150: 80/1941
# Bigger than 200: 54/1941

# %% [markdown]
# ## Rank by statistic

# %%
statistic = calc_statistic(df)
idx = np.argsort(statistic)

# %%
### Calculate for Modern Samples
df_m = df[df["age"]==0].copy()
statistic = calc_statistic(df_m)
idx = np.argsort(statistic)
df_m.iloc[idx,:]
# Out:
#                  iid           pop     max_roh   sum_roh>4  n_roh>4  \
# 1304       Kusunda_8       Kusunda   17.500895  421.116423       57
# 1358         Hadza_2         Hadza   28.286100  262.123512       40
# 1560         Hadza_1         Hadza   10.636902   99.650816       17
# 1578       Kalash_14        Kalash   11.871701   92.587928       14
# 1579       Chukchi_3       Chukchi   11.070204   92.293502       14
# 1626        Atayal_3        Atayal    8.487797   74.892797       14
# 1677        Atayal_0        Atayal    7.705498   63.668915       11
# 1616        Atayal_6        Atayal   10.270199   77.748809       12
# 1668       Chukchi_7       Chukchi   10.340601   65.218099       10
# 1505      Chukchi_21       Chukchi   10.392000  119.781691       17
# 1730         Yakut_5         Yakut    7.710000   52.851219        8
# 1533       Eskimo_14        Eskimo   14.808297  106.489784       17
# 1609      Tubalar_17       Tubalar   11.465103   79.546109       12
# 1696          Mixe_7          Mixe   10.881499   59.268001       10
# 1526         Hadza_4         Hadza   12.667095  110.308495       16
# 1659        Kalash_4        Kalash   10.888803   66.469993       10
# 1670       Yukagir_4       Yukagir   10.518998   64.933592       11
# 1671       Chukchi_2       Chukchi    9.731504   64.710799       10
# 1707      Chukchi_18       Chukchi   11.776292   56.914302       10
# 1720       Papuan_11        Papuan   10.478700   54.880090        9
# 1742      Chukchi_20       Chukchi    8.600003   52.058204        9
# 1800        Eskimo_8        Eskimo    6.093201   43.397806        9
# 1570       Kalash_11        Kalash   15.847599   95.196077       14
# 1737        Kalash_6        Kalash    9.333001   52.494009        9
# 1686         Hadza_0         Hadza    9.909397   61.432686       10
# 1538    Cochin_Jew_0    Cochin_Jew   11.537802  103.672399       14
# 1746        Papuan_5        Papuan   10.212803   51.519814        9
# 1818         Yakut_6         Yakut    7.415795   40.978492        7
# 1693    Cochin_Jew_3    Cochin_Jew   10.068012   60.118424        9
# 1743      Chukchi_16       Chukchi   11.806106   52.031097        9
# ...              ...           ...         ...         ...      ...
# 1308      Balochi_16       Balochi   51.099300  410.489315       30
# 1332     BedouinA_11      BedouinA   75.687497  325.788194       15
# 1306         Surui_3         Surui   50.861692  418.176677       28
# 1309      Makrani_17       Makrani   48.696101  408.913315       27
# 1349         Tujia_2         Tujia  157.113902  280.060284        3
# 1316       Balochi_0       Balochi   90.107697  390.835010       20
# 1318      Makrani_16       Makrani   38.863903  375.986565       22
# 1300  Tunisian_Jew_2  Tunisian_Jew  101.071715  462.131325       28
# 1312     Jordanian_2     Jordanian   33.541799  398.418900       26
# 1322         Saudi_3         Saudi   66.003597  359.428709       20
# 1305        Syrian_5        Syrian   65.470994  420.765380       27
# 1314        Sindhi_9        Sindhi   39.794400  395.274110       24
# 1325       Pathan_16        Pathan   55.872607  348.304323       18
# 1326        Sindhi_4        Sindhi   43.713301  346.288899       21
# 1320       Balochi_5       Balochi   51.195597  366.510165       20
# 1298         Surui_7         Surui   36.485505  499.415998       38
# 1302         Surui_5         Surui   36.631894  442.665492       30
# 1324     Jordanian_5     Jordanian   48.661995  350.821298       19
# 1303      Lebanese_1      Lebanese   46.195000  424.840383       25
# 1310          Pima_5          Pima   51.157599  404.903109       22
# 1311      Saharawi_5      Saharawi   47.007999  401.566989       21
# 1299         Surui_6         Surui   96.734203  482.479889       28
# 1301         Uzbek_4         Uzbek   73.301301  457.112501       23
# 1292    Karitiana_11     Karitiana   71.722305  609.730034       38
# 1296         Pima_11          Pima  124.891199  543.410879       30
# 1297         Surui_4         Surui   50.708199  517.682011       34
# 1293         Surui_1         Surui   92.519199  598.087441       31
# 1295      Lebanese_6      Lebanese   59.008193  552.432877       29
# 1294      Makrani_12       Makrani   39.371300  568.998682       34
# 1291         Surui_0         Surui   45.051694  694.037023       49
#
#        sum_roh>8  n_roh>8  sum_roh>12  n_roh>12   lat    lon  age  \
# 1304  171.865712       15   83.805906         6  28.1   82.5  0.0
# 1358   83.777997        6   46.683204         2  -3.6   35.1  0.0
# 1560   20.185995        2    0.000000         0  -3.6   35.1  0.0
# 1578   20.887702        2    0.000000         0  36.0   71.5  0.0
# 1579   20.727003        2    0.000000         0  69.5  168.8  0.0
# 1626    8.487797        1    0.000000         0  24.6  121.3  0.0
# 1677    0.000000        0    0.000000         0  24.6  121.3  0.0
# 1616   19.068798        2    0.000000         0  24.6  121.3  0.0
# 1668   10.340601        1    0.000000         0  69.5  168.8  0.0
# 1505   65.070500        7    0.000000         0  64.4  173.9  0.0
# 1730    0.000000        0    0.000000         0  63.0  129.5  0.0
# 1533   33.048683        3   14.808297         1  66.0  169.7  0.0
# 1609   29.322100        3    0.000000         0  51.1   87.0  0.0
# 1696   10.881499        1    0.000000         0  17.0   96.6  0.0
# 1526   42.453187        4   12.667095         1  -3.6   35.1  0.0
# 1659   20.229506        2    0.000000         0  36.0   71.5  0.0
# 1670   19.104689        2    0.000000         0  68.6  153.0  0.0
# 1671   18.954006        2    0.000000         0  69.5  168.8  0.0
# 1707   11.776292        1    0.000000         0  69.5  168.8  0.0
# 1720   10.478700        1    0.000000         0  -4.0  143.0  0.0
# 1742    8.600003        1    0.000000         0  69.5  168.8  0.0
# 1800    0.000000        0    0.000000         0  64.4  173.9  0.0
# 1570   27.497589        2   15.847599         1  36.0   71.5  0.0
# 1737    9.333001        1    0.000000         0  36.0   71.5  0.0
# 1686   19.730597        2    0.000000         0  -3.6   35.1  0.0
# 1538   62.227497        6    0.000000         0  10.0   76.3  0.0
# 1746   10.212803        1    0.000000         0  -4.0  143.0  0.0
# 1818    0.000000        0    0.000000         0  63.0  129.5  0.0
# 1693   19.412328        2    0.000000         0  10.0   76.3  0.0
# 1743   11.806106        1    0.000000         0  69.5  168.8  0.0
# ...          ...      ...         ...       ...   ...    ...  ...
# 1308  366.439014       22  280.955415        13  30.5   66.5  0.0
# 1332  301.319497       10  291.701197         9  31.0   35.0  0.0
# 1306  365.010177       18  310.817888        12 -11.0  -62.0  0.0
# 1309  373.028016       20  302.552311        13  26.0   64.0  0.0
# 1349  280.060284        3  280.060284         3  29.0  109.0  0.0
# 1316  340.396095       12  314.565102         9  30.5   66.5  0.0
# 1318  357.095069       19  296.854680        13  26.0   64.0  0.0
# 1300  396.016340       17  327.700313        10  36.8   10.2  0.0
# 1312  361.720602       20  308.595502        14  32.1   35.9  0.0
# 1322  322.188710       14  310.471811        13  18.5   42.5  0.0
# 1305  372.034779       18  319.744282        13  35.1   36.9  0.0
# 1314  361.604311       18  310.602814        13  25.5   69.0  0.0
# 1325  324.781317       14  304.262310        12  33.5   70.5  0.0
# 1326  334.357802       19  297.022301        15  25.5   69.0  0.0
# 1320  334.632962       14  313.788464        12  30.5   66.5  0.0
# 1298  416.420093       23  354.785003        17 -11.0  -62.0  0.0
# 1302  393.274282       21  335.728694        15 -11.0  -62.0  0.0
# 1324  337.912201       17  320.885201        15  32.1   35.9  0.0
# 1303  410.192205       22  324.896102        14  33.8   35.6  0.0
# 1310  373.721012       17  344.733104        14  29.0 -108.0  0.0
# 1311  375.956992       16  343.737982        13  27.3   -8.9  0.0
# 1299  439.879094       21  373.253603        14 -11.0  -62.0  0.0
# 1301  416.245893       16  394.651494        14  41.3   69.2  0.0
# 1292  500.172620       20  461.165116        16 -10.0  -63.0  0.0
# 1296  495.179579       21  422.557495        13  29.0 -108.0  0.0
# 1297  464.438611       24  432.264611        21 -11.0  -62.0  0.0
# 1293  506.134515       15  477.951111        12 -11.0  -62.0  0.0
# 1295  512.506074       22  460.429071        17  33.8   35.6  0.0
# 1294  534.789077       28  458.872198        20  26.0   64.0  0.0
# 1291  583.532804       30  522.787878        24 -11.0  -62.0  0.0
#
#                       study    clst  mean_cov  n_cov_snp  include_alt   color  \
# 1304  Lazaridis et al. 2014  Modern       NaN     554199            1  yellow
# 1358  Lazaridis et al. 2014  Modern       NaN     540831            1  yellow
# 1560  Lazaridis et al. 2014  Modern       NaN     543967            1  yellow
# 1578  Lazaridis et al. 2014  Modern       NaN     553663            1  yellow
# 1579  Lazaridis et al. 2014  Modern       NaN     555618            1  yellow
# 1626  Lazaridis et al. 2014  Modern       NaN     552401            1  yellow
# 1677  Lazaridis et al. 2014  Modern       NaN     555199            1  yellow
# 1616  Lazaridis et al. 2014  Modern       NaN     554252            1  yellow
# 1668  Lazaridis et al. 2014  Modern       NaN     555748            1  yellow
# 1505  Lazaridis et al. 2014  Modern       NaN     552905            1  yellow
# 1730  Lazaridis et al. 2014  Modern       NaN     555433            1  yellow
# 1533  Lazaridis et al. 2014  Modern       NaN     555246            1  yellow
# 1609  Lazaridis et al. 2014  Modern       NaN     555652            1  yellow
# 1696  Lazaridis et al. 2014  Modern       NaN     554529            1  yellow
# 1526  Lazaridis et al. 2014  Modern       NaN     545031            1  yellow
# 1659  Lazaridis et al. 2014  Modern       NaN     554022            1  yellow
# 1670  Lazaridis et al. 2014  Modern       NaN     555149            1  yellow
# 1671  Lazaridis et al. 2014  Modern       NaN     555686            1  yellow
# 1707  Lazaridis et al. 2014  Modern       NaN     555221            1  yellow
# 1720  Lazaridis et al. 2014  Modern       NaN     555090            1  yellow
# 1742  Lazaridis et al. 2014  Modern       NaN     555094            1  yellow
# 1800  Lazaridis et al. 2014  Modern       NaN     552837            1  yellow
# 1570  Lazaridis et al. 2014  Modern       NaN     550397            1  yellow
# 1737  Lazaridis et al. 2014  Modern       NaN     552136            1  yellow
# 1686  Lazaridis et al. 2014  Modern       NaN     543902            1  yellow
# 1538  Lazaridis et al. 2014  Modern       NaN     554753            1  yellow
# 1746  Lazaridis et al. 2014  Modern       NaN     555313            1  yellow
# 1818  Lazaridis et al. 2014  Modern       NaN     554966            1  yellow
# 1693  Lazaridis et al. 2014  Modern       NaN     555547            1  yellow
# 1743  Lazaridis et al. 2014  Modern       NaN     554755            1  yellow
# ...                     ...     ...       ...        ...          ...     ...
# 1308  Lazaridis et al. 2014  Modern       NaN     555244            1  yellow
# 1332  Lazaridis et al. 2014  Modern       NaN     555370            1  yellow
# 1306  Lazaridis et al. 2014  Modern       NaN     548535            1  yellow
# 1309  Lazaridis et al. 2014  Modern       NaN     555120            1  yellow
# 1349  Lazaridis et al. 2014  Modern       NaN     555498            1  yellow
# 1316  Lazaridis et al. 2014  Modern       NaN     554689            1  yellow
# 1318  Lazaridis et al. 2014  Modern       NaN     554497            1  yellow
# 1300  Lazaridis et al. 2014  Modern       NaN     555263            1  yellow
# 1312  Lazaridis et al. 2014  Modern       NaN     555548            1  yellow
# 1322  Lazaridis et al. 2014  Modern       NaN     554910            1  yellow
# 1305  Lazaridis et al. 2014  Modern       NaN     555554            1  yellow
# 1314  Lazaridis et al. 2014  Modern       NaN     552518            1  yellow
# 1325  Lazaridis et al. 2014  Modern       NaN     552564            1  yellow
# 1326  Lazaridis et al. 2014  Modern       NaN     553728            1  yellow
# 1320  Lazaridis et al. 2014  Modern       NaN     553925            1  yellow
# 1298  Lazaridis et al. 2014  Modern       NaN     551142            1  yellow
# 1302  Lazaridis et al. 2014  Modern       NaN     551416            1  yellow
# 1324  Lazaridis et al. 2014  Modern       NaN     553306            1  yellow
# 1303  Lazaridis et al. 2014  Modern       NaN     553756            1  yellow
# 1310  Lazaridis et al. 2014  Modern       NaN     555623            1  yellow
# 1311  Lazaridis et al. 2014  Modern       NaN     555296            1  yellow
# 1299  Lazaridis et al. 2014  Modern       NaN     551165            1  yellow
# 1301  Lazaridis et al. 2014  Modern       NaN     549425            1  yellow
# 1292  Lazaridis et al. 2014  Modern       NaN     553410            1  yellow
# 1296  Lazaridis et al. 2014  Modern       NaN     554855            1  yellow
# 1297  Lazaridis et al. 2014  Modern       NaN     549636            1  yellow
# 1293  Lazaridis et al. 2014  Modern       NaN     546003            1  yellow
# 1295  Lazaridis et al. 2014  Modern       NaN     553090            1  yellow
# 1294  Lazaridis et al. 2014  Modern       NaN     554321            1  yellow
# 1291  Lazaridis et al. 2014  Modern       NaN     555005            1  yellow
#
#               region
# 1304         Kusunda
# 1358           Hadza
# 1560           Hadza
# 1578          Kalash
# 1579         Chukchi
# 1626          Atayal
# 1677          Atayal
# 1616          Atayal
# 1668         Chukchi
# 1505         Chukchi
# 1730           Yakut
# 1533          Eskimo
# 1609          Steppe
# 1696            Mixe
# 1526           Hadza
# 1659          Kalash
# 1670         Yukagir
# 1671         Chukchi
# 1707         Chukchi
# 1720          Papuan
# 1742         Chukchi
# 1800          Eskimo
# 1570          Kalash
# 1737          Kalash
# 1686           Hadza
# 1538      Cochin_Jew
# 1746          Papuan
# 1818           Yakut
# 1693      Cochin_Jew
# 1743         Chukchi
# ...              ...
# 1308         Balochi
# 1332         Levante
# 1306  Atlantic Coast
# 1309         Makrani
# 1349           Tujia
# 1316         Balochi
# 1318         Makrani
# 1300    Tunisian_Jew
# 1312         Levante
# 1322           Saudi
# 1305         Levante
# 1314          Sindhi
# 1325          Pathan
# 1326          Sindhi
# 1320         Balochi
# 1298  Atlantic Coast
# 1302  Atlantic Coast
# 1324         Levante
# 1303         Levante
# 1310            Pima
# 1311    North Africa
# 1299  Atlantic Coast
# 1301          Steppe
# 1292       Karitiana
# 1296            Pima
# 1297  Atlantic Coast
# 1293  Atlantic Coast
# 1295         Levante
# 1294         Makrani
# 1291  Atlantic Coast
#
# [1941 rows x 19 columns]

# %% [markdown]
# ### Do per Pop Statistics

# %%
cutoff= 70

df = pd.read_csv("./Empirical/roh_all_inds.csv", sep='\t')
statistic = calc_statistic(df)
df["statistic"] = statistic
df[f"statistic>{cutoff}"] = (statistic >= cutoff)

df_m = df[df["age"]==0].copy()
df_mg = df_m.groupby("pop")
df_pop_stat = df_mg[f"statistic>{cutoff}"].agg(["sum", 'count'])
df_pop_stat["percent"] = df_pop_stat["sum"]/df_pop_stat["count"]

# %%
### Calculate Binomial Confidence Intervalls
from scipy.stats import binom.inter

# %%
df_pop_stat.sort_values(by="percent", ascending=False)
# Out:
#                 sum  count   percent
# pop
# Saami_WGA       1.0      1  1.000000
# Surui           8.0      8  1.000000
# Karitiana       9.0     12  0.750000
# Syrian          5.0      8  0.625000
# Balochi        11.0     20  0.550000
# Makrani        10.0     20  0.500000
# BedouinA       11.0     25  0.440000
# Tunisian_Jew    3.0      7  0.428571
# Pima            6.0     14  0.428571
# Tunisian        3.0      8  0.375000
# Druze          13.0     39  0.333333
# Saharawi        2.0      6  0.333333
# Jordanian       3.0      9  0.333333
# Brahui          7.0     21  0.333333
# Australian      1.0      3  0.333333
# BedouinB        6.0     19  0.315789
# Algerian        2.0      7  0.285714
# Turkmen         2.0      7  0.285714
# Sindhi          5.0     18  0.277778
# Tajik_Pomiri    2.0      8  0.250000
# Saudi           2.0      8  0.250000
# Piapoco         1.0      4  0.250000
# Lebanese        2.0      8  0.250000
# Yemenite_Jew    2.0      8  0.250000
# Palestinian     9.0     38  0.236842
# Libyan_Jew      2.0      9  0.222222
# Pathan          4.0     19  0.210526
# Tujia           2.0     10  0.200000
# Mixtec          2.0     10  0.200000
# Uzbek           2.0     10  0.200000
# ...             ...    ...       ...
# Lithuanian      0.0     10  0.000000
# Lezgin          0.0      9  0.000000
# Lahu            0.0      8  0.000000
# Kusunda         0.0     10  0.000000
# Koryak          0.0      9  0.000000
# Abkhasian       0.0      9  0.000000
# Kinh            0.0      8  0.000000
# Kikuyu          0.0      4  0.000000
# Kalmyk          0.0     10  0.000000
# Kalash          0.0     18  0.000000
# Ju_hoan_North   0.0      5  0.000000
# Itelmen         0.0      6  0.000000
# Italian_South   0.0      1  0.000000
# Icelandic       0.0     12  0.000000
# Finnish         0.0      7  0.000000
# Hungarian       0.0     20  0.000000
# Hezhen          0.0      8  0.000000
# Han_NChina      0.0     10  0.000000
# Han             0.0     33  0.000000
# Hadza           0.0      5  0.000000
# GujaratiD       0.0      5  0.000000
# GujaratiC       0.0      5  0.000000
# GujaratiB       0.0      5  0.000000
# GujaratiA       0.0      5  0.000000
# Greek           0.0     20  0.000000
# Georgian_Jew    0.0      7  0.000000
# Georgian        0.0     10  0.000000
# Gambian         0.0      6  0.000000
# French_South    0.0      7  0.000000
# Zapotec         0.0     10  0.000000
#
# [162 rows x 3 columns]

# %% [markdown]
# # Area 51

# %%
from statsmodels.stats.proportion import proportion_confint

# %%
proportion_confint(1,20)
# Out:
# (0.0, 0.14551682940272123)

# %%
proportion_confint(0,100, method="wilson")
# Out:
# (0.0, 0.03699349820698569)

# %%
proportion_confint(0,100, method="jeffreys")
# Out:
# (4.898073104397494e-06, 0.02474527001526987)

# %%
3/50
# Out:
# 0.06
