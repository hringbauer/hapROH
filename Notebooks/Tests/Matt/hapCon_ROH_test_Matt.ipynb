# %% [markdown]
# # a test on Matt's problematic pileup files

# %%
import sys
sys.path.insert(0, "/mnt/archgen/users/yilei/tools/hapROH/package")

# %%
from hapsburg.PackagesSupport.loadEigenstrat.saveHDF5 import mpileup2hdf5

for ch in range(1,23):
    mpileup2hdf5(f'./Matt/test.chr{ch}.mpileup',f'/mnt/archgen/users/yilei/Data/1000G/1000g1240khdf5/all1240/chr{ch}.hdf5')
# Out:
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 734
# number of minor reads at flanking sites: 18
# number of major reads at focal sites: 15211
# number of minor reads at focal sites: 1193
# err rate at flanking sites: 0.023936
# err rate at focal sites: 0.072726
# saving sample as test.chr1 in test.chr1.hdf5
# estimated genotyping error by flanking sites: 0.023936
# number of sites covered by at least one read: 27889, fraction covered: 0.313
# hdf5 file saved to test.chr1.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 715
# number of minor reads at flanking sites: 18
# number of major reads at focal sites: 14937
# number of minor reads at focal sites: 1164
# err rate at flanking sites: 0.024557
# err rate at focal sites: 0.072294
# saving sample as test.chr2 in test.chr2.hdf5
# estimated genotyping error by flanking sites: 0.024557
# number of sites covered by at least one read: 28220, fraction covered: 0.299
# hdf5 file saved to test.chr2.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 598
# number of minor reads at flanking sites: 10
# number of major reads at focal sites: 11778
# number of minor reads at focal sites: 955
# err rate at flanking sites: 0.016447
# err rate at focal sites: 0.075002
# saving sample as test.chr3 in test.chr3.hdf5
# estimated genotyping error by flanking sites: 0.016447
# number of sites covered by at least one read: 22807, fraction covered: 0.294
# hdf5 file saved to test.chr3.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 387
# number of minor reads at flanking sites: 13
# number of major reads at focal sites: 9166
# number of minor reads at focal sites: 717
# err rate at flanking sites: 0.032500
# err rate at focal sites: 0.072549
# saving sample as test.chr4 in test.chr4.hdf5
# estimated genotyping error by flanking sites: 0.032500
# number of sites covered by at least one read: 19079, fraction covered: 0.277
# hdf5 file saved to test.chr4.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 748
# number of minor reads at flanking sites: 20
# number of major reads at focal sites: 10429
# number of minor reads at focal sites: 713
# err rate at flanking sites: 0.026042
# err rate at focal sites: 0.063992
# saving sample as test.chr5 in test.chr5.hdf5
# estimated genotyping error by flanking sites: 0.026042
# number of sites covered by at least one read: 20384, fraction covered: 0.294
# hdf5 file saved to test.chr5.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 514
# number of minor reads at flanking sites: 12
# number of major reads at focal sites: 11860
# number of minor reads at focal sites: 788
# err rate at flanking sites: 0.022814
# err rate at focal sites: 0.062302
# saving sample as test.chr6 in test.chr6.hdf5
# estimated genotyping error by flanking sites: 0.022814
# number of sites covered by at least one read: 22609, fraction covered: 0.298
# hdf5 file saved to test.chr6.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 450
# number of minor reads at flanking sites: 13
# number of major reads at focal sites: 9579
# number of minor reads at focal sites: 735
# err rate at flanking sites: 0.028078
# err rate at focal sites: 0.071262
# saving sample as test.chr7 in test.chr7.hdf5
# estimated genotyping error by flanking sites: 0.028078
# number of sites covered by at least one read: 18085, fraction covered: 0.302
# hdf5 file saved to test.chr7.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 458
# number of minor reads at flanking sites: 9
# number of major reads at focal sites: 10097
# number of minor reads at focal sites: 702
# err rate at flanking sites: 0.019272
# err rate at focal sites: 0.065006
# saving sample as test.chr8 in test.chr8.hdf5
# estimated genotyping error by flanking sites: 0.019272
# number of sites covered by at least one read: 18650, fraction covered: 0.305
# hdf5 file saved to test.chr8.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 374
# number of minor reads at flanking sites: 11
# number of major reads at focal sites: 8508
# number of minor reads at focal sites: 615
# err rate at flanking sites: 0.028571
# err rate at focal sites: 0.067412
# saving sample as test.chr9 in test.chr9.hdf5
# estimated genotyping error by flanking sites: 0.028571
# number of sites covered by at least one read: 15544, fraction covered: 0.307
# hdf5 file saved to test.chr9.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 425
# number of minor reads at flanking sites: 10
# number of major reads at focal sites: 10164
# number of minor reads at focal sites: 815
# err rate at flanking sites: 0.022989
# err rate at focal sites: 0.074233
# saving sample as test.chr10 in test.chr10.hdf5
# estimated genotyping error by flanking sites: 0.022989
# number of sites covered by at least one read: 18535, fraction covered: 0.315
# hdf5 file saved to test.chr10.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 410
# number of minor reads at flanking sites: 13
# number of major reads at focal sites: 9290
# number of minor reads at focal sites: 708
# err rate at flanking sites: 0.030733
# err rate at focal sites: 0.070814
# saving sample as test.chr11 in test.chr11.hdf5
# estimated genotyping error by flanking sites: 0.030733
# number of sites covered by at least one read: 16922, fraction covered: 0.309
# hdf5 file saved to test.chr11.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 366
# number of minor reads at flanking sites: 8
# number of major reads at focal sites: 8625
# number of minor reads at focal sites: 643
# err rate at flanking sites: 0.021390
# err rate at focal sites: 0.069379
# saving sample as test.chr12 in test.chr12.hdf5
# estimated genotyping error by flanking sites: 0.021390
# number of sites covered by at least one read: 16267, fraction covered: 0.302
# hdf5 file saved to test.chr12.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 224
# number of minor reads at flanking sites: 1
# number of major reads at focal sites: 5598
# number of minor reads at focal sites: 423
# err rate at flanking sites: 0.004444
# err rate at focal sites: 0.070254
# saving sample as test.chr13 in test.chr13.hdf5
# estimated genotyping error by flanking sites: 0.004444
# number of sites covered by at least one read: 10974, fraction covered: 0.281
# hdf5 file saved to test.chr13.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 285
# number of minor reads at flanking sites: 4
# number of major reads at focal sites: 6200
# number of minor reads at focal sites: 466
# err rate at flanking sites: 0.013841
# err rate at focal sites: 0.069907
# saving sample as test.chr14 in test.chr14.hdf5
# estimated genotyping error by flanking sites: 0.013841
# number of sites covered by at least one read: 11086, fraction covered: 0.305
# hdf5 file saved to test.chr14.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 282
# number of minor reads at flanking sites: 6
# number of major reads at focal sites: 6418
# number of minor reads at focal sites: 514
# err rate at flanking sites: 0.020833
# err rate at focal sites: 0.074149
# saving sample as test.chr15 in test.chr15.hdf5
# estimated genotyping error by flanking sites: 0.020833
# number of sites covered by at least one read: 11073, fraction covered: 0.322
# hdf5 file saved to test.chr15.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 301
# number of minor reads at flanking sites: 9
# number of major reads at focal sites: 6781
# number of minor reads at focal sites: 540
# err rate at flanking sites: 0.029032
# err rate at focal sites: 0.073760
# saving sample as test.chr16 in test.chr16.hdf5
# estimated genotyping error by flanking sites: 0.029032
# number of sites covered by at least one read: 11394, fraction covered: 0.331
# hdf5 file saved to test.chr16.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 307
# number of minor reads at flanking sites: 5
# number of major reads at focal sites: 6217
# number of minor reads at focal sites: 453
# err rate at flanking sites: 0.016026
# err rate at focal sites: 0.067916
# saving sample as test.chr17 in test.chr17.hdf5
# estimated genotyping error by flanking sites: 0.016026
# number of sites covered by at least one read: 10141, fraction covered: 0.346
# hdf5 file saved to test.chr17.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 258
# number of minor reads at flanking sites: 9
# number of major reads at focal sites: 5295
# number of minor reads at focal sites: 397
# err rate at flanking sites: 0.033708
# err rate at focal sites: 0.069747
# saving sample as test.chr18 in test.chr18.hdf5
# estimated genotyping error by flanking sites: 0.033708
# number of sites covered by at least one read: 10281, fraction covered: 0.303
# hdf5 file saved to test.chr18.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 216
# number of minor reads at flanking sites: 4
# number of major reads at focal sites: 4310
# number of minor reads at focal sites: 368
# err rate at flanking sites: 0.018182
# err rate at focal sites: 0.078666
# saving sample as test.chr19 in test.chr19.hdf5
# estimated genotyping error by flanking sites: 0.018182
# number of sites covered by at least one read: 6721, fraction covered: 0.364
# hdf5 file saved to test.chr19.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 226
# number of minor reads at flanking sites: 8
# number of major reads at focal sites: 5794
# number of minor reads at focal sites: 453
# err rate at flanking sites: 0.034188
# err rate at focal sites: 0.072515
# saving sample as test.chr20 in test.chr20.hdf5
# estimated genotyping error by flanking sites: 0.034188
# number of sites covered by at least one read: 9634, fraction covered: 0.331
# hdf5 file saved to test.chr20.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 113
# number of minor reads at flanking sites: 2
# number of major reads at focal sites: 2637
# number of minor reads at focal sites: 226
# err rate at flanking sites: 0.017391
# err rate at focal sites: 0.078938
# saving sample as test.chr21 in test.chr21.hdf5
# estimated genotyping error by flanking sites: 0.017391
# number of sites covered by at least one read: 4844, fraction covered: 0.302
# hdf5 file saved to test.chr21.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# number of major reads at flanking sites: 145
# number of minor reads at flanking sites: 6
# number of major reads at focal sites: 4025
# number of minor reads at focal sites: 304
# err rate at flanking sites: 0.039735
# err rate at focal sites: 0.070224
# saving sample as test.chr22 in test.chr22.hdf5
# estimated genotyping error by flanking sites: 0.039735
# number of sites covered by at least one read: 6018, fraction covered: 0.381
# hdf5 file saved to test.chr22.hdf5

# %%
# !hapCon_ROH --mpileup ./Matt -i test -r /mnt/archgen/users/yilei/Data/1000G/1000g1240khdf5/all1240/chr --meta /mnt/archgen/users/yilei/Data/1000G/1000g1240khdf5/all1240/meta_df_all.csv
# Out:
# saving hdf5 files in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr1.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr2.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr3.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr4.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr5.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr6.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr7.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr8.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr9.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr10.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr11.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr12.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr13.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr14.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr15.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr16.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr17.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr18.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr19.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr20.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr21.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as test in /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hdf5/test.chr22.hdf5
# finished reading input files, takes 20.717s
# estimated genotyping error: 0.023850409557141142
# fraction of sites covered by at least one read: 0.3062101748853836
# Doing Individual test...
# Set Output Log path: /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hapRoh_iter/test/chr1/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# number of blocks found with null-model: 4 with total length 33.219cM
# chr5	1.285502	1.415539
# chr14	0.252409	0.335213
# chr15	0.619845	0.707687
# chr17	0.659744	0.731246
# a total of 4 ROH blocks passing filtering threshold found, total length after trimming: 33.219cM.
# 4 hmm models loaded, takes 164.431s
# hapsb_multiChunk_preload takes 0.5502474308013916
# hapsb_multiChunk_preload takes 0.41172361373901367
# hapsb_multiChunk_preload takes 0.395643949508667
# hapsb_multiChunk_preload takes 0.37603282928466797
# hapsb_multiChunk_preload takes 0.3605530261993408
# hapsb_multiChunk_preload takes 0.2704153060913086
# hapsb_multiChunk_preload takes 0.2686767578125
# hapsb_multiChunk_preload takes 0.26488351821899414
# hapsb_multiChunk_preload takes 0.25057387351989746
# hapsb_multiChunk_preload takes 0.5438873767852783
# hapsb_multiChunk_preload takes 0.2594935894012451
# hapsb_multiChunk_preload takes 0.25101590156555176
# hapsb_multiChunk_preload takes 0.25316739082336426
# hapsb_multiChunk_preload takes 0.37597060203552246
# hapsb_multiChunk_preload takes 0.25005030632019043
# hapsb_multiChunk_preload takes 0.24612045288085938
# hapsb_multiChunk_preload takes 0.25004029273986816
# hapsb_multiChunk_preload takes 0.35849475860595703
# hapsb_multiChunk_preload takes 0.42914485931396484
# estimated contamination rate 0.052893 greater than 0.05, start iteration.
# Doing Individual test...
# Set Output Log path: /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hapRoh_iter/test/chr1/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# chr2	2.233203	2.294629
# chr5	0.326404	0.390297
# chr5	1.285044	1.415697
# chr14	0.112034	0.167947
# chr14	0.249489	0.335363
# chr15	0.619845	0.722629
# chr16	0.051745	0.134458
# chr17	0.659744	0.732082
# a total of 8 ROH blocks passing filtering threshold found, total length after trimming: 57.559cM.
# 8 hmm models loaded, takes 464.493s
# hapsb_multiChunk_preload takes 0.552776575088501
# hapsb_multiChunk_preload takes 0.5919411182403564
# hapsb_multiChunk_preload takes 0.418196439743042
# hapsb_multiChunk_preload takes 0.42392730712890625
# hapsb_multiChunk_preload takes 0.43415141105651855
# hapsb_multiChunk_preload takes 0.4381842613220215
# hapsb_multiChunk_preload takes 0.46250414848327637
# hapsb_multiChunk_preload takes 0.41926050186157227
# hapsb_multiChunk_preload takes 0.4269144535064697
# hapsb_multiChunk_preload takes 0.46230411529541016
# hapsb_multiChunk_preload takes 0.4239623546600342
# hapsb_multiChunk_preload takes 0.43479108810424805
# hapsb_multiChunk_preload takes 0.4222755432128906
# hapsb_multiChunk_preload takes 0.451033353805542
# hapsb_multiChunk_preload takes 0.4762277603149414
# hapsb_multiChunk_preload takes 0.41751813888549805
# hapsb_multiChunk_preload takes 0.49158430099487305
# hapsb_multiChunk_preload takes 0.412447452545166
# hapsb_multiChunk_preload takes 0.40096426010131836
# iteration 2 done, prev contam: 0.052893, current contam: 0.053902
# contamination rate converged after 2 iterations.
# Doing Individual test...
# Set Output Log path: /mnt/archgen/users/yilei/tools/hapROH/Notebooks/Tests/hapRoh_iter/test/chr1/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
