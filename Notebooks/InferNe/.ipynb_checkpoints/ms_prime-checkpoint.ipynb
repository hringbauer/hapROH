# %% [markdown]
# # Simulate ROH under constant Ne

# %%
import numpy as np
import os  # For Saving to Folder
import pandas as pd
import matplotlib.pyplot as plt
import socket
import os as os
import sys as sys
import multiprocessing as mp

### For Arial Font
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'   # Set the defaul
rcParams['font.sans-serif'] = ['Arial']  # Make sure to have the font installed (it is on cluster for Harald)

socket_name = socket.gethostname()
print(socket_name)
if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
elif socket_name.startswith("Harald-Laptop"):
    print("Harald laptop detected.")
    path = "/home/hringbauer/git/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")
# Out:
# midway2-0401.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# ### The first test run

# %%
import msprime

# %%
tree = msprime.simulate(sample_size=10, Ne=100).first()

# %%
print(tree.draw(format="unicode"))
# Out:
#    18
# ┏━━━┻━━┓
# ┃     17
# ┃  ┏━━━┻━━━┓
# ┃  ┃      16
# ┃  ┃    ┏━━┻━━┓
# ┃  ┃    ┃    15
# ┃  ┃    ┃   ┏━┻━┓
# ┃  ┃   14   ┃   ┃
# ┃  ┃  ┏━┻┓  ┃   ┃
# ┃  ┃  ┃  ┃  ┃  13
# ┃  ┃  ┃  ┃  ┃ ┏━┻┓
# ┃  ┃  ┃  ┃  ┃ ┃ 12
# ┃  ┃  ┃  ┃  ┃ ┃ ┏┻┓
# ┃ 11  ┃  ┃  ┃ ┃ ┃ ┃
# ┃ ┏┻┓ ┃  ┃  ┃ ┃ ┃ ┃
# ┃ ┃ ┃ ┃ 10  ┃ ┃ ┃ ┃
# ┃ ┃ ┃ ┃ ┏┻┓ ┃ ┃ ┃ ┃
# 8 3 7 0 4 5 1 9 2 6

# %%
u = 2
while u != tskit.NULL:
    print("node {}: time = {}".format(u, tree.time(u)))
    u = tree.parent(u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d598978750ec> in <module>()
#       1 u = 2
# ----> 2 while u != tskit.NULL:
#       3     print("node {}: time = {}".format(u, tree.time(u)))
#       4     u = tree.parent(u)
#
# NameError: name 'tskit' is not defined

# %%
print(tree.branch_length(7))
print(tree.total_branch_length)
# Out:
# 11.994188360901946
# 1175.7360121316685

# %% [markdown]
# ### Move to multiple chromosomes

# %%
# %%time
rho = 1e-8
positions = [0, 1e8-1, 1e8, 2e8-1]
rates = [rho, 0.5, rho, 0]
num_loci = int(positions[-1])

recombination_map = msprime.RecombinationMap(
    positions=positions, rates=rates, num_loci=num_loci)

tree_sequence = msprime.simulate(
    sample_size=2, Ne=1000, recombination_map=recombination_map,
    model="dtwf")

# %%
for tree in tree_sequence.trees():
    print("-" * 20)
    print("tree {}: interval = {}".format(tree.index, tree.interval))
    print(tree.draw(format="unicode"))
# Out:
# --------------------
# tree 0: interval = (0.0, 6847.499979451299)
# 2337
# ┏┻┓
# 0 1
#
# --------------------
# tree 1: interval = (6847.499979451299, 42824.99987152219)
# 1254
# ┏┻┓
# 0 1
#
# --------------------
# tree 2: interval = (42824.99987152219, 175026.24947491288)
# 490
# ┏┻┓
# 0 1
#
# --------------------
# tree 3: interval = (175026.24947491288, 187586.24943724275)
# 2075
# ┏┻┓
# 0 1
#
# --------------------
# tree 4: interval = (187586.24943724275, 199247.49940225482)
# 870
# ┏┻┓
# 0 1
#
# --------------------
# tree 5: interval = (199247.49940225482, 231311.24930606782)
# 1199
# ┏┻┓
# 0 1
#
# --------------------
# tree 6: interval = (231311.24930606782, 247813.74925655127)
# 303
# ┏┻┓
# 0 1
#
# --------------------
# tree 7: interval = (247813.74925655127, 305749.9990827441)
# 1254
# ┏┻┓
# 0 1
#
# --------------------
# tree 8: interval = (305749.9990827441, 313404.99905978143)
# 624
# ┏┻┓
# 0 1
#
# --------------------
# tree 9: interval = (313404.99905978143, 1184981.2464450598)
# 52
# ┏┻┓
# 0 1
#
# --------------------
# tree 10: interval = (1184981.2464450598, 1227238.7463182807)
# 630
# ┏┻┓
# 0 1
#
# --------------------
# tree 11: interval = (1227238.7463182807, 1769389.994691819)
# 69
# ┏┻┓
# 0 1
#
# --------------------
# tree 12: interval = (1769389.994691819, 1818606.2445441782)
# 407
# ┏┻┓
# 0 1
#
# --------------------
# tree 13: interval = (1818606.2445441782, 1893234.9943202883)
# 630
# ┏┻┓
# 0 1
#
# --------------------
# tree 14: interval = (1893234.9943202883, 1958777.4941236675)
# 994
# ┏┻┓
# 0 1
#
# --------------------
# tree 15: interval = (1958777.4941236675, 1977243.744068265)
# 227
# ┏┻┓
# 0 1
#
# --------------------
# tree 16: interval = (1977243.744068265, 2260957.4932171255)
# 1331
# ┏┻┓
# 0 1
#
# --------------------
# tree 17: interval = (2260957.4932171255, 2271954.9931841344)
# 3429
# ┏┻┓
# 0 1
#
# --------------------
# tree 18: interval = (2271954.9931841344, 2278916.243163243)
# 4028
# ┏┻┓
# 0 1
#
# --------------------
# tree 19: interval = (2278916.243163243, 2383321.2428500354)
# 1649
# ┏┻┓
# 0 1
#
# --------------------
# tree 20: interval = (2383321.2428500354, 2482214.9925533533)
# 994
# ┏┻┓
# 0 1
#
# --------------------
# tree 21: interval = (2482214.9925533533, 2517821.242446542)
# 2349
# ┏┻┓
# 0 1
#
# --------------------
# tree 22: interval = (2517821.242446542, 2518082.492445752)
# 1649
# ┏┻┓
# 0 1
#
# --------------------
# tree 23: interval = (2518082.492445752, 2544211.242367357)
# 2349
# ┏┻┓
# 0 1
#
# --------------------
# tree 24: interval = (2544211.242367357, 2569008.7422929704)
# 2510
# ┏┻┓
# 0 1
#
# --------------------
# tree 25: interval = (2569008.7422929704, 2625459.9921236187)
# 3125
# ┏┻┓
# 0 1
#
# --------------------
# tree 26: interval = (2625459.9921236187, 2629886.242110342)
# 2349
# ┏┻┓
# 0 1
#
# --------------------
# tree 27: interval = (2629886.242110342, 2675252.4919742346)
# 3830
# ┏┻┓
# 0 1
#
# --------------------
# tree 28: interval = (2675252.4919742346, 2687318.7419380397)
# 1556
# ┏┻┓
# 0 1
#
# --------------------
# tree 29: interval = (2687318.7419380397, 2705766.2418826967)
# 1274
# ┏┻┓
# 0 1
#
# --------------------
# tree 30: interval = (2705766.2418826967, 2722779.9918316603)
# 4947
# ┏┻┓
# 0 1
#
# --------------------
# tree 31: interval = (2722779.9918316603, 2730111.241809666)
# 4235
# ┏┻┓
# 0 1
#
# --------------------
# tree 32: interval = (2730111.241809666, 2740947.491777152)
# 2633
# ┏┻┓
# 0 1
#
# --------------------
# tree 33: interval = (2740947.491777152, 2742269.991773188)
# 4235
# ┏┻┓
# 0 1
#
# --------------------
# tree 34: interval = (2742269.991773188, 2742656.241772026)
# 2633
# ┏┻┓
# 0 1
#
# --------------------
# tree 35: interval = (2742656.241772026, 2754518.741736442)
# 2133
# ┏┻┓
# 0 1
#
# --------------------
# tree 36: interval = (2754518.741736442, 2759689.991720915)
# 2150
# ┏┻┓
# 0 1
#
# --------------------
# tree 37: interval = (2759689.991720915, 2782916.241651252)
# 2633
# ┏┻┓
# 0 1
#
# --------------------
# tree 38: interval = (2782916.241651252, 2792561.241622314)
# 5014
# ┏┻┓
# 0 1
#
# --------------------
# tree 39: interval = (2792561.241622314, 2858554.991424322)
# 2476
# ┏┻┓
# 0 1
#
# --------------------
# tree 40: interval = (2858554.991424322, 2966434.9911006987)
# 2288
# ┏┻┓
# 0 1
#
# --------------------
# tree 41: interval = (2966434.9911006987, 2968078.7410957515)
# 3456
# ┏┻┓
# 0 1
#
# --------------------
# tree 42: interval = (2968078.7410957515, 2983536.241049379)
# 2713
# ┏┻┓
# 0 1
#
# --------------------
# tree 43: interval = (2983536.241049379, 2983816.2410485446)
# 3456
# ┏┻┓
# 0 1
#
# --------------------
# tree 44: interval = (2983816.2410485446, 3008739.9909737706)
# 2165
# ┏┻┓
# 0 1
#
# --------------------
# tree 45: interval = (3008739.9909737706, 3018809.990943566)
# 2713
# ┏┻┓
# 0 1
#
# --------------------
# tree 46: interval = (3018809.990943566, 3029606.240911171)
# 1649
# ┏┻┓
# 0 1
#
# --------------------
# tree 47: interval = (3029606.240911171, 3045376.2408638746)
# 1274
# ┏┻┓
# 0 1
#
# --------------------
# tree 48: interval = (3045376.2408638746, 3048744.9908537716)
# 3456
# ┏┻┓
# 0 1
#
# --------------------
# tree 49: interval = (3048744.9908537716, 3063638.740809083)
# 4128
# ┏┻┓
# 0 1
#
# --------------------
# tree 50: interval = (3063638.740809083, 3092453.7407226264)
# 1649
# ┏┻┓
# 0 1
#
# --------------------
# tree 51: interval = (3092453.7407226264, 3099723.740700826)
# 69
# ┏┻┓
# 0 1
#
# --------------------
# tree 52: interval = (3099723.740700826, 3175326.2404740155)
# 1465
# ┏┻┓
# 0 1
#
# --------------------
# tree 53: interval = (3175326.2404740155, 3181767.4904547036)
# 5007
# ┏┻┓
# 0 1
#
# --------------------
# tree 54: interval = (3181767.4904547036, 3184888.7404453307)
# 4101
# ┏┻┓
# 0 1
#
# --------------------
# tree 55: interval = (3184888.7404453307, 3193328.7404199988)
# 997
# ┏┻┓
# 0 1
#
# --------------------
# tree 56: interval = (3193328.7404199988, 3195774.9904126823)
# 1918
# ┏┻┓
# 0 1
#
# --------------------
# tree 57: interval = (3195774.9904126823, 3268562.490194306)
# 1842
# ┏┻┓
# 0 1
#
# --------------------
# tree 58: interval = (3268562.490194306, 3283017.4901509434)
# 1918
# ┏┻┓
# 0 1
#
# --------------------
# tree 59: interval = (3283017.4901509434, 3347172.48995848)
# 1225
# ┏┻┓
# 0 1
#
# --------------------
# tree 60: interval = (3347172.48995848, 3440607.4896781743)
# 69
# ┏┻┓
# 0 1
#
# --------------------
# tree 61: interval = (3440607.4896781743, 3461699.989614889)
# 3347
# ┏┻┓
# 0 1
#
# --------------------
# tree 62: interval = (3461699.989614889, 3534524.989396423)
# 3959
# ┏┻┓
# 0 1
#
# --------------------
# tree 63: interval = (3534524.989396423, 3568511.2392944694)
# 3262
# ┏┻┓
# 0 1
#
# --------------------
# tree 64: interval = (3568511.2392944694, 3599562.4892013073)
# 2811
# ┏┻┓
# 0 1
#
# --------------------
# tree 65: interval = (3599562.4892013073, 3609482.4891715497)
# 3262
# ┏┻┓
# 0 1
#
# --------------------
# tree 66: interval = (3609482.4891715497, 3636136.23909159)
# 3654
# ┏┻┓
# 0 1
#
# --------------------
# tree 67: interval = (3636136.23909159, 3638797.489083603)
# 4235
# ┏┻┓
# 0 1
#
# --------------------
# tree 68: interval = (3638797.489083603, 3643366.239069894)
# 5058
# ┏┻┓
# 0 1
#
# --------------------
# tree 69: interval = (3643366.239069894, 3679573.7389612794)
# 4491
# ┏┻┓
# 0 1
#
# --------------------
# tree 70: interval = (3679573.7389612794, 3720341.2388389707)
# 1225
# ┏┻┓
# 0 1
#
# --------------------
# tree 71: interval = (3720341.2388389707, 3731189.9888064265)
# 2001
# ┏┻┓
# 0 1
#
# --------------------
# tree 72: interval = (3731189.9888064265, 3735236.238794282)
# 4253
# ┏┻┓
# 0 1
#
# --------------------
# tree 73: interval = (3735236.238794282, 3742157.4887735248)
# 3268
# ┏┻┓
# 0 1
#
# --------------------
# tree 74: interval = (3742157.4887735248, 3747733.7387567908)
# 242
# ┏┻┓
# 0 1
#
# --------------------
# tree 75: interval = (3747733.7387567908, 3753873.738738373)
# 1392
# ┏┻┓
# 0 1
#
# --------------------
# tree 76: interval = (3753873.738738373, 3761577.488715261)
# 2933
# ┏┻┓
# 0 1
#
# --------------------
# tree 77: interval = (3761577.488715261, 3917604.988247171)
# 561
# ┏┻┓
# 0 1
#
# --------------------
# tree 78: interval = (3917604.988247171, 4102457.4876926243)
# 515
# ┏┻┓
# 0 1
#
# --------------------
# tree 79: interval = (4102457.4876926243, 4113774.9876586795)
# 780
# ┏┻┓
# 0 1
#
# --------------------
# tree 80: interval = (4113774.9876586795, 4118297.4876451045)
# 1473
# ┏┻┓
# 0 1
#
# --------------------
# tree 81: interval = (4118297.4876451045, 4154936.2375351787)
# 1736
# ┏┻┓
# 0 1
#
# --------------------
# tree 82: interval = (4154936.2375351787, 4175381.2374738455)
# 561
# ┏┻┓
# 0 1
#
# --------------------
# tree 83: interval = (4175381.2374738455, 4175707.487472877)
# 2713
# ┏┻┓
# 0 1
#
# --------------------
# tree 84: interval = (4175707.487472877, 4213447.487359658)
# 635
# ┏┻┓
# 0 1
#
# --------------------
# tree 85: interval = (4213447.487359658, 4278242.487165272)
# 275
# ┏┻┓
# 0 1
#
# --------------------
# tree 86: interval = (4278242.487165272, 4510244.986469269)
# 238
# ┏┻┓
# 0 1
#
# --------------------
# tree 87: interval = (4510244.986469269, 4565067.48630479)
# 1044
# ┏┻┓
# 0 1
#
# --------------------
# tree 88: interval = (4565067.48630479, 4571253.736286238)
# 2050
# ┏┻┓
# 0 1
#
# --------------------
# tree 89: interval = (4571253.736286238, 4608169.986175492)
# 2539
# ┏┻┓
# 0 1
#
# --------------------
# tree 90: interval = (4608169.986175492, 4613539.986159369)
# 2632
# ┏┻┓
# 0 1
#
# --------------------
# tree 91: interval = (4613539.986159369, 4668853.73599343)
# 2437
# ┏┻┓
# 0 1
#
# --------------------
# tree 92: interval = (4668853.73599343, 4673602.4859791845)
# 1418
# ┏┻┓
# 0 1
#
# --------------------
# tree 93: interval = (4673602.4859791845, 4734024.985797927)
# 2632
# ┏┻┓
# 0 1
#
# --------------------
# tree 94: interval = (4734024.985797927, 4740183.735779449)
# 3363
# ┏┻┓
# 0 1
#
# --------------------
# tree 95: interval = (4740183.735779449, 4760936.235717192)
# 2632
# ┏┻┓
# 0 1
#
# --------------------
# tree 96: interval = (4760936.235717192, 4811711.235564858)
# 1515
# ┏┻┓
# 0 1
#
# --------------------
# tree 97: interval = (4811711.235564858, 4828656.23551403)
# 3121
# ┏┻┓
# 0 1
#
# --------------------
# tree 98: interval = (4828656.23551403, 4883758.735348716)
# 2883
# ┏┻┓
# 0 1
#
# --------------------
# tree 99: interval = (4883758.735348716, 4919357.48524192)
# 4199
# ┏┻┓
# 0 1
#
# --------------------
# tree 100: interval = (4919357.48524192, 4925506.235223472)
# 2883
# ┏┻┓
# 0 1
#
# --------------------
# tree 101: interval = (4925506.235223472, 4981964.985054091)
# 4199
# ┏┻┓
# 0 1
#
# --------------------
# tree 102: interval = (4981964.985054091, 4988171.235035479)
# 4924
# ┏┻┓
# 0 1
#
# --------------------
# tree 103: interval = (4988171.235035479, 4995783.7350126505)
# 4960
# ┏┻┓
# 0 1
#
# --------------------
# tree 104: interval = (4995783.7350126505, 5024844.984925464)
# 4938
# ┏┻┓
# 0 1
#
# --------------------
# tree 105: interval = (5024844.984925464, 5027118.734918639)
# 4959
# ┏┻┓
# 0 1
#
# --------------------
# tree 106: interval = (5027118.734918639, 5027634.984917089)
# 2437
# ┏┻┓
# 0 1
#
# --------------------
# tree 107: interval = (5027634.984917089, 5040614.984878153)
# 4959
# ┏┻┓
# 0 1
#
# --------------------
# tree 108: interval = (5040614.984878153, 5061173.734816477)
# 3551
# ┏┻┓
# 0 1
#
# --------------------
# tree 109: interval = (5061173.734816477, 5141266.2345761955)
# 1544
# ┏┻┓
# 0 1
#
# --------------------
# tree 110: interval = (5141266.2345761955, 5207487.484377533)
# 3551
# ┏┻┓
# 0 1
#
# --------------------
# tree 111: interval = (5207487.484377533, 5254536.234236389)
# 3427
# ┏┻┓
# 0 1
#
# --------------------
# tree 112: interval = (5254536.234236389, 5271877.484184369)
# 607
# ┏┻┓
# 0 1
#
# --------------------
# tree 113: interval = (5271877.484184369, 5277282.484168157)
# 3427
# ┏┻┓
# 0 1
#
# --------------------
# tree 114: interval = (5277282.484168157, 5281071.234156787)
# 3551
# ┏┻┓
# 0 1
#
# --------------------
# tree 115: interval = (5281071.234156787, 5285421.234143734)
# 3361
# ┏┻┓
# 0 1
#
# --------------------
# tree 116: interval = (5285421.234143734, 5313619.98405914)
# 3551
# ┏┻┓
# 0 1
#
# --------------------
# tree 117: interval = (5313619.98405914, 5316556.234050319)
# 3171
# ┏┻┓
# 0 1
#
# --------------------
# tree 118: interval = (5316556.234050319, 5320811.234037563)
# 4391
# ┏┻┓
# 0 1
#
# --------------------
# tree 119: interval = (5320811.234037563, 5339864.983980402)
# 3551
# ┏┻┓
# 0 1
#
# --------------------
# tree 120: interval = (5339864.983980402, 5356683.733929947)
# 3476
# ┏┻┓
# 0 1
#
# --------------------
# tree 121: interval = (5356683.733929947, 5359136.233922586)
# 657
# ┏┻┓
# 0 1
#
# --------------------
# tree 122: interval = (5359136.233922586, 5595384.983213842)
# 297
# ┏┻┓
# 0 1
#
# --------------------
# tree 123: interval = (5595384.983213842, 5596667.4832099825)
# 1391
# ┏┻┓
# 0 1
#
# --------------------
# tree 124: interval = (5596667.4832099825, 5626616.233120143)
# 4729
# ┏┻┓
# 0 1
#
# --------------------
# tree 125: interval = (5626616.233120143, 5633889.983098328)
# 2774
# ┏┻┓
# 0 1
#
# --------------------
# tree 126: interval = (5633889.983098328, 5647712.483056858)
# 4644
# ┏┻┓
# 0 1
#
# --------------------
# tree 127: interval = (5647712.483056858, 5663702.483008891)
# 4729
# ┏┻┓
# 0 1
#
# --------------------
# tree 128: interval = (5663702.483008891, 5700013.732899949)
# 2993
# ┏┻┓
# 0 1
#
# --------------------
# tree 129: interval = (5700013.732899949, 5701097.4828967005)
# 2841
# ┏┻┓
# 0 1
#
# --------------------
# tree 130: interval = (5701097.4828967005, 5704258.732887223)
# 4449
# ┏┻┓
# 0 1
#
# --------------------
# tree 131: interval = (5704258.732887223, 5732688.732801929)
# 3733
# ┏┻┓
# 0 1
#
# --------------------
# tree 132: interval = (5732688.732801929, 5743106.232770681)
# 2130
# ┏┻┓
# 0 1
#
# --------------------
# tree 133: interval = (5743106.232770681, 5745324.982764021)
# 3733
# ┏┻┓
# 0 1
#
# --------------------
# tree 134: interval = (5745324.982764021, 5783483.73264955)
# 2940
# ┏┻┓
# 0 1
#
# --------------------
# tree 135: interval = (5783483.73264955, 5815189.982554436)
# 2406
# ┏┻┓
# 0 1
#
# --------------------
# tree 136: interval = (5815189.982554436, 5816552.482550338)
# 884
# ┏┻┓
# 0 1
#
# --------------------
# tree 137: interval = (5816552.482550338, 5858611.23242417)
# 657
# ┏┻┓
# 0 1
#
# --------------------
# tree 138: interval = (5858611.23242417, 5899369.982301891)
# 646
# ┏┻┓
# 0 1
#
# --------------------
# tree 139: interval = (5899369.982301891, 6013057.481960818)
# 706
# ┏┻┓
# 0 1
#
# --------------------
# tree 140: interval = (6013057.481960818, 6145838.73156248)
# 657
# ┏┻┓
# 0 1
#
# --------------------
# tree 141: interval = (6145838.73156248, 6244661.231266007)
# 1079
# ┏┻┓
# 0 1
#
# --------------------
# tree 142: interval = (6244661.231266007, 6255343.731233954)
# 3223
# ┏┻┓
# 0 1
#
# --------------------
# tree 143: interval = (6255343.731233954, 6326364.981020898)
# 2479
# ┏┻┓
# 0 1
#
# --------------------
# tree 144: interval = (6326364.981020898, 6348037.480955884)
# 4575
# ┏┻┓
# 0 1
#
# --------------------
# tree 145: interval = (6348037.480955884, 6384699.980845898)
# 838
# ┏┻┓
# 0 1
#
# --------------------
# tree 146: interval = (6384699.980845898, 6398714.980803847)
# 2437
# ┏┻┓
# 0 1
#
# --------------------
# tree 147: interval = (6398714.980803847, 6451214.980646357)
# 2508
# ┏┻┓
# 0 1
#
# --------------------
# tree 148: interval = (6451214.980646357, 6451404.980645776)
# 2957
# ┏┻┓
# 0 1
#
# --------------------
# tree 149: interval = (6451404.980645776, 6453259.980640218)
# 2983
# ┏┻┓
# 0 1
#
# --------------------
# tree 150: interval = (6453259.980640218, 6469641.230591074)
# 3109
# ┏┻┓
# 0 1
#
# --------------------
# tree 151: interval = (6469641.230591074, 6562457.4803126305)
# 2983
# ┏┻┓
# 0 1
#
# --------------------
# tree 152: interval = (6562457.4803126305, 6576451.230270639)
# 2516
# ┏┻┓
# 0 1
#
# --------------------
# tree 153: interval = (6576451.230270639, 6581797.480254605)
# 2603
# ┏┻┓
# 0 1
#
# --------------------
# tree 154: interval = (6581797.480254605, 6615976.2301520705)
# 1596
# ┏┻┓
# 0 1
#
# --------------------
# tree 155: interval = (6615976.2301520705, 7020421.228938729)
# 580
# ┏┻┓
# 0 1
#
# --------------------
# tree 156: interval = (7020421.228938729, 7039852.478880435)
# 2451
# ┏┻┓
# 0 1
#
# --------------------
# tree 157: interval = (7039852.478880435, 7046324.978861019)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 158: interval = (7046324.978861019, 7057779.978826657)
# 2666
# ┏┻┓
# 0 1
#
# --------------------
# tree 159: interval = (7057779.978826657, 7087224.978738323)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 160: interval = (7087224.978738323, 7088003.728735983)
# 2306
# ┏┻┓
# 0 1
#
# --------------------
# tree 161: interval = (7088003.728735983, 7104243.728687257)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 162: interval = (7104243.728687257, 7117299.978648096)
# 2306
# ┏┻┓
# 0 1
#
# --------------------
# tree 163: interval = (7117299.978648096, 7120251.22863923)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 164: interval = (7120251.22863923, 7121151.228636548)
# 2306
# ┏┻┓
# 0 1
#
# --------------------
# tree 165: interval = (7121151.228636548, 7145272.478564173)
# 2282
# ┏┻┓
# 0 1
#
# --------------------
# tree 166: interval = (7145272.478564173, 7170214.978489354)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 167: interval = (7170214.978489354, 7170309.978489056)
# 3896
# ┏┻┓
# 0 1
#
# --------------------
# tree 168: interval = (7170309.978489056, 7172921.228481233)
# 3761
# ┏┻┓
# 0 1
#
# --------------------
# tree 169: interval = (7172921.228481233, 7183918.728448242)
# 2435
# ┏┻┓
# 0 1
#
# --------------------
# tree 170: interval = (7183918.728448242, 7200821.228397533)
# 2818
# ┏┻┓
# 0 1
#
# --------------------
# tree 171: interval = (7200821.228397533, 7380158.727859512)
# 136
# ┏┻┓
# 0 1
#
# --------------------
# tree 172: interval = (7380158.727859512, 7382638.727852076)
# 4228
# ┏┻┓
# 0 1
#
# --------------------
# tree 173: interval = (7382638.727852076, 7386969.9778390825)
# 4132
# ┏┻┓
# 0 1
#
# --------------------
# tree 174: interval = (7386969.9778390825, 7405694.97778292)
# 4980
# ┏┻┓
# 0 1
#
# --------------------
# tree 175: interval = (7405694.97778292, 7424149.977727547)
# 4987
# ┏┻┓
# 0 1
#
# --------------------
# tree 176: interval = (7424149.977727547, 7434781.227695644)
# 3896
# ┏┻┓
# 0 1
#
# --------------------
# tree 177: interval = (7434781.227695644, 7450426.22764872)
# 4132
# ┏┻┓
# 0 1
#
# --------------------
# tree 178: interval = (7450426.22764872, 7485656.227543026)
# 4228
# ┏┻┓
# 0 1
#
# --------------------
# tree 179: interval = (7485656.227543026, 7512183.727463439)
# 3605
# ┏┻┓
# 0 1
#
# --------------------
# tree 180: interval = (7512183.727463439, 7519148.727442548)
# 4228
# ┏┻┓
# 0 1
#
# --------------------
# tree 181: interval = (7519148.727442548, 7550162.477349505)
# 4492
# ┏┻┓
# 0 1
#
# --------------------
# tree 182: interval = (7550162.477349505, 7554786.227335632)
# 4671
# ┏┻┓
# 0 1
#
# --------------------
# tree 183: interval = (7554786.227335632, 7651237.477046281)
# 388
# ┏┻┓
# 0 1
#
# --------------------
# tree 184: interval = (7651237.477046281, 7687308.726938069)
# 774
# ┏┻┓
# 0 1
#
# --------------------
# tree 185: interval = (7687308.726938069, 7697879.976906359)
# 4195
# ┏┻┓
# 0 1
#
# --------------------
# tree 186: interval = (7697879.976906359, 7701657.476895019)
# 3943
# ┏┻┓
# 0 1
#
# --------------------
# tree 187: interval = (7701657.476895019, 7707239.9768782705)
# 2939
# ┏┻┓
# 0 1
#
# --------------------
# tree 188: interval = (7707239.9768782705, 7716641.226850063)
# 3943
# ┏┻┓
# 0 1
#
# --------------------
# tree 189: interval = (7716641.226850063, 7730758.726807728)
# 1419
# ┏┻┓
# 0 1
#
# --------------------
# tree 190: interval = (7730758.726807728, 7752661.226742014)
# 4195
# ┏┻┓
# 0 1
#
# --------------------
# tree 191: interval = (7752661.226742014, 7767977.476696059)
# 1730
# ┏┻┓
# 0 1
#
# --------------------
# tree 192: interval = (7767977.476696059, 7782291.226653129)
# 2884
# ┏┻┓
# 0 1
#
# --------------------
# tree 193: interval = (7782291.226653129, 7788191.226635411)
# 2952
# ┏┻┓
# 0 1
#
# --------------------
# tree 194: interval = (7788191.226635411, 7793934.976618201)
# 1615
# ┏┻┓
# 0 1
#
# --------------------
# tree 195: interval = (7793934.976618201, 7801946.22659415)
# 4727
# ┏┻┓
# 0 1
#
# --------------------
# tree 196: interval = (7801946.22659415, 7806218.72658135)
# 2952
# ┏┻┓
# 0 1
#
# --------------------
# tree 197: interval = (7806218.72658135, 7936833.726189494)
# 2669
# ┏┻┓
# 0 1
#
# --------------------
# tree 198: interval = (7936833.726189494, 8052253.725843236)
# 198
# ┏┻┓
# 0 1
#
# --------------------
# tree 199: interval = (8052253.725843236, 8053918.725838244)
# 5061
# ┏┻┓
# 0 1
#
# --------------------
# tree 200: interval = (8053918.725838244, 8054502.475836486)
# 5209
# ┏┻┓
# 0 1
#
# --------------------
# tree 201: interval = (8054502.475836486, 8066503.725800484)
# 4980
# ┏┻┓
# 0 1
#
# --------------------
# tree 202: interval = (8066503.725800484, 8216581.225350261)
# 802
# ┏┻┓
# 0 1
#
# --------------------
# tree 203: interval = (8216581.225350261, 8275864.9751724005)
# 198
# ┏┻┓
# 0 1
#
# --------------------
# tree 204: interval = (8275864.9751724005, 8277772.475166678)
# 802
# ┏┻┓
# 0 1
#
# --------------------
# tree 205: interval = (8277772.475166678, 8301081.225096762)
# 583
# ┏┻┓
# 0 1
#
# --------------------
# tree 206: interval = (8301081.225096762, 8313769.97505869)
# 2742
# ┏┻┓
# 0 1
#
# --------------------
# tree 207: interval = (8313769.97505869, 8316869.975049391)
# 583
# ┏┻┓
# 0 1
#
# --------------------
# tree 208: interval = (8316869.975049391, 8319049.97504285)
# 802
# ┏┻┓
# 0 1
#
# --------------------
# tree 209: interval = (8319049.97504285, 8399528.724801406)
# 956
# ┏┻┓
# 0 1
#
# --------------------
# tree 210: interval = (8399528.724801406, 8406451.224780634)
# 3579
# ┏┻┓
# 0 1
#
# --------------------
# tree 211: interval = (8406451.224780634, 8410233.724769294)
# 4399
# ┏┻┓
# 0 1
#
# --------------------
# tree 212: interval = (8410233.724769294, 8415847.474752456)
# 4630
# ┏┻┓
# 0 1
#
# --------------------
# tree 213: interval = (8415847.474752456, 8456287.47463113)
# 4575
# ┏┻┓
# 0 1
#
# --------------------
# tree 214: interval = (8456287.47463113, 8500721.224497825)
# 1122
# ┏┻┓
# 0 1
#
# --------------------
# tree 215: interval = (8500721.224497825, 8650111.224049658)
# 1893
# ┏┻┓
# 0 1
#
# --------------------
# tree 216: interval = (8650111.224049658, 8670132.473989591)
# 2432
# ┏┻┓
# 0 1
#
# --------------------
# tree 217: interval = (8670132.473989591, 8678303.723965079)
# 3584
# ┏┻┓
# 0 1
#
# --------------------
# tree 218: interval = (8678303.723965079, 8694581.223916247)
# 2432
# ┏┻┓
# 0 1
#
# --------------------
# tree 219: interval = (8694581.223916247, 8709031.2238729)
# 2737
# ┏┻┓
# 0 1
#
# --------------------
# tree 220: interval = (8709031.2238729, 8742903.723771289)
# 2927
# ┏┻┓
# 0 1
#
# --------------------
# tree 221: interval = (8742903.723771289, 8775467.473673582)
# 4489
# ┏┻┓
# 0 1
#
# --------------------
# tree 222: interval = (8775467.473673582, 8784522.473646417)
# 3358
# ┏┻┓
# 0 1
#
# --------------------
# tree 223: interval = (8784522.473646417, 8787748.723636746)
# 4489
# ┏┻┓
# 0 1
#
# --------------------
# tree 224: interval = (8787748.723636746, 8803941.223588169)
# 4506
# ┏┻┓
# 0 1
#
# --------------------
# tree 225: interval = (8803941.223588169, 8808661.223574013)
# 4004
# ┏┻┓
# 0 1
#
# --------------------
# tree 226: interval = (8808661.223574013, 8810753.72356774)
# 4506
# ┏┻┓
# 0 1
#
# --------------------
# tree 227: interval = (8810753.72356774, 8819598.7235412)
# 4586
# ┏┻┓
# 0 1
#
# --------------------
# tree 228: interval = (8819598.7235412, 8830968.723507091)
# 4941
# ┏┻┓
# 0 1
#
# --------------------
# tree 229: interval = (8830968.723507091, 8833634.97349909)
# 3441
# ┏┻┓
# 0 1
#
# --------------------
# tree 230: interval = (8833634.97349909, 8926511.223220468)
# 767
# ┏┻┓
# 0 1
#
# --------------------
# tree 231: interval = (8926511.223220468, 8960133.723119602)
# 2923
# ┏┻┓
# 0 1
#
# --------------------
# tree 232: interval = (8960133.723119602, 8987098.723038703)
# 4982
# ┏┻┓
# 0 1
#
# --------------------
# tree 233: interval = (8987098.723038703, 8987716.223036855)
# 795
# ┏┻┓
# 0 1
#
# --------------------
# tree 234: interval = (8987716.223036855, 9052301.222843096)
# 270
# ┏┻┓
# 0 1
#
# --------------------
# tree 235: interval = (9052301.222843096, 9060011.222819954)
# 5193
# ┏┻┓
# 0 1
#
# --------------------
# tree 236: interval = (9060011.222819954, 9080764.972757697)
# 5151
# ┏┻┓
# 0 1
#
# --------------------
# tree 237: interval = (9080764.972757697, 9087453.72273764)
# 3285
# ┏┻┓
# 0 1
#
# --------------------
# tree 238: interval = (9087453.72273764, 9093296.222720116)
# 2575
# ┏┻┓
# 0 1
#
# --------------------
# tree 239: interval = (9093296.222720116, 9104498.7226865)
# 4004
# ┏┻┓
# 0 1
#
# --------------------
# tree 240: interval = (9104498.7226865, 9112219.972663328)
# 3532
# ┏┻┓
# 0 1
#
# --------------------
# tree 241: interval = (9112219.972663328, 9141909.972574264)
# 3483
# ┏┻┓
# 0 1
#
# --------------------
# tree 242: interval = (9141909.972574264, 9143948.722568154)
# 5184
# ┏┻┓
# 0 1
#
# --------------------
# tree 243: interval = (9143948.722568154, 9149103.722552687)
# 4670
# ┏┻┓
# 0 1
#
# --------------------
# tree 244: interval = (9149103.722552687, 9151946.222544163)
# 1190
# ┏┻┓
# 0 1
#
# --------------------
# tree 245: interval = (9151946.222544163, 9197337.472407982)
# 1150
# ┏┻┓
# 0 1
#
# --------------------
# tree 246: interval = (9197337.472407982, 9233301.222300097)
# 1190
# ┏┻┓
# 0 1
#
# --------------------
# tree 247: interval = (9233301.222300097, 9395927.471812218)
# 1127
# ┏┻┓
# 0 1
#
# --------------------
# tree 248: interval = (9395927.471812218, 9408477.471774563)
# 820
# ┏┻┓
# 0 1
#
# --------------------
# tree 249: interval = (9408477.471774563, 9477193.72156842)
# 406
# ┏┻┓
# 0 1
#
# --------------------
# tree 250: interval = (9477193.72156842, 9483094.971550703)
# 3564
# ┏┻┓
# 0 1
#
# --------------------
# tree 251: interval = (9483094.971550703, 9497384.971507847)
# 1820
# ┏┻┓
# 0 1
#
# --------------------
# tree 252: interval = (9497384.971507847, 9526071.221421778)
# 1662
# ┏┻┓
# 0 1
#
# --------------------
# tree 253: interval = (9526071.221421778, 9585129.971244603)
# 670
# ┏┻┓
# 0 1
#
# --------------------
# tree 254: interval = (9585129.971244603, 9586407.471240774)
# 820
# ┏┻┓
# 0 1
#
# --------------------
# tree 255: interval = (9586407.471240774, 9609074.971172765)
# 499
# ┏┻┓
# 0 1
#
# --------------------
# tree 256: interval = (9609074.971172765, 9622487.471132532)
# 2046
# ┏┻┓
# 0 1
#
# --------------------
# tree 257: interval = (9622487.471132532, 9675842.470972463)
# 1150
# ┏┻┓
# 0 1
#
# --------------------
# tree 258: interval = (9675842.470972463, 9741987.47077404)
# 2046
# ┏┻┓
# 0 1
#
# --------------------
# tree 259: interval = (9741987.47077404, 9920762.470237702)
# 1585
# ┏┻┓
# 0 1
#
# --------------------
# tree 260: interval = (9920762.470237702, 9934851.220195442)
# 3060
# ┏┻┓
# 0 1
#
# --------------------
# tree 261: interval = (9934851.220195442, 9935026.22019492)
# 4148
# ┏┻┓
# 0 1
#
# --------------------
# tree 262: interval = (9935026.22019492, 9938562.470184311)
# 4385
# ┏┻┓
# 0 1
#
# --------------------
# tree 263: interval = (9938562.470184311, 10044341.219866976)
# 1854
# ┏┻┓
# 0 1
#
# --------------------
# tree 264: interval = (10044341.219866976, 10060861.219817415)
# 1713
# ┏┻┓
# 0 1
#
# --------------------
# tree 265: interval = (10060861.219817415, 10099311.219702065)
# 2107
# ┏┻┓
# 0 1
#
# --------------------
# tree 266: interval = (10099311.219702065, 10106753.719679728)
# 4399
# ┏┻┓
# 0 1
#
# --------------------
# tree 267: interval = (10106753.719679728, 10114931.2196552)
# 4876
# ┏┻┓
# 0 1
#
# --------------------
# tree 268: interval = (10114931.2196552, 10118697.469643906)
# 4086
# ┏┻┓
# 0 1
#
# --------------------
# tree 269: interval = (10118697.469643906, 10129796.219610602)
# 2107
# ┏┻┓
# 0 1
#
# --------------------
# tree 270: interval = (10129796.219610602, 10133501.219599485)
# 2639
# ┏┻┓
# 0 1
#
# --------------------
# tree 271: interval = (10133501.219599485, 10172366.219482899)
# 3060
# ┏┻┓
# 0 1
#
# --------------------
# tree 272: interval = (10172366.219482899, 10400128.718799606)
# 559
# ┏┻┓
# 0 1
#
# --------------------
# tree 273: interval = (10400128.718799606, 10461258.718616217)
# 254
# ┏┻┓
# 0 1
#
# --------------------
# tree 274: interval = (10461258.718616217, 10466289.968601122)
# 2821
# ┏┻┓
# 0 1
#
# --------------------
# tree 275: interval = (10466289.968601122, 10476268.718571186)
# 3060
# ┏┻┓
# 0 1
#
# --------------------
# tree 276: interval = (10476268.718571186, 10494162.468517512)
# 3270
# ┏┻┓
# 0 1
#
# --------------------
# tree 277: interval = (10494162.468517512, 10503661.218489006)
# 2260
# ┏┻┓
# 0 1
#
# --------------------
# tree 278: interval = (10503661.218489006, 10555194.968334407)
# 3270
# ┏┻┓
# 0 1
#
# --------------------
# tree 279: interval = (10555194.968334407, 10576221.21827133)
# 4124
# ┏┻┓
# 0 1
#
# --------------------
# tree 280: interval = (10576221.21827133, 10576999.96826899)
# 2716
# ┏┻┓
# 0 1
#
# --------------------
# tree 281: interval = (10576999.96826899, 10592083.71822375)
# 4124
# ┏┻┓
# 0 1
#
# --------------------
# tree 282: interval = (10592083.71822375, 10594378.718216866)
# 727
# ┏┻┓
# 0 1
#
# --------------------
# tree 283: interval = (10594378.718216866, 10711192.46786642)
# 785
# ┏┻┓
# 0 1
#
# --------------------
# tree 284: interval = (10711192.46786642, 10718596.217844203)
# 2821
# ┏┻┓
# 0 1
#
# --------------------
# tree 285: interval = (10718596.217844203, 10754379.967736855)
# 2610
# ┏┻┓
# 0 1
#
# --------------------
# tree 286: interval = (10754379.967736855, 10757771.217726678)
# 1925
# ┏┻┓
# 0 1
#
# --------------------
# tree 287: interval = (10757771.217726678, 10801273.717596173)
# 2610
# ┏┻┓
# 0 1
#
# --------------------
# tree 288: interval = (10801273.717596173, 10986497.467040509)
# 115
# ┏┻┓
# 0 1
#
# --------------------
# tree 289: interval = (10986497.467040509, 11084006.216747984)
# 2949
# ┏┻┓
# 0 1
#
# --------------------
# tree 290: interval = (11084006.216747984, 11114544.966656372)
# 3819
# ┏┻┓
# 0 1
#
# --------------------
# tree 291: interval = (11114544.966656372, 11116848.716649443)
# 5074
# ┏┻┓
# 0 1
#
# --------------------
# tree 292: interval = (11116848.716649443, 11119868.716640383)
# 4803
# ┏┻┓
# 0 1
#
# --------------------
# tree 293: interval = (11119868.716640383, 11135148.716594547)
# 434
# ┏┻┓
# 0 1
#
# --------------------
# tree 294: interval = (11135148.716594547, 11168327.466495022)
# 1904
# ┏┻┓
# 0 1
#
# --------------------
# tree 295: interval = (11168327.466495022, 11175796.21647261)
# 4606
# ┏┻┓
# 0 1
#
# --------------------
# tree 296: interval = (11175796.21647261, 11223511.216329455)
# 1893
# ┏┻┓
# 0 1
#
# --------------------
# tree 297: interval = (11223511.216329455, 11228638.716314077)
# 4309
# ┏┻┓
# 0 1
#
# --------------------
# tree 298: interval = (11228638.716314077, 11232351.216302946)
# 4315
# ┏┻┓
# 0 1
#
# --------------------
# tree 299: interval = (11232351.216302946, 11234323.716297016)
# 5295
# ┏┻┓
# 0 1
#
# --------------------
# tree 300: interval = (11234323.716297016, 11243299.966270104)
# 5318
# ┏┻┓
# 0 1
#
# --------------------
# tree 301: interval = (11243299.966270104, 11253421.216239735)
# 3493
# ┏┻┓
# 0 1
#
# --------------------
# tree 302: interval = (11253421.216239735, 11261638.716215074)
# 1453
# ┏┻┓
# 0 1
#
# --------------------
# tree 303: interval = (11261638.716215074, 11262696.2162119)
# 3493
# ┏┻┓
# 0 1
#
# --------------------
# tree 304: interval = (11262696.2162119, 11263941.216208175)
# 3417
# ┏┻┓
# 0 1
#
# --------------------
# tree 305: interval = (11263941.216208175, 11383123.715850621)
# 825
# ┏┻┓
# 0 1
#
# --------------------
# tree 306: interval = (11383123.715850621, 11384276.215847164)
# 3774
# ┏┻┓
# 0 1
#
# --------------------
# tree 307: interval = (11384276.215847164, 11418687.46574393)
# 2149
# ┏┻┓
# 0 1
#
# --------------------
# tree 308: interval = (11418687.46574393, 11464266.215607196)
# 2880
# ┏┻┓
# 0 1
#
# --------------------
# tree 309: interval = (11464266.215607196, 11466541.215600371)
# 2916
# ┏┻┓
# 0 1
#
# --------------------
# tree 310: interval = (11466541.215600371, 11523152.465430543)
# 1752
# ┏┻┓
# 0 1
#
# --------------------
# tree 311: interval = (11523152.465430543, 11547801.215356588)
# 2387
# ┏┻┓
# 0 1
#
# --------------------
# tree 312: interval = (11547801.215356588, 11699977.464900061)
# 528
# ┏┻┓
# 0 1
#
# --------------------
# tree 313: interval = (11699977.464900061, 11703382.464889854)
# 5292
# ┏┻┓
# 0 1
#
# --------------------
# tree 314: interval = (11703382.464889854, 11720413.714838758)
# 5039
# ┏┻┓
# 0 1
#
# --------------------
# tree 315: interval = (11720413.714838758, 11758843.714723468)
# 4279
# ┏┻┓
# 0 1
#
# --------------------
# tree 316: interval = (11758843.714723468, 11831438.714505672)
# 3703
# ┏┻┓
# 0 1
#
# --------------------
# tree 317: interval = (11831438.714505672, 11848001.214455992)
# 2372
# ┏┻┓
# 0 1
#
# --------------------
# tree 318: interval = (11848001.214455992, 11876156.214371532)
# 1096
# ┏┻┓
# 0 1
#
# --------------------
# tree 319: interval = (11876156.214371532, 11915342.464253977)
# 1916
# ┏┻┓
# 0 1
#
# --------------------
# tree 320: interval = (11915342.464253977, 11940392.464178815)
# 2253
# ┏┻┓
# 0 1
#
# --------------------
# tree 321: interval = (11940392.464178815, 11946036.214161888)
# 1162
# ┏┻┓
# 0 1
#
# --------------------
# tree 322: interval = (11946036.214161888, 11981286.214056134)
# 1096
# ┏┻┓
# 0 1
#
# --------------------
# tree 323: interval = (11981286.214056134, 12113851.213658437)
# 171
# ┏┻┓
# 0 1
#
# --------------------
# tree 324: interval = (12113851.213658437, 12183031.213450894)
# 743
# ┏┻┓
# 0 1
#
# --------------------
# tree 325: interval = (12183031.213450894, 12188677.463433966)
# 2029
# ┏┻┓
# 0 1
#
# --------------------
# tree 326: interval = (12188677.463433966, 12211411.213365763)
# 950
# ┏┻┓
# 0 1
#
# --------------------
# tree 327: interval = (12211411.213365763, 12246584.963260233)
# 2029
# ┏┻┓
# 0 1
#
# --------------------
# tree 328: interval = (12246584.963260233, 12292912.463121265)
# 3774
# ┏┻┓
# 0 1
#
# --------------------
# tree 329: interval = (12292912.463121265, 12339252.462982237)
# 4787
# ┏┻┓
# 0 1
#
# --------------------
# tree 330: interval = (12339252.462982237, 12352219.962943345)
# 4551
# ┏┻┓
# 0 1
#
# --------------------
# tree 331: interval = (12352219.962943345, 12382607.46285218)
# 4337
# ┏┻┓
# 0 1
#
# --------------------
# tree 332: interval = (12382607.46285218, 12391993.712824017)
# 4551
# ┏┻┓
# 0 1
#
# --------------------
# tree 333: interval = (12391993.712824017, 12424427.462726712)
# 3683
# ┏┻┓
# 0 1
#
# --------------------
# tree 334: interval = (12424427.462726712, 12432207.462703377)
# 4504
# ┏┻┓
# 0 1
#
# --------------------
# tree 335: interval = (12432207.462703377, 12448942.462653175)
# 2581
# ┏┻┓
# 0 1
#
# --------------------
# tree 336: interval = (12448942.462653175, 12471101.2125867)
# 459
# ┏┻┓
# 0 1
#
# --------------------
# tree 337: interval = (12471101.2125867, 12559282.462322146)
# 545
# ┏┻┓
# 0 1
#
# --------------------
# tree 338: interval = (12559282.462322146, 12567252.46229823)
# 3583
# ┏┻┓
# 0 1
#
# --------------------
# tree 339: interval = (12567252.46229823, 12614703.712155893)
# 3774
# ┏┻┓
# 0 1
#
# --------------------
# tree 340: interval = (12614703.712155893, 12655381.212033853)
# 3952
# ┏┻┓
# 0 1
#
# --------------------
# tree 341: interval = (12655381.212033853, 12660093.712019712)
# 2692
# ┏┻┓
# 0 1
#
# --------------------
# tree 342: interval = (12660093.712019712, 12687973.711936086)
# 643
# ┏┻┓
# 0 1
#
# --------------------
# tree 343: interval = (12687973.711936086, 12783364.961649895)
# 585
# ┏┻┓
# 0 1
#
# --------------------
# tree 344: interval = (12783364.961649895, 12795897.461612314)
# 3254
# ┏┻┓
# 0 1
#
# --------------------
# tree 345: interval = (12795897.461612314, 12807206.211578384)
# 2692
# ┏┻┓
# 0 1
#
# --------------------
# tree 346: interval = (12807206.211578384, 12868968.711393088)
# 3254
# ┏┻┓
# 0 1
#
# --------------------
# tree 347: interval = (12868968.711393088, 12876557.46137032)
# 3015
# ┏┻┓
# 0 1
#
# --------------------
# tree 348: interval = (12876557.46137032, 12878488.711364523)
# 4508
# ┏┻┓
# 0 1
#
# --------------------
# tree 349: interval = (12878488.711364523, 12904782.46128565)
# 4541
# ┏┻┓
# 0 1
#
# --------------------
# tree 350: interval = (12904782.46128565, 12942874.961171359)
# 2969
# ┏┻┓
# 0 1
#
# --------------------
# tree 351: interval = (12942874.961171359, 12961427.461115718)
# 2203
# ┏┻┓
# 0 1
#
# --------------------
# tree 352: interval = (12961427.461115718, 12982656.21105203)
# 3248
# ┏┻┓
# 0 1
#
# --------------------
# tree 353: interval = (12982656.21105203, 13047441.210857674)
# 2373
# ┏┻┓
# 0 1
#
# --------------------
# tree 354: interval = (13047441.210857674, 13072666.210781991)
# 120
# ┏┻┓
# 0 1
#
# --------------------
# tree 355: interval = (13072666.210781991, 13344003.709967986)
# 63
# ┏┻┓
# 0 1
#
# --------------------
# tree 356: interval = (13344003.709967986, 13528601.209414184)
# 155
# ┏┻┓
# 0 1
#
# --------------------
# tree 357: interval = (13528601.209414184, 13580098.709259704)
# 599
# ┏┻┓
# 0 1
#
# --------------------
# tree 358: interval = (13580098.709259704, 13615071.209154785)
# 3426
# ┏┻┓
# 0 1
#
# --------------------
# tree 359: interval = (13615071.209154785, 13659031.20902291)
# 2616
# ┏┻┓
# 0 1
#
# --------------------
# tree 360: interval = (13659031.20902291, 13668749.958993748)
# 4517
# ┏┻┓
# 0 1
#
# --------------------
# tree 361: interval = (13668749.958993748, 13680059.958959818)
# 4553
# ┏┻┓
# 0 1
#
# --------------------
# tree 362: interval = (13680059.958959818, 13680696.20895791)
# 3627
# ┏┻┓
# 0 1
#
# --------------------
# tree 363: interval = (13680696.20895791, 13705292.45888412)
# 2402
# ┏┻┓
# 0 1
#
# --------------------
# tree 364: interval = (13705292.45888412, 13707132.458878592)
# 3627
# ┏┻┓
# 0 1
#
# --------------------
# tree 365: interval = (13707132.458878592, 13708416.208874747)
# 4553
# ┏┻┓
# 0 1
#
# --------------------
# tree 366: interval = (13708416.208874747, 13711291.20886612)
# 2551
# ┏┻┓
# 0 1
#
# --------------------
# tree 367: interval = (13711291.20886612, 13726104.958821684)
# 5052
# ┏┻┓
# 0 1
#
# --------------------
# tree 368: interval = (13726104.958821684, 13728039.958815888)
# 4948
# ┏┻┓
# 0 1
#
# --------------------
# tree 369: interval = (13728039.958815888, 13730082.458809748)
# 4976
# ┏┻┓
# 0 1
#
# --------------------
# tree 370: interval = (13730082.458809748, 13745188.708764434)
# 4848
# ┏┻┓
# 0 1
#
# --------------------
# tree 371: interval = (13745188.708764434, 13778071.208665788)
# 4422
# ┏┻┓
# 0 1
#
# --------------------
# tree 372: interval = (13778071.208665788, 13782106.208653674)
# 4976
# ┏┻┓
# 0 1
#
# --------------------
# tree 373: interval = (13782106.208653674, 13808312.45857507)
# 3998
# ┏┻┓
# 0 1
#
# --------------------
# tree 374: interval = (13808312.45857507, 13816306.208551079)
# 4659
# ┏┻┓
# 0 1
#
# --------------------
# tree 375: interval = (13816306.208551079, 13850799.95844759)
# 1807
# ┏┻┓
# 0 1
#
# --------------------
# tree 376: interval = (13850799.95844759, 13856354.958430931)
# 2616
# ┏┻┓
# 0 1
#
# --------------------
# tree 377: interval = (13856354.958430931, 13859537.45842138)
# 4460
# ┏┻┓
# 0 1
#
# --------------------
# tree 378: interval = (13859537.45842138, 13903588.708289236)
# 1816
# ┏┻┓
# 0 1
#
# --------------------
# tree 379: interval = (13903588.708289236, 13918707.458243877)
# 3011
# ┏┻┓
# 0 1
#
# --------------------
# tree 380: interval = (13918707.458243877, 13935242.45819427)
# 1513
# ┏┻┓
# 0 1
#
# --------------------
# tree 381: interval = (13935242.45819427, 13940568.708178282)
# 2591
# ┏┻┓
# 0 1
#
# --------------------
# tree 382: interval = (13940568.708178282, 13952303.708143085)
# 1513
# ┏┻┓
# 0 1
#
# --------------------
# tree 383: interval = (13952303.708143085, 13969397.458091795)
# 2431
# ┏┻┓
# 0 1
#
# --------------------
# tree 384: interval = (13969397.458091795, 14014407.457956776)
# 1513
# ┏┻┓
# 0 1
#
# --------------------
# tree 385: interval = (14014407.457956776, 14017127.45794861)
# 2460
# ┏┻┓
# 0 1
#
# --------------------
# tree 386: interval = (14017127.45794861, 14099462.457701609)
# 1513
# ┏┻┓
# 0 1
#
# --------------------
# tree 387: interval = (14099462.457701609, 14132259.957603216)
# 2473
# ┏┻┓
# 0 1
#
# --------------------
# tree 388: interval = (14132259.957603216, 14153897.457538307)
# 3484
# ┏┻┓
# 0 1
#
# --------------------
# tree 389: interval = (14153897.457538307, 14172919.957481235)
# 3635
# ┏┻┓
# 0 1
#
# --------------------
# tree 390: interval = (14172919.957481235, 14180063.707459807)
# 3484
# ┏┻┓
# 0 1
#
# --------------------
# tree 391: interval = (14180063.707459807, 14199142.457402572)
# 1759
# ┏┻┓
# 0 1
#
# --------------------
# tree 392: interval = (14199142.457402572, 14211432.457365692)
# 2019
# ┏┻┓
# 0 1
#
# --------------------
# tree 393: interval = (14211432.457365692, 14245059.95726481)
# 1086
# ┏┻┓
# 0 1
#
# --------------------
# tree 394: interval = (14245059.95726481, 14260721.207217842)
# 140
# ┏┻┓
# 0 1
#
# --------------------
# tree 395: interval = (14260721.207217842, 14281098.707156703)
# 2250
# ┏┻┓
# 0 1
#
# --------------------
# tree 396: interval = (14281098.707156703, 14284199.957147405)
# 3930
# ┏┻┓
# 0 1
#
# --------------------
# tree 397: interval = (14284199.957147405, 14287327.457138017)
# 3426
# ┏┻┓
# 0 1
#
# --------------------
# tree 398: interval = (14287327.457138017, 14305479.957083553)
# 3635
# ┏┻┓
# 0 1
#
# --------------------
# tree 399: interval = (14305479.957083553, 14316836.207049489)
# 998
# ┏┻┓
# 0 1
#
# --------------------
# tree 400: interval = (14316836.207049489, 14320837.457037494)
# 1433
# ┏┻┓
# 0 1
#
# --------------------
# tree 401: interval = (14320837.457037494, 14331781.207004651)
# 3635
# ┏┻┓
# 0 1
#
# --------------------
# tree 402: interval = (14331781.207004651, 14336679.956989959)
# 1893
# ┏┻┓
# 0 1
#
# --------------------
# tree 403: interval = (14336679.956989959, 14349486.206951544)
# 1723
# ┏┻┓
# 0 1
#
# --------------------
# tree 404: interval = (14349486.206951544, 14383318.706850037)
# 3635
# ┏┻┓
# 0 1
#
# --------------------
# tree 405: interval = (14383318.706850037, 14400652.456798047)
# 2710
# ┏┻┓
# 0 1
#
# --------------------
# tree 406: interval = (14400652.456798047, 14401923.706794217)
# 3484
# ┏┻┓
# 0 1
#
# --------------------
# tree 407: interval = (14401923.706794217, 14467607.456597164)
# 3274
# ┏┻┓
# 0 1
#
# --------------------
# tree 408: interval = (14467607.456597164, 14476892.456569314)
# 3529
# ┏┻┓
# 0 1
#
# --------------------
# tree 409: interval = (14476892.456569314, 14491727.45652482)
# 3219
# ┏┻┓
# 0 1
#
# --------------------
# tree 410: interval = (14491727.45652482, 14517782.456446663)
# 3696
# ┏┻┓
# 0 1
#
# --------------------
# tree 411: interval = (14517782.456446663, 14521891.206434324)
# 2250
# ┏┻┓
# 0 1
#
# --------------------
# tree 412: interval = (14521891.206434324, 14556667.456329986)
# 3696
# ┏┻┓
# 0 1
#
# --------------------
# tree 413: interval = (14556667.456329986, 14741688.705774933)
# 1365
# ┏┻┓
# 0 1
#
# --------------------
# tree 414: interval = (14741688.705774933, 14787356.205637932)
# 705
# ┏┻┓
# 0 1
#
# --------------------
# tree 415: interval = (14787356.205637932, 14789552.45563133)
# 4009
# ┏┻┓
# 0 1
#
# --------------------
# tree 416: interval = (14789552.45563133, 14793003.70562099)
# 3847
# ┏┻┓
# 0 1
#
# --------------------
# tree 417: interval = (14793003.70562099, 14803092.455590725)
# 4009
# ┏┻┓
# 0 1
#
# --------------------
# tree 418: interval = (14803092.455590725, 14831544.955505356)
# 141
# ┏┻┓
# 0 1
#
# --------------------
# tree 419: interval = (14831544.955505356, 14834732.455495805)
# 1784
# ┏┻┓
# 0 1
#
# --------------------
# tree 420: interval = (14834732.455495805, 14874366.205376893)
# 518
# ┏┻┓
# 0 1
#
# --------------------
# tree 421: interval = (14874366.205376893, 14941313.705176055)
# 609
# ┏┻┓
# 0 1
#
# --------------------
# tree 422: interval = (14941313.705176055, 15010109.954969674)
# 958
# ┏┻┓
# 0 1
#
# --------------------
# tree 423: interval = (15010109.954969674, 15035901.204892293)
# 1827
# ┏┻┓
# 0 1
#
# --------------------
# tree 424: interval = (15035901.204892293, 15080161.204759523)
# 1244
# ┏┻┓
# 0 1
#
# --------------------
# tree 425: interval = (15080161.204759523, 15101903.704694286)
# 1827
# ┏┻┓
# 0 1
#
# --------------------
# tree 426: interval = (15101903.704694286, 15114753.704655737)
# 1765
# ┏┻┓
# 0 1
#
# --------------------
# tree 427: interval = (15114753.704655737, 15134412.454596758)
# 1827
# ┏┻┓
# 0 1
#
# --------------------
# tree 428: interval = (15134412.454596758, 15146317.454561055)
# 3042
# ┏┻┓
# 0 1
#
# --------------------
# tree 429: interval = (15146317.454561055, 15164257.454507217)
# 3924
# ┏┻┓
# 0 1
#
# --------------------
# tree 430: interval = (15164257.454507217, 15186644.954440057)
# 3762
# ┏┻┓
# 0 1
#
# --------------------
# tree 431: interval = (15186644.954440057, 15226139.954321578)
# 981
# ┏┻┓
# 0 1
#
# --------------------
# tree 432: interval = (15226139.954321578, 15236699.954289898)
# 1827
# ┏┻┓
# 0 1
#
# --------------------
# tree 433: interval = (15236699.954289898, 15302713.704091862)
# 1765
# ┏┻┓
# 0 1
#
# --------------------
# tree 434: interval = (15302713.704091862, 15315324.954054013)
# 963
# ┏┻┓
# 0 1
#
# --------------------
# tree 435: interval = (15315324.954054013, 15351046.203946859)
# 1827
# ┏┻┓
# 0 1
#
# --------------------
# tree 436: interval = (15351046.203946859, 15352863.703941405)
# 1784
# ┏┻┓
# 0 1
#
# --------------------
# tree 437: interval = (15352863.703941405, 15431564.953705296)
# 1506
# ┏┻┓
# 0 1
#
# --------------------
# tree 438: interval = (15431564.953705296, 15433107.453700677)
# 3042
# ┏┻┓
# 0 1
#
# --------------------
# tree 439: interval = (15433107.453700677, 15443634.953669086)
# 3320
# ┏┻┓
# 0 1
#
# --------------------
# tree 440: interval = (15443634.953669086, 15444221.203667343)
# 3980
# ┏┻┓
# 0 1
#
# --------------------
# tree 441: interval = (15444221.203667343, 15476749.95356974)
# 3382
# ┏┻┓
# 0 1
#
# --------------------
# tree 442: interval = (15476749.95356974, 15510173.70346947)
# 661
# ┏┻┓
# 0 1
#
# --------------------
# tree 443: interval = (15510173.70346947, 15518019.953445941)
# 4432
# ┏┻┓
# 0 1
#
# --------------------
# tree 444: interval = (15518019.953445941, 15594762.453215718)
# 1286
# ┏┻┓
# 0 1
#
# --------------------
# tree 445: interval = (15594762.453215718, 15695592.45291321)
# 1734
# ┏┻┓
# 0 1
#
# --------------------
# tree 446: interval = (15695592.45291321, 15709674.95287098)
# 4256
# ┏┻┓
# 0 1
#
# --------------------
# tree 447: interval = (15709674.95287098, 15723479.952829555)
# 2823
# ┏┻┓
# 0 1
#
# --------------------
# tree 448: interval = (15723479.952829555, 15753138.70274058)
# 475
# ┏┻┓
# 0 1
#
# --------------------
# tree 449: interval = (15753138.70274058, 15773836.202678487)
# 5030
# ┏┻┓
# 0 1
#
# --------------------
# tree 450: interval = (15773836.202678487, 15774046.20267786)
# 5117
# ┏┻┓
# 0 1
#
# --------------------
# tree 451: interval = (15774046.20267786, 15786648.702640057)
# 4721
# ┏┻┓
# 0 1
#
# --------------------
# tree 452: interval = (15786648.702640057, 15796042.452611879)
# 3193
# ┏┻┓
# 0 1
#
# --------------------
# tree 453: interval = (15796042.452611879, 15835893.702492312)
# 2490
# ┏┻┓
# 0 1
#
# --------------------
# tree 454: interval = (15835893.702492312, 15838056.20248583)
# 3154
# ┏┻┓
# 0 1
#
# --------------------
# tree 455: interval = (15838056.20248583, 15871952.452384144)
# 2910
# ┏┻┓
# 0 1
#
# --------------------
# tree 456: interval = (15871952.452384144, 15880691.202357933)
# 2026
# ┏┻┓
# 0 1
#
# --------------------
# tree 457: interval = (15880691.202357933, 15895254.952314228)
# 469
# ┏┻┓
# 0 1
#
# --------------------
# tree 458: interval = (15895254.952314228, 16019689.951940924)
# 199
# ┏┻┓
# 0 1
#
# --------------------
# tree 459: interval = (16019689.951940924, 16060567.451818287)
# 882
# ┏┻┓
# 0 1
#
# --------------------
# tree 460: interval = (16060567.451818287, 16083027.45175092)
# 4274
# ┏┻┓
# 0 1
#
# --------------------
# tree 461: interval = (16083027.45175092, 16105801.201682582)
# 2718
# ┏┻┓
# 0 1
#
# --------------------
# tree 462: interval = (16105801.201682582, 16141024.951576918)
# 882
# ┏┻┓
# 0 1
#
# --------------------
# tree 463: interval = (16141024.951576918, 16179038.70146288)
# 1871
# ┏┻┓
# 0 1
#
# --------------------
# tree 464: interval = (16179038.70146288, 16190974.951427072)
# 2718
# ┏┻┓
# 0 1
#
# --------------------
# tree 465: interval = (16190974.951427072, 16208728.701373816)
# 275
# ┏┻┓
# 0 1
#
# --------------------
# tree 466: interval = (16208728.701373816, 16247704.951256871)
# 1871
# ┏┻┓
# 0 1
#
# --------------------
# tree 467: interval = (16247704.951256871, 16291859.951124415)
# 2459
# ┏┻┓
# 0 1
#
# --------------------
# tree 468: interval = (16291859.951124415, 16398554.950804323)
# 106
# ┏┻┓
# 0 1
#
# --------------------
# tree 469: interval = (16398554.950804323, 16413013.70076096)
# 1253
# ┏┻┓
# 0 1
#
# --------------------
# tree 470: interval = (16413013.70076096, 16505633.700483099)
# 420
# ┏┻┓
# 0 1
#
# --------------------
# tree 471: interval = (16505633.700483099, 16589606.20023118)
# 752
# ┏┻┓
# 0 1
#
# --------------------
# tree 472: interval = (16589606.20023118, 16600821.200197533)
# 454
# ┏┻┓
# 0 1
#
# --------------------
# tree 473: interval = (16600821.200197533, 16863433.699409693)
# 425
# ┏┻┓
# 0 1
#
# --------------------
# tree 474: interval = (16863433.699409693, 16969208.699092373)
# 1057
# ┏┻┓
# 0 1
#
# --------------------
# tree 475: interval = (16969208.699092373, 17027993.698916018)
# 1024
# ┏┻┓
# 0 1
#
# --------------------
# tree 476: interval = (17027993.698916018, 17088294.948735118)
# 1891
# ┏┻┓
# 0 1
#
# --------------------
# tree 477: interval = (17088294.948735118, 17097157.44870852)
# 2411
# ┏┻┓
# 0 1
#
# --------------------
# tree 478: interval = (17097157.44870852, 17108642.448674068)
# 1057
# ┏┻┓
# 0 1
#
# --------------------
# tree 479: interval = (17108642.448674068, 17166661.198500007)
# 1115
# ┏┻┓
# 0 1
#
# --------------------
# tree 480: interval = (17166661.198500007, 17184321.198447034)
# 1057
# ┏┻┓
# 0 1
#
# --------------------
# tree 481: interval = (17184321.198447034, 17359694.947920904)
# 905
# ┏┻┓
# 0 1
#
# --------------------
# tree 482: interval = (17359694.947920904, 17382924.947851226)
# 4902
# ┏┻┓
# 0 1
#
# --------------------
# tree 483: interval = (17382924.947851226, 17407262.44777821)
# 5015
# ┏┻┓
# 0 1
#
# --------------------
# tree 484: interval = (17407262.44777821, 17409553.69777134)
# 3827
# ┏┻┓
# 0 1
#
# --------------------
# tree 485: interval = (17409553.69777134, 17419013.697742954)
# 3192
# ┏┻┓
# 0 1
#
# --------------------
# tree 486: interval = (17419013.697742954, 17419299.94774209)
# 3968
# ┏┻┓
# 0 1
#
# --------------------
# tree 487: interval = (17419299.94774209, 17432706.197701886)
# 892
# ┏┻┓
# 0 1
#
# --------------------
# tree 488: interval = (17432706.197701886, 17465613.69760315)
# 3192
# ┏┻┓
# 0 1
#
# --------------------
# tree 489: interval = (17465613.69760315, 17512136.197463587)
# 2705
# ┏┻┓
# 0 1
#
# --------------------
# tree 490: interval = (17512136.197463587, 17523262.44743021)
# 3192
# ┏┻┓
# 0 1
#
# --------------------
# tree 491: interval = (17523262.44743021, 17528943.69741316)
# 1798
# ┏┻┓
# 0 1
#
# --------------------
# tree 492: interval = (17528943.69741316, 17615204.947154373)
# 2705
# ┏┻┓
# 0 1
#
# --------------------
# tree 493: interval = (17615204.947154373, 17622441.197132677)
# 4116
# ┏┻┓
# 0 1
#
# --------------------
# ...
# 5131
# ┏┻┓
# 0 1
#
# --------------------
# tree 6767: interval = (195492645.2635221, 195534201.5133974)
# 2491
# ┏┻┓
# 0 1
#
# --------------------
# tree 6768: interval = (195534201.5133974, 195540522.76337844)
# 1633
# ┏┻┓
# 0 1
#
# --------------------
# tree 6769: interval = (195540522.76337844, 195615085.26315475)
# 663
# ┏┻┓
# 0 1
#
# --------------------
# tree 6770: interval = (195615085.26315475, 195637997.76308602)
# 548
# ┏┻┓
# 0 1
#
# --------------------
# tree 6771: interval = (195637997.76308602, 195650154.0130495)
# 3545
# ┏┻┓
# 0 1
#
# --------------------
# tree 6772: interval = (195650154.0130495, 195662150.26301354)
# 2382
# ┏┻┓
# 0 1
#
# --------------------
# tree 6773: interval = (195662150.26301354, 195671149.01298657)
# 3485
# ┏┻┓
# 0 1
#
# --------------------
# tree 6774: interval = (195671149.01298657, 195675016.51297495)
# 2605
# ┏┻┓
# 0 1
#
# --------------------
# tree 6775: interval = (195675016.51297495, 195728814.01281354)
# 2618
# ┏┻┓
# 0 1
#
# --------------------
# tree 6776: interval = (195728814.01281354, 195752261.5127432)
# 4217
# ┏┻┓
# 0 1
#
# --------------------
# tree 6777: interval = (195752261.5127432, 195797324.01260802)
# 2618
# ┏┻┓
# 0 1
#
# --------------------
# tree 6778: interval = (195797324.01260802, 195805656.51258305)
# 3485
# ┏┻┓
# 0 1
#
# --------------------
# tree 6779: interval = (195805656.51258305, 195832105.26250365)
# 1458
# ┏┻┓
# 0 1
#
# --------------------
# tree 6780: interval = (195832105.26250365, 195837055.26248884)
# 3485
# ┏┻┓
# 0 1
#
# --------------------
# tree 6781: interval = (195837055.26248884, 195858604.01242417)
# 3891
# ┏┻┓
# 0 1
#
# --------------------
# tree 6782: interval = (195858604.01242417, 195860397.76241878)
# 5080
# ┏┻┓
# 0 1
#
# --------------------
# tree 6783: interval = (195860397.76241878, 195861252.7624162)
# 5137
# ┏┻┓
# 0 1
#
# --------------------
# tree 6784: interval = (195861252.7624162, 195878526.51236442)
# 5066
# ┏┻┓
# 0 1
#
# --------------------
# tree 6785: interval = (195878526.51236442, 196133224.01160032)
# 176
# ┏┻┓
# 0 1
#
# --------------------
# tree 6786: interval = (196133224.01160032, 196168885.26149333)
# 1967
# ┏┻┓
# 0 1
#
# --------------------
# tree 6787: interval = (196168885.26149333, 196171425.26148573)
# 2768
# ┏┻┓
# 0 1
#
# --------------------
# tree 6788: interval = (196171425.26148573, 196176801.51146957)
# 4414
# ┏┻┓
# 0 1
#
# --------------------
# tree 6789: interval = (196176801.51146957, 196178691.5114639)
# 4270
# ┏┻┓
# 0 1
#
# --------------------
# tree 6790: interval = (196178691.5114639, 196225185.26132447)
# 4414
# ┏┻┓
# 0 1
#
# --------------------
# tree 6791: interval = (196225185.26132447, 196241616.51127517)
# 1780
# ┏┻┓
# 0 1
#
# --------------------
# tree 6792: interval = (196241616.51127517, 196244395.26126683)
# 2629
# ┏┻┓
# 0 1
#
# --------------------
# tree 6793: interval = (196244395.26126683, 196250315.26124904)
# 3058
# ┏┻┓
# 0 1
#
# --------------------
# tree 6794: interval = (196250315.26124904, 196264832.7612055)
# 3046
# ┏┻┓
# 0 1
#
# --------------------
# tree 6795: interval = (196264832.7612055, 196265776.51120266)
# 4414
# ┏┻┓
# 0 1
#
# --------------------
# tree 6796: interval = (196265776.51120266, 196325630.2610231)
# 3658
# ┏┻┓
# 0 1
#
# --------------------
# tree 6797: interval = (196325630.2610231, 196349877.7609504)
# 2584
# ┏┻┓
# 0 1
#
# --------------------
# tree 6798: interval = (196349877.7609504, 196358132.76092562)
# 1825
# ┏┻┓
# 0 1
#
# --------------------
# tree 6799: interval = (196358132.76092562, 196405054.01078483)
# 2697
# ┏┻┓
# 0 1
#
# --------------------
# tree 6800: interval = (196405054.01078483, 196411897.76076427)
# 5166
# ┏┻┓
# 0 1
#
# --------------------
# tree 6801: interval = (196411897.76076427, 196415312.76075405)
# 5076
# ┏┻┓
# 0 1
#
# --------------------
# tree 6802: interval = (196415312.76075405, 196430752.76070774)
# 5087
# ┏┻┓
# 0 1
#
# --------------------
# tree 6803: interval = (196430752.76070774, 196434010.26069796)
# 5166
# ┏┻┓
# 0 1
#
# --------------------
# tree 6804: interval = (196434010.26069796, 196437175.26068845)
# 4955
# ┏┻┓
# 0 1
#
# --------------------
# tree 6805: interval = (196437175.26068845, 196438827.76068354)
# 4789
# ┏┻┓
# 0 1
#
# --------------------
# tree 6806: interval = (196438827.76068354, 196449814.01065058)
# 4828
# ┏┻┓
# 0 1
#
# --------------------
# tree 6807: interval = (196449814.01065058, 196530230.26040933)
# 3005
# ┏┻┓
# 0 1
#
# --------------------
# tree 6808: interval = (196530230.26040933, 196530244.01040927)
# 5273
# ┏┻┓
# 0 1
#
# --------------------
# tree 6809: interval = (196530244.01040927, 196531497.7604055)
# 2226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6810: interval = (196531497.7604055, 196651640.26004505)
# 233
# ┏┻┓
# 0 1
#
# --------------------
# tree 6811: interval = (196651640.26004505, 196687950.25993615)
# 522
# ┏┻┓
# 0 1
#
# --------------------
# tree 6812: interval = (196687950.25993615, 196704434.00988668)
# 1908
# ┏┻┓
# 0 1
#
# --------------------
# tree 6813: interval = (196704434.00988668, 196743177.75977048)
# 3368
# ┏┻┓
# 0 1
#
# --------------------
# tree 6814: interval = (196743177.75977048, 196761359.0097159)
# 2226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6815: interval = (196761359.0097159, 196762896.50971133)
# 3368
# ┏┻┓
# 0 1
#
# --------------------
# tree 6816: interval = (196762896.50971133, 196839027.75948292)
# 1014
# ┏┻┓
# 0 1
#
# --------------------
# tree 6817: interval = (196839027.75948292, 196870522.75938842)
# 305
# ┏┻┓
# 0 1
#
# --------------------
# tree 6818: interval = (196870522.75938842, 196884536.50934637)
# 2171
# ┏┻┓
# 0 1
#
# --------------------
# tree 6819: interval = (196884536.50934637, 197102281.50869316)
# 522
# ┏┻┓
# 0 1
#
# --------------------
# tree 6820: interval = (197102281.50869316, 197205370.2583839)
# 3432
# ┏┻┓
# 0 1
#
# --------------------
# tree 6821: interval = (197205370.2583839, 197303740.2580888)
# 1384
# ┏┻┓
# 0 1
#
# --------------------
# tree 6822: interval = (197303740.2580888, 197310772.75806767)
# 2299
# ┏┻┓
# 0 1
#
# --------------------
# tree 6823: interval = (197310772.75806767, 197311260.2580662)
# 1677
# ┏┻┓
# 0 1
#
# --------------------
# tree 6824: interval = (197311260.2580662, 197317444.00804767)
# 2299
# ┏┻┓
# 0 1
#
# --------------------
# tree 6825: interval = (197317444.00804767, 197317864.0080464)
# 3319
# ┏┻┓
# 0 1
#
# --------------------
# tree 6826: interval = (197317864.0080464, 197347305.25795808)
# 3948
# ┏┻┓
# 0 1
#
# --------------------
# tree 6827: interval = (197347305.25795808, 197356320.25793105)
# 2874
# ┏┻┓
# 0 1
#
# --------------------
# tree 6828: interval = (197356320.25793105, 197399461.50780162)
# 843
# ┏┻┓
# 0 1
#
# --------------------
# tree 6829: interval = (197399461.50780162, 197451826.5076445)
# 632
# ┏┻┓
# 0 1
#
# --------------------
# tree 6830: interval = (197451826.5076445, 197601342.75719595)
# 1351
# ┏┻┓
# 0 1
#
# --------------------
# tree 6831: interval = (197601342.75719595, 197608437.7571747)
# 4154
# ┏┻┓
# 0 1
#
# --------------------
# tree 6832: interval = (197608437.7571747, 197641139.00707656)
# 2953
# ┏┻┓
# 0 1
#
# --------------------
# tree 6833: interval = (197641139.00707656, 197680107.7569597)
# 2485
# ┏┻┓
# 0 1
#
# --------------------
# tree 6834: interval = (197680107.7569597, 197687549.00693735)
# 4030
# ┏┻┓
# 0 1
#
# --------------------
# tree 6835: interval = (197687549.00693735, 197733462.7567996)
# 2358
# ┏┻┓
# 0 1
#
# --------------------
# tree 6836: interval = (197733462.7567996, 197749104.00675267)
# 4537
# ┏┻┓
# 0 1
#
# --------------------
# tree 6837: interval = (197749104.00675267, 197779709.0066609)
# 2439
# ┏┻┓
# 0 1
#
# --------------------
# tree 6838: interval = (197779709.0066609, 197791292.75662613)
# 4387
# ┏┻┓
# 0 1
#
# --------------------
# tree 6839: interval = (197791292.75662613, 197808972.75657308)
# 4484
# ┏┻┓
# 0 1
#
# --------------------
# tree 6840: interval = (197808972.75657308, 197810137.75656956)
# 3829
# ┏┻┓
# 0 1
#
# --------------------
# tree 6841: interval = (197810137.75656956, 197850180.25644943)
# 3258
# ┏┻┓
# 0 1
#
# --------------------
# tree 6842: interval = (197850180.25644943, 197875399.0063738)
# 806
# ┏┻┓
# 0 1
#
# --------------------
# tree 6843: interval = (197875399.0063738, 197887554.00633734)
# 2683
# ┏┻┓
# 0 1
#
# --------------------
# tree 6844: interval = (197887554.00633734, 197966994.00609902)
# 1157
# ┏┻┓
# 0 1
#
# --------------------
# tree 6845: interval = (197966994.00609902, 197980161.5060595)
# 2299
# ┏┻┓
# 0 1
#
# --------------------
# tree 6846: interval = (197980161.5060595, 197988837.75603348)
# 3308
# ┏┻┓
# 0 1
#
# --------------------
# tree 6847: interval = (197988837.75603348, 198001880.25599435)
# 3214
# ┏┻┓
# 0 1
#
# --------------------
# tree 6848: interval = (198001880.25599435, 198005487.75598353)
# 3308
# ┏┻┓
# 0 1
#
# --------------------
# tree 6849: interval = (198005487.75598353, 198030420.2559087)
# 3298
# ┏┻┓
# 0 1
#
# --------------------
# tree 6850: interval = (198030420.2559087, 198056804.00582957)
# 552
# ┏┻┓
# 0 1
#
# --------------------
# tree 6851: interval = (198056804.00582957, 198113507.75565946)
# 495
# ┏┻┓
# 0 1
#
# --------------------
# tree 6852: interval = (198113507.75565946, 198133754.00559872)
# 3298
# ┏┻┓
# 0 1
#
# --------------------
# tree 6853: interval = (198133754.00559872, 198481744.00455475)
# 59
# ┏┻┓
# 0 1
#
# --------------------
# tree 6854: interval = (198481744.00455475, 198493590.2545192)
# 4169
# ┏┻┓
# 0 1
#
# --------------------
# tree 6855: interval = (198493590.2545192, 198550937.7543472)
# 3174
# ┏┻┓
# 0 1
#
# --------------------
# tree 6856: interval = (198550937.7543472, 198570514.00428846)
# 3226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6857: interval = (198570514.00428846, 198571025.25428694)
# 2416
# ┏┻┓
# 0 1
#
# --------------------
# tree 6858: interval = (198571025.25428694, 198573069.0042808)
# 3226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6859: interval = (198573069.0042808, 198575951.5042721)
# 79
# ┏┻┓
# 0 1
#
# --------------------
# tree 6860: interval = (198575951.5042721, 198596437.75421068)
# 3174
# ┏┻┓
# 0 1
#
# --------------------
# tree 6861: interval = (198596437.75421068, 198638707.75408387)
# 3226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6862: interval = (198638707.75408387, 198651662.754045)
# 4055
# ┏┻┓
# 0 1
#
# --------------------
# tree 6863: interval = (198651662.754045, 198658420.25402474)
# 4601
# ┏┻┓
# 0 1
#
# --------------------
# tree 6864: interval = (198658420.25402474, 198658645.2540241)
# 4640
# ┏┻┓
# 0 1
#
# --------------------
# tree 6865: interval = (198658645.2540241, 198660414.00401875)
# 3226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6866: interval = (198660414.00401875, 198661720.25401485)
# 1982
# ┏┻┓
# 0 1
#
# --------------------
# tree 6867: interval = (198661720.25401485, 198664172.7540075)
# 2082
# ┏┻┓
# 0 1
#
# --------------------
# tree 6868: interval = (198664172.7540075, 198690705.25392786)
# 3226
# ┏┻┓
# 0 1
#
# --------------------
# tree 6869: interval = (198690705.25392786, 198696189.00391144)
# 3174
# ┏┻┓
# 0 1
#
# --------------------
# tree 6870: interval = (198696189.00391144, 198715641.50385308)
# 1881
# ┏┻┓
# 0 1
#
# --------------------
# tree 6871: interval = (198715641.50385308, 198723224.0038303)
# 4640
# ┏┻┓
# 0 1
#
# --------------------
# tree 6872: interval = (198723224.0038303, 198738699.0037839)
# 3715
# ┏┻┓
# 0 1
#
# --------------------
# tree 6873: interval = (198738699.0037839, 198739172.75378248)
# 1642
# ┏┻┓
# 0 1
#
# --------------------
# tree 6874: interval = (198739172.75378248, 198751789.00374463)
# 3715
# ┏┻┓
# 0 1
#
# --------------------
# tree 6875: interval = (198751789.00374463, 198755059.00373483)
# 4747
# ┏┻┓
# 0 1
#
# --------------------
# tree 6876: interval = (198755059.00373483, 198790436.50362867)
# 2912
# ┏┻┓
# 0 1
#
# --------------------
# tree 6877: interval = (198790436.50362867, 198795337.75361398)
# 4039
# ┏┻┓
# 0 1
#
# --------------------
# tree 6878: interval = (198795337.75361398, 198812141.5035636)
# 521
# ┏┻┓
# 0 1
#
# --------------------
# tree 6879: interval = (198812141.5035636, 198812734.0035618)
# 4039
# ┏┻┓
# 0 1
#
# --------------------
# tree 6880: interval = (198812734.0035618, 198829651.50351107)
# 4601
# ┏┻┓
# 0 1
#
# --------------------
# tree 6881: interval = (198829651.50351107, 198855882.75343236)
# 4493
# ┏┻┓
# 0 1
#
# --------------------
# tree 6882: interval = (198855882.75343236, 198858142.7534256)
# 4457
# ┏┻┓
# 0 1
#
# --------------------
# tree 6883: interval = (198858142.7534256, 198880420.25335872)
# 4493
# ┏┻┓
# 0 1
#
# --------------------
# tree 6884: interval = (198880420.25335872, 198895437.7533137)
# 2017
# ┏┻┓
# 0 1
#
# --------------------
# tree 6885: interval = (198895437.7533137, 198932775.2532017)
# 4493
# ┏┻┓
# 0 1
#
# --------------------
# tree 6886: interval = (198932775.2532017, 198936867.75318938)
# 3798
# ┏┻┓
# 0 1
#
# --------------------
# tree 6887: interval = (198936867.75318938, 198963667.75310898)
# 4493
# ┏┻┓
# 0 1
#
# --------------------
# tree 6888: interval = (198963667.75310898, 198973510.25307944)
# 4392
# ┏┻┓
# 0 1
#
# --------------------
# tree 6889: interval = (198973510.25307944, 198986389.00304082)
# 2724
# ┏┻┓
# 0 1
#
# --------------------
# tree 6890: interval = (198986389.00304082, 198992594.00302225)
# 3862
# ┏┻┓
# 0 1
#
# --------------------
# tree 6891: interval = (198992594.00302225, 199007837.7529765)
# 821
# ┏┻┓
# 0 1
#
# --------------------
# tree 6892: interval = (199007837.7529765, 199020345.25293896)
# 3862
# ┏┻┓
# 0 1
#
# --------------------
# tree 6893: interval = (199020345.25293896, 199057240.25282824)
# 2365
# ┏┻┓
# 0 1
#
# --------------------
# tree 6894: interval = (199057240.25282824, 199082860.2527514)
# 4267
# ┏┻┓
# 0 1
#
# --------------------
# tree 6895: interval = (199082860.2527514, 199091734.00272477)
# 4457
# ┏┻┓
# 0 1
#
# --------------------
# tree 6896: interval = (199091734.00272477, 199094885.25271535)
# 4089
# ┏┻┓
# 0 1
#
# --------------------
# tree 6897: interval = (199094885.25271535, 199530281.50140914)
# 461
# ┏┻┓
# 0 1
#
# --------------------
# tree 6898: interval = (199530281.50140914, 199632716.50110185)
# 1007
# ┏┻┓
# 0 1
#
# --------------------
# tree 6899: interval = (199632716.50110185, 199646047.75106186)
# 3107
# ┏┻┓
# 0 1
#
# --------------------
# tree 6900: interval = (199646047.75106186, 199649287.75105214)
# 4383
# ┏┻┓
# 0 1
#
# --------------------
# tree 6901: interval = (199649287.75105214, 199664584.00100625)
# 2468
# ┏┻┓
# 0 1
#
# --------------------
# tree 6902: interval = (199664584.00100625, 199680116.5009596)
# 4383
# ┏┻┓
# 0 1
#
# --------------------
# tree 6903: interval = (199680116.5009596, 199689646.50093105)
# 4775
# ┏┻┓
# 0 1
#
# --------------------
# tree 6904: interval = (199689646.50093105, 199690039.00092986)
# 4663
# ┏┻┓
# 0 1
#
# --------------------
# tree 6905: interval = (199690039.00092986, 199692859.00092143)
# 4316
# ┏┻┓
# 0 1
#
# --------------------
# tree 6906: interval = (199692859.00092143, 199694427.75091672)
# 4386
# ┏┻┓
# 0 1
#
# --------------------
# tree 6907: interval = (199694427.75091672, 199695059.0009148)
# 4180
# ┏┻┓
# 0 1
#
# --------------------
# tree 6908: interval = (199695059.0009148, 199722065.2508338)
# 4663
# ┏┻┓
# 0 1
#
# --------------------
# tree 6909: interval = (199722065.2508338, 199764425.25070673)
# 3159
# ┏┻┓
# 0 1
#
# --------------------
# tree 6910: interval = (199764425.25070673, 199786942.75063917)
# 2052
# ┏┻┓
# 0 1
#
# --------------------
# tree 6911: interval = (199786942.75063917, 199787037.75063884)
# 3978
# ┏┻┓
# 0 1
#
# --------------------
# tree 6912: interval = (199787037.75063884, 199788465.25063458)
# 4836
# ┏┻┓
# 0 1
#
# --------------------
# tree 6913: interval = (199788465.25063458, 199791835.25062448)
# 5311
# ┏┻┓
# 0 1
#
# --------------------
# tree 6914: interval = (199791835.25062448, 199813795.2505586)
# 5303
# ┏┻┓
# 0 1
#
# --------------------
# tree 6915: interval = (199813795.2505586, 199817761.5005467)
# 5208
# ┏┻┓
# 0 1
#
# --------------------
# tree 6916: interval = (199817761.5005467, 199820592.75053823)
# 5165
# ┏┻┓
# 0 1
#
# --------------------
# tree 6917: interval = (199820592.75053823, 199829831.5005105)
# 4836
# ┏┻┓
# 0 1
#
# --------------------
# tree 6918: interval = (199829831.5005105, 199852340.25044298)
# 4108
# ┏┻┓
# 0 1
#
# --------------------
# tree 6919: interval = (199852340.25044298, 199856005.25043198)
# 3915
# ┏┻┓
# 0 1
#
# --------------------
# tree 6920: interval = (199856005.25043198, 199863720.25040886)
# 3535
# ┏┻┓
# 0 1
#
# --------------------
# tree 6921: interval = (199863720.25040886, 199883336.50034997)
# 3915
# ┏┻┓
# 0 1
#
# --------------------
# tree 6922: interval = (199883336.50034997, 199885617.75034314)
# 2052
# ┏┻┓
# 0 1
#
# --------------------
# tree 6923: interval = (199885617.75034314, 199909757.75027072)
# 3915
# ┏┻┓
# 0 1
#
# --------------------
# tree 6924: interval = (199909757.75027072, 199923241.50023028)
# 5165
# ┏┻┓
# 0 1
#
# --------------------
# tree 6925: interval = (199923241.50023028, 199969640.25009108)
# 2541
# ┏┻┓
# 0 1
#
# --------------------
# tree 6926: interval = (199969640.25009108, 199990865.25002742)
# 4258
# ┏┻┓
# 0 1
#
# --------------------
# tree 6927: interval = (199990865.25002742, 199999999.0)
# 4386
# ┏┻┓
# 0 1
