# %% [markdown]
# # Likelihood Analysis of Parameter space
# This notebook contains analysis regarding the Likelihood of various parameter combinations.
#
# .) Do Maximum Likelihood analysis (with Nelder Mead)
# .) Parallelize

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

import os as os
import multiprocessing as mp
import sys as sys
import socket
import h5py  # Python Package to do the HDF5.
import matplotlib.pyplot as plt

### Pick the right path (whether on cluster or at home)
if socket.gethostname() == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket.gethostname() == "midway2-0401.rcc.local" or socket.gethostname() == "midway2-0402.rcc.local":
    print("Midway jnovmbre partition detected.")
    path = "/project/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)

sys.path.append("./Python3/")  # Since now we are in the Root Directory
from hmm_inference import HMM_Analyze   # Do not move. Should be after sys.path..
#sys.path.append("./Python3/create1000G_Mosaic/")  # Since now we are in the Root Directory
#from createMosaicsMulti import Mosaic_1000G_Multi  # Import the object that can create the Multiruns

print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")
# Out:
# Midway jnovmbre partition detected.
# /project/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# ### Need: Parallel, quick computation of likelihoods for target individuals
# Problem: Bottleneck is I/O. I.e. load the 100 TSI individuals once - and then just update the parameters and recalculate
#
# ### Potential Plan:
# Have the 100 TSI individuals in storage in Load Object. Have loading function there that provides the genotype Matrix of one of these Individuals (from storage)
#
# ### First try: Only do one individual

# %%
def prep_hmm_object(path_mosaic, exclude_pops, iid, prefix_out="", ch=3, n_ref=503, diploid=True):
    """Prepare and return a working HMM object
    diploid: Whether to shuffle diploid observations."""
    
    hmm = HMM_Analyze(cython=2, p_model="MosaicHDF5",
                      manual_load=True, save=False, save_fp=False, output=False)

    # Load and prepare the pre-processing Model
    hmm.load_preprocessing_model()              # Load the preprocessing Model
    hmm.p_obj.set_folder(path_mosaic)         # Set the Folder
    hmm.p_obj.set_prefix_out_data(prefix_out)
    hmm.p_obj.set_exclude_pops(pops=exclude_pops)

    hmm.load_data(iid=iid, ch=ch, n_ref=n_ref)  # Load the actual Data
    hmm.load_emission_model()
    hmm.load_transition_model()
    if diploid == True:
        hmm.set_diploid_observations()             # To diploidize Individuals
    return hmm

def ll_mosaic_individual(hmm, roh_in=1, roh_out=10, roh_jump=100):
    """Calculate the Log Likelihood of Mosaic Individual"""    
    hmm.t_obj.set_params(roh_in=roh_in, roh_out=roh_out, roh_jump=roh_jump)
    _, _, _, tot_ll = hmm.calc_posterior(save=False, full=True)
    return tot_ll

def ll_mosaic_individual(prms):
    """Calculate the log likelihood of Mosaic individual.
    ASSUME THAT HMM (hmm) IS INITIALIZED PROPERLY!!!"""
    roh_in, roh_out, roh_jump = prms
    print("\nParameters Current Step:")
    print(f"ROH In {roh_in:.3f}")
    print(f"ROH Out {roh_out:.3f}")
    print(f"ROH Jump: {roh_jump:.3f}")
    
    if np.min(prms)<0:   # If Parameter not feasible, penalize
        return np.inf
    
    hmm.t_obj.set_params(roh_in=roh_in, roh_out=roh_out, roh_jump=roh_jump) # Set the Parameters
    _, _, _, tot_ll = hmm.calc_posterior(save = False, full = True)  # Calculate the LL
    
    print(f"LL: {tot_ll:.6f}")
    return -tot_ll  # Return Negetive one (for minimization)

# %% [markdown]
# ### Load HMM Object

# %%
iid = "iid0"
ch=3
n_ref=503
path_mosaic = "./Simulated/1000G_Mosaic/TSI5/ch3_8cm/"
exclude_pops = ["TSI", ]

### Prepare HMM Object
hmm = prep_hmm_object(path_mosaic, exclude_pops=exclude_pops, iid = iid, ch=ch, n_ref=n_ref)
# Out:
# Loaded 77652 variants
# Loaded 100 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI5/ch3_8cm/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference

# %%
### Test the log likelihood evaltions
#ll = ll_mosaic_individual(hmm, roh_in=1, roh_out=10, roh_jump=100)
ll = ll_mosaic_individual([1,10,100])
ll
# Out:
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 100.000
# Reference Number: 792
# Total Log likelihood: -24388.063
# Likelihood: -24388.063309
# 24388.063309288642

# %% [markdown]
# # Optimize Single Individual Function

# %%
x0 = np.array([5, 10, 500])  # The Starting Value
res = minimize(ll_mosaic_individual, x0, method='nelder-mead', options={'fatol': 1e-2, 'disp': True})
# Out:
# Parameters Current Step:
# ROH In 5.000
# ROH Out 10.000
# ROH Jump: 500.000
# Reference Number: 792
# Total Log likelihood: -23783.968
# LL: -23783.968242
#
# Parameters Current Step:
# ROH In 5.250
# ROH Out 10.000
# ROH Jump: 500.000
# Reference Number: 792
# Total Log likelihood: -23776.304
# LL: -23776.304274
#
# Parameters Current Step:
# ROH In 5.000
# ROH Out 10.500
# ROH Jump: 500.000
# Reference Number: 792
# Total Log likelihood: -23776.463
# LL: -23776.462745
#
# Parameters Current Step:
# ROH In 5.000
# ROH Out 10.000
# ROH Jump: 525.000
# Reference Number: 792
# Total Log likelihood: -23779.428
# LL: -23779.428025
#
# Parameters Current Step:
# ROH In 5.167
# ROH Out 10.333
# ROH Jump: 516.667
# Reference Number: 792
# Total Log likelihood: -23770.693
# LL: -23770.692578
#
# Parameters Current Step:
# ROH In 5.250
# ROH Out 10.500
# ROH Jump: 525.000
# Reference Number: 792
# Total Log likelihood: -23764.245
# LL: -23764.245117
#
# Parameters Current Step:
# ROH In 5.333
# ROH Out 10.667
# ROH Jump: 491.667
# Reference Number: 792
# Total Log likelihood: -23765.440
# LL: -23765.439956
#
# Parameters Current Step:
# ROH In 5.556
# ROH Out 10.278
# ROH Jump: 511.111
# Reference Number: 792
# Total Log likelihood: -23761.070
# LL: -23761.070275
#
# Parameters Current Step:
# ROH In 5.833
# ROH Out 10.167
# ROH Jump: 516.667
# Reference Number: 792
# Total Log likelihood: -23754.046
# LL: -23754.046021
#
# Parameters Current Step:
# ROH In 5.694
# ROH Out 10.889
# ROH Jump: 522.222
# Reference Number: 792
# Total Log likelihood: -23746.195
# LL: -23746.195430
#
# Parameters Current Step:
# ROH In 5.917
# ROH Out 11.333
# ROH Jump: 533.333
# Reference Number: 792
# Total Log likelihood: -23731.962
# LL: -23731.962176
#
# Parameters Current Step:
# ROH In 6.000
# ROH Out 10.667
# ROH Jump: 558.333
# Reference Number: 792
# Total Log likelihood: -23735.328
# LL: -23735.328264
#
# Parameters Current Step:
# ROH In 6.583
# ROH Out 10.944
# ROH Jump: 547.222
# Reference Number: 792
# Total Log likelihood: -23718.144
# LL: -23718.144014
#
# Parameters Current Step:
# ROH In 7.250
# ROH Out 11.167
# ROH Jump: 558.333
# Reference Number: 792
# Total Log likelihood: -23697.764
# LL: -23697.763908
#
# Parameters Current Step:
# ROH In 6.944
# ROH Out 11.944
# ROH Jump: 583.333
# Reference Number: 792
# Total Log likelihood: -23690.544
# LL: -23690.543511
#
# Parameters Current Step:
# ROH In 7.500
# ROH Out 12.833
# ROH Jump: 616.667
# Reference Number: 792
# Total Log likelihood: -23662.524
# LL: -23662.523703
#
# Parameters Current Step:
# ROH In 7.778
# ROH Out 12.889
# ROH Jump: 580.556
# Reference Number: 792
# Total Log likelihood: -23660.209
# LL: -23660.208821
#
# Parameters Current Step:
# ROH In 8.667
# ROH Out 14.000
# ROH Jump: 591.667
# Reference Number: 792
# Total Log likelihood: -23627.440
# LL: -23627.439898
#
# Parameters Current Step:
# ROH In 9.694
# ROH Out 14.000
# ROH Jump: 644.444
# Reference Number: 792
# Total Log likelihood: -23603.035
# LL: -23603.034961
#
# Parameters Current Step:
# ROH In 11.583
# ROH Out 15.333
# ROH Jump: 700.000
# Reference Number: 792
# Total Log likelihood: -23553.331
# LL: -23553.331005
#
# Parameters Current Step:
# ROH In 11.250
# ROH Out 16.944
# ROH Jump: 713.889
# Reference Number: 792
# Total Log likelihood: -23540.560
# LL: -23540.559665
#
# Parameters Current Step:
# ROH In 13.250
# ROH Out 19.833
# ROH Jump: 791.667
# Reference Number: 792
# Total Log likelihood: -23481.714
# LL: -23481.713521
#
# Parameters Current Step:
# ROH In 14.833
# ROH Out 19.944
# ROH Jump: 772.222
# Reference Number: 792
# Total Log likelihood: -23461.560
# LL: -23461.560172
#
# Parameters Current Step:
# ROH In 18.500
# ROH Out 23.500
# ROH Jump: 850.000
# Reference Number: 792
# Total Log likelihood: -23391.097
# LL: -23391.096783
#
# Parameters Current Step:
# ROH In 20.222
# ROH Out 25.111
# ROH Jump: 969.444
# Reference Number: 792
# Total Log likelihood: -23363.192
# LL: -23363.192200
#
# Parameters Current Step:
# ROH In 26.000
# ROH Out 30.667
# ROH Jump: 1158.333
# Reference Number: 792
# Total Log likelihood: -23286.329
# LL: -23286.329283
#
# Parameters Current Step:
# ROH In 26.917
# ROH Out 34.000
# ROH Jump: 1166.667
# Reference Number: 792
# Total Log likelihood: -23261.115
# LL: -23261.115211
#
# Parameters Current Step:
# ROH In 34.583
# ROH Out 43.333
# ROH Jump: 1400.000
# Reference Number: 792
# Total Log likelihood: -23182.177
# LL: -23182.177190
#
# Parameters Current Step:
# ROH In 39.472
# ROH Out 45.167
# ROH Jump: 1480.556
# Reference Number: 792
# Total Log likelihood: -23154.673
# LL: -23154.673112
#
# Parameters Current Step:
# ROH In 52.583
# ROH Out 57.833
# ROH Jump: 1825.000
# Reference Number: 792
# Total Log likelihood: -23081.831
# LL: -23081.830737
#
# Parameters Current Step:
# ROH In 56.944
# ROH Out 64.389
# ROH Jump: 2072.222
# Reference Number: 792
# Total Log likelihood: -23070.961
# LL: -23070.960675
#
# Parameters Current Step:
# ROH In 76.167
# ROH Out 84.833
# ROH Jump: 2683.333
# Reference Number: 792
# Total Log likelihood: -23028.676
# LL: -23028.676093
#
# Parameters Current Step:
# ROH In 82.889
# ROH Out 93.333
# ROH Jump: 2780.556
# Reference Number: 792
# Total Log likelihood: -23004.993
# LL: -23004.993007
#
# Parameters Current Step:
# ROH In 111.333
# ROH Out 124.667
# ROH Jump: 3591.667
# Reference Number: 792
# Total Log likelihood: -22989.481
# LL: -22989.480661
#
# Parameters Current Step:
# ROH In 125.472
# ROH Out 134.889
# ROH Jump: 4000.000
# Reference Number: 792
# Total Log likelihood: -23000.377
# LL: -23000.376683
#
# Parameters Current Step:
# ROH In 156.065
# ROH Out 171.759
# ROH Jump: 5025.000
# Reference Number: 792
# Total Log likelihood: -23038.856
# LL: -23038.855536
#
# Parameters Current Step:
# ROH In 130.194
# ROH Out 143.278
# ROH Jump: 4225.000
# Reference Number: 792
# Total Log likelihood: -23009.716
# LL: -23009.716239
#
# Parameters Current Step:
# ROH In 168.500
# ROH Out 183.722
# ROH Jump: 5194.444
# Reference Number: 792
# Total Log likelihood: -23033.325
# LL: -23033.325036
#
# Parameters Current Step:
# ROH In 99.250
# ROH Out 109.556
# ROH Jump: 3311.111
# Reference Number: 792
# Total Log likelihood: -23002.087
# LL: -23002.086851
#
# Parameters Current Step:
# ROH In 93.843
# ROH Out 102.796
# ROH Jump: 3043.519
# Reference Number: 792
# Total Log likelihood: -22992.991
# LL: -22992.990684
#
# Parameters Current Step:
# ROH In 121.182
# ROH Out 132.012
# ROH Jump: 3779.012
# Reference Number: 792
# Total Log likelihood: -22984.700
# LL: -22984.699732
#
# Parameters Current Step:
# ROH In 132.148
# ROH Out 143.241
# ROH Jump: 4012.963
# Reference Number: 792
# Total Log likelihood: -22981.353
# LL: -22981.353041
#
# Parameters Current Step:
# ROH In 99.410
# ROH Out 112.247
# ROH Jump: 3098.765
# Reference Number: 792
# Total Log likelihood: -22971.904
# LL: -22971.904476
#
# Parameters Current Step:
# ROH In 86.380
# ROH Out 100.926
# ROH Jump: 2648.148
# Reference Number: 792
# Total Log likelihood: -22966.393
# LL: -22966.392526
#
# Parameters Current Step:
# ROH In 126.065
# ROH Out 143.093
# ROH Jump: 3791.667
# Reference Number: 792
# Total Log likelihood: -22964.741
# LL: -22964.740832
#
# Parameters Current Step:
# ROH In 142.176
# ROH Out 163.241
# ROH Jump: 4165.741
# Reference Number: 792
# Total Log likelihood: -22964.016
# LL: -22964.016033
#
# Parameters Current Step:
# ROH In 129.136
# ROH Out 146.938
# ROH Jump: 3626.235
# Reference Number: 792
# Total Log likelihood: -22935.362
# LL: -22935.362470
#
# Parameters Current Step:
# ROH In 138.037
# ROH Out 158.074
# ROH Jump: 3643.519
# Reference Number: 792
# Total Log likelihood: -22911.856
# LL: -22911.856199
#
# Parameters Current Step:
# ROH In 112.247
# ROH Out 138.253
# ROH Jump: 2958.642
# Reference Number: 792
# Total Log likelihood: -22893.480
# LL: -22893.479758
#
# Parameters Current Step:
# ROH In 102.296
# ROH Out 135.759
# ROH Jump: 2431.481
# Reference Number: 792
# Total Log likelihood: -22852.458
# LL: -22852.458057
#
# Parameters Current Step:
# ROH In 168.627
# ROH Out 203.790
# ROH Jump: 4179.012
# Reference Number: 792
# Total Log likelihood: -22898.436
# LL: -22898.435727
#
# Parameters Current Step:
# ROH In 130.464
# ROH Out 168.508
# ROH Jump: 2670.267
# Reference Number: 792
# Total Log likelihood: -22793.764
# LL: -22793.763713
#
# Parameters Current Step:
# ROH In 124.608
# ROH Out 171.142
# ROH Jump: 1922.531
# Reference Number: 792
# Total Log likelihood: -22710.778
# LL: -22710.778203
#
# Parameters Current Step:
# ROH In 125.650
# ROH Out 182.387
# ROH Jump: 2045.165
# Reference Number: 792
# Total Log likelihood: -22713.821
# LL: -22713.821140
#
# Parameters Current Step:
# ROH In 66.410
# ROH Out 122.402
# ROH Jump: 87.106
# Reference Number: 792
# Total Log likelihood: -23032.417
# LL: -23032.417385
#
# Parameters Current Step:
# ROH In 143.072
# ROH Out 183.443
# ROH Jump: 3156.036
# Reference Number: 792
# Total Log likelihood: -22821.698
# LL: -22821.697702
#
# Parameters Current Step:
# ROH In 159.924
# ROH Out 222.222
# ROH Jump: 2317.673
# Reference Number: 792
# Total Log likelihood: -22665.567
# LL: -22665.566555
#
# Parameters Current Step:
# ROH In 188.738
# ROH Out 265.453
# ROH Jump: 2260.768
# Reference Number: 792
# Total Log likelihood: -22600.163
# LL: -22600.163117
#
# Parameters Current Step:
# ROH In 149.592
# ROH Out 229.212
# ROH Jump: 996.273
# Reference Number: 792
# Total Log likelihood: -22535.809
# LL: -22535.808827
#
# Parameters Current Step:
# ROH In 152.852
# ROH Out 252.096
# ROH Jump: -83.608
#
# Parameters Current Step:
# ROH In 182.975
# ROH Out 261.485
# ROH Jump: 1407.884
# Reference Number: 792
# Total Log likelihood: -22507.334
# LL: -22507.333871
#
# Parameters Current Step:
# ROH In 211.637
# ROH Out 301.033
# ROH Jump: 1089.243
# Reference Number: 792
# Total Log likelihood: -22428.216
# LL: -22428.215504
#
# Parameters Current Step:
# ROH In 242.037
# ROH Out 359.324
# ROH Jump: 974.992
# Reference Number: 792
# Total Log likelihood: -22372.014
# LL: -22372.013782
#
# Parameters Current Step:
# ROH In 300.751
# ROH Out 453.414
# ROH Jump: 501.223
# Reference Number: 792
# Total Log likelihood: -22294.060
# LL: -22294.060455
#
# Parameters Current Step:
# ROH In 252.582
# ROH Out 390.320
# ROH Jump: -536.275
#
# Parameters Current Step:
# ROH In 204.699
# ROH Out 296.670
# ROH Jump: 1561.507
# Reference Number: 792
# Total Log likelihood: -22484.633
# LL: -22484.632722
#
# Parameters Current Step:
# ROH In 328.467
# ROH Out 471.534
# ROH Jump: 1105.042
# Reference Number: 792
# Total Log likelihood: -22297.940
# LL: -22297.939590
#
# Parameters Current Step:
# ROH In 355.871
# ROH Out 520.651
# ROH Jump: 235.498
# Reference Number: 792
# Total Log likelihood: -22282.944
# LL: -22282.943864
#
# Parameters Current Step:
# ROH In 431.457
# ROH Out 632.641
# ROH Jump: -427.506
#
# Parameters Current Step:
# ROH In 445.088
# ROH Out 662.699
# ROH Jump: 138.599
# Reference Number: 792
# Total Log likelihood: -22249.009
# LL: -22249.009423
#
# Parameters Current Step:
# ROH In 561.814
# ROH Out 843.532
# ROH Jump: -336.722
#
# Parameters Current Step:
# ROH In 406.007
# ROH Out 619.643
# ROH Jump: -521.495
#
# Parameters Current Step:
# ROH In 347.852
# ROH Out 508.561
# ROH Jump: 698.408
# Reference Number: 792
# Total Log likelihood: -22254.927
# LL: -22254.926990
#
# Parameters Current Step:
# ROH In 465.123
# ROH Out 674.526
# ROH Jump: 213.781
# Reference Number: 792
# Total Log likelihood: -22214.445
# LL: -22214.444644
#
# Parameters Current Step:
# ROH In 547.309
# ROH Out 785.082
# ROH Jump: 70.060
# Reference Number: 792
# Total Log likelihood: -22223.706
# LL: -22223.705773
#
# Parameters Current Step:
# ROH In 482.838
# ROH Out 709.873
# ROH Jump: 465.027
# Reference Number: 792
# Total Log likelihood: -22180.014
# LL: -22180.014433
#
# Parameters Current Step:
# ROH In 546.321
# ROH Out 804.484
# ROH Jump: 579.791
# Reference Number: 792
# Total Log likelihood: -22160.612
# LL: -22160.611647
#
# Parameters Current Step:
# ROH In 623.170
# ROH Out 919.246
# ROH Jump: -76.960
#
# Parameters Current Step:
# ROH In 416.681
# ROH Out 611.232
# ROH Jump: 504.566
# Reference Number: 792
# Total Log likelihood: -22209.842
# LL: -22209.842195
#
# Parameters Current Step:
# ROH In 506.995
# ROH Out 730.796
# ROH Jump: 726.826
# Reference Number: 792
# Total Log likelihood: -22177.189
# LL: -22177.189129
#
# Parameters Current Step:
# ROH In 514.875
# ROH Out 756.482
# ROH Jump: 993.675
# Reference Number: 792
# Total Log likelihood: -22198.685
# LL: -22198.684519
#
# Parameters Current Step:
# ROH In 628.780
# ROH Out 916.610
# ROH Jump: 1028.962
# Reference Number: 792
# Total Log likelihood: -22179.940
# LL: -22179.939663
#
# Parameters Current Step:
# ROH In 606.522
# ROH Out 878.111
# ROH Jump: 563.378
# Reference Number: 792
# Total Log likelihood: -22144.553
# LL: -22144.552910
#
# Parameters Current Step:
# ROH In 652.345
# ROH Out 938.926
# ROH Jump: 348.230
# Reference Number: 792
# Total Log likelihood: -22134.148
# LL: -22134.147509
#
# Parameters Current Step:
# ROH In 508.328
# ROH Out 732.861
# ROH Jump: 74.270
# Reference Number: 792
# Total Log likelihood: -22242.334
# LL: -22242.333759
#
# Parameters Current Step:
# ROH In 598.667
# ROH Out 870.672
# ROH Jump: 790.289
# Reference Number: 792
# Total Log likelihood: -22160.658
# LL: -22160.658378
#
# Parameters Current Step:
# ROH In 691.227
# ROH Out 1011.926
# ROH Jump: 418.714
# Reference Number: 792
# Total Log likelihood: -22129.495
# LL: -22129.495350
#
# Parameters Current Step:
# ROH In 783.343
# ROH Out 1152.491
# ROH Jump: 264.658
# Reference Number: 792
# Total Log likelihood: -22123.631
# LL: -22123.631153
#
# Parameters Current Step:
# ROH In 722.673
# ROH Out 1059.928
# ROH Jump: 4.831
# Reference Number: 792
# Total Log likelihood: -22193.071
# LL: -22193.070805
#
# Parameters Current Step:
# ROH In 629.668
# ROH Out 917.986
# ROH Jump: 593.924
# Reference Number: 792
# Total Log likelihood: -22142.705
# LL: -22142.705469
#
# Parameters Current Step:
# ROH In 830.583
# ROH Out 1201.784
# ROH Jump: 224.751
# Reference Number: 792
# Total Log likelihood: -22118.843
# LL: -22118.843459
#
# Parameters Current Step:
# ROH In 972.714
# ROH Out 1400.434
# ROH Jump: 47.230
# Reference Number: 792
# Total Log likelihood: -22130.904
# LL: -22130.904394
#
# Parameters Current Step:
# ROH In 881.179
# ROH Out 1277.481
# ROH Jump: -35.498
#
# Parameters Current Step:
# ROH In 692.546
# ROH Out 1007.860
# ROH Jump: 436.569
# Reference Number: 792
# Total Log likelihood: -22128.549
# LL: -22128.549443
#
# Parameters Current Step:
# ROH In 885.303
# ROH Out 1302.498
# ROH Jump: 269.088
# Reference Number: 792
# Total Log likelihood: -22118.555
# LL: -22118.555023
#
# Parameters Current Step:
# ROH In 1001.782
# ROH Out 1484.284
# ROH Jump: 229.517
# Reference Number: 792
# Total Log likelihood: -22122.347
# LL: -22122.346924
#
# Parameters Current Step:
# ROH In 973.607
# ROH Out 1429.988
# ROH Jump: 69.096
# Reference Number: 792
# Total Log likelihood: -22131.440
# LL: -22131.440226
#
# Parameters Current Step:
# ROH In 762.811
# ROH Out 1113.392
# ROH Jump: 344.701
# Reference Number: 792
# Total Log likelihood: -22121.674
# LL: -22121.674342
#
# Parameters Current Step:
# ROH In 869.122
# ROH Out 1259.292
# ROH Jump: 294.368
# Reference Number: 792
# Total Log likelihood: -22114.883
# LL: -22114.882557
#
# Parameters Current Step:
# ROH In 912.012
# ROH Out 1312.692
# ROH Jump: 309.223
# Reference Number: 792
# Total Log likelihood: -22112.535
# LL: -22112.535263
#
# Parameters Current Step:
# ROH In 989.121
# ROH Out 1431.257
# ROH Jump: 190.674
# Reference Number: 792
# Total Log likelihood: -22116.086
# LL: -22116.086194
#
# Parameters Current Step:
# ROH In 1027.040
# ROH Out 1495.847
# ROH Jump: 287.906
# Reference Number: 792
# Total Log likelihood: -22118.357
# LL: -22118.356557
#
# Parameters Current Step:
# ROH In 1066.812
# ROH Out 1524.034
# ROH Jump: 256.113
# Reference Number: 792
# Total Log likelihood: -22113.795
# LL: -22113.794821
#
# Parameters Current Step:
# ROH In 951.589
# ROH Out 1349.475
# ROH Jump: 216.101
# Reference Number: 792
# Total Log likelihood: -22109.933
# LL: -22109.933104
#
# Parameters Current Step:
# ROH In 913.864
# ROH Out 1276.289
# ROH Jump: 180.198
# Reference Number: 792
# Total Log likelihood: -22109.664
# LL: -22109.663581
#
# Parameters Current Step:
# ROH In 939.338
# ROH Out 1310.752
# ROH Jump: 306.349
# Reference Number: 792
# Total Log likelihood: -22104.718
# LL: -22104.717879
#
# Parameters Current Step:
# ROH In 914.446
# ROH Out 1250.500
# ROH Jump: 364.186
# Reference Number: 792
# Total Log likelihood: -22101.009
# LL: -22101.009420
#
# Parameters Current Step:
# ROH In 760.069
# ROH Out 1035.620
# ROH Jump: 312.958
# Reference Number: 792
# Total Log likelihood: -22111.445
# LL: -22111.445157
#
# Parameters Current Step:
# ROH In 813.575
# ROH Out 1062.247
# ROH Jump: 262.339
# Reference Number: 792
# Total Log likelihood: -22101.487
# LL: -22101.486517
#
# Parameters Current Step:
# ROH In 1001.187
# ROH Out 1357.070
# ROH Jump: 224.857
# Reference Number: 792
# Total Log likelihood: -22098.254
# LL: -22098.254039
#
# Parameters Current Step:
# ROH In 1121.746
# ROH Out 1517.795
# ROH Jump: 180.807
# Reference Number: 792
# Total Log likelihood: -22100.321
# LL: -22100.320945
#
# Parameters Current Step:
# ROH In 905.608
# ROH Out 1170.256
# ROH Jump: 387.390
# Reference Number: 792
# Total Log likelihood: -22090.347
# LL: -22090.347192
#
# Parameters Current Step:
# ROH In 901.480
# ROH Out 1117.240
# ROH Jump: 490.987
# Reference Number: 792
# Total Log likelihood: -22086.733
# LL: -22086.732913
#
# Parameters Current Step:
# ROH In 1064.501
# ROH Out 1420.960
# ROH Jump: 457.682
# Reference Number: 792
# Total Log likelihood: -22101.162
# LL: -22101.161879
#
# Parameters Current Step:
# ROH In 1001.770
# ROH Out 1331.281
# ROH Jump: 408.846
# Reference Number: 792
# Total Log likelihood: -22095.552
# LL: -22095.551570
#
# Parameters Current Step:
# ROH In 1021.845
# ROH Out 1286.561
# ROH Jump: 385.607
# Reference Number: 792
# Total Log likelihood: -22082.431
# LL: -22082.430969
#
# Parameters Current Step:
# ROH In 1075.545
# ROH Out 1304.592
# ROH Jump: 396.317
# Reference Number: 792
# Total Log likelihood: -22074.947
# LL: -22074.947095
#
# Parameters Current Step:
# ROH In 984.676
# ROH Out 1145.005
# ROH Jump: 639.242
# Reference Number: 792
# Total Log likelihood: -22082.465
# LL: -22082.464638
#
# Parameters Current Step:
# ROH In 972.697
# ROH Out 1046.610
# ROH Jump: 608.851
# Reference Number: 792
# Total Log likelihood: -22070.341
# LL: -22070.341031
#
# Parameters Current Step:
# ROH In 958.161
# ROH Out 904.274
# ROH Jump: 708.854
# Reference Number: 792
# Total Log likelihood: -22069.378
# LL: -22069.377908
#
# Parameters Current Step:
# ROH In 1110.774
# ROH Out 1118.674
# ROH Jump: 671.956
# Reference Number: 792
# Total Log likelihood: -22061.811
# LL: -22061.811211
#
# Parameters Current Step:
# ROH In 1215.421
# ROH Out 1119.390
# ROH Jump: 762.440
# Reference Number: 792
# Total Log likelihood: -22058.184
# LL: -22058.184388
#
# Parameters Current Step:
# ROH In 1181.409
# ROH Out 1073.832
# ROH Jump: 605.832
# Reference Number: 792
# Total Log likelihood: -22045.540
# LL: -22045.540342
#
# Parameters Current Step:
# ROH In 1279.776
# ROH Out 1038.245
# ROH Jump: 589.127
# Reference Number: 792
# Total Log likelihood: -22036.054
# LL: -22036.054337
#
# Parameters Current Step:
# ROH In 1226.695
# ROH Out 736.682
# ROH Jump: 977.298
# Reference Number: 792
# Total Log likelihood: -22087.225
# LL: -22087.224820
#
# Parameters Current Step:
# ROH In 1113.332
# ROH Out 1162.614
# ROH Jump: 541.562
# Reference Number: 792
# Total Log likelihood: -22056.809
# LL: -22056.809474
#
# Parameters Current Step:
# ROH In 1447.525
# ROH Out 1309.226
# ROH Jump: 553.232
# Reference Number: 792
# Total Log likelihood: -22038.952
# LL: -22038.952277
#
# Parameters Current Step:
# ROH In 1345.001
# ROH Out 1220.667
# ROH Jump: 360.174
# Reference Number: 792
# Total Log likelihood: -22029.371
# LL: -22029.371012
#
# Parameters Current Step:
# ROH In 1409.791
# ROH Out 1271.305
# ROH Jump: 159.041
# Reference Number: 792
# Total Log likelihood: -22030.207
# LL: -22030.206617
#
# Parameters Current Step:
# ROH In 1601.536
# ROH Out 1216.145
# ROH Jump: 460.127
# Reference Number: 792
# Total Log likelihood: -22020.973
# LL: -22020.972686
#
# Parameters Current Step:
# ROH In 1845.638
# ROH Out 1242.910
# ROH Jump: 419.409
# Reference Number: 792
# Total Log likelihood: -22018.789
# LL: -22018.788913
#
# Parameters Current Step:
# ROH In 1532.752
# ROH Out 1025.322
# ROH Jump: 359.241
# Reference Number: 792
# Total Log likelihood: -22023.156
# LL: -22023.155849
#
# Parameters Current Step:
# ROH In 1869.151
# ROH Out 1287.687
# ROH Jump: 170.089
# Reference Number: 792
# Total Log likelihood: -22016.072
# LL: -22016.071629
#
# Parameters Current Step:
# ROH In 2163.838
# ROH Out 1412.408
# ROH Jump: -39.430
#
# Parameters Current Step:
# ROH In 2153.359
# ROH Out 1149.946
# ROH Jump: 272.319
# Reference Number: 792
# Total Log likelihood: -22034.572
# LL: -22034.571745
#
# Parameters Current Step:
# ROH In 1547.091
# ROH Out 1202.987
# ROH Jump: 338.210
# Reference Number: 792
# Total Log likelihood: -22017.807
# LL: -22017.806944
#
# Parameters Current Step:
# ROH In 1975.168
# ROH Out 1463.734
# ROH Jump: 259.231
# Reference Number: 792
# Total Log likelihood: -22017.011
# LL: -22017.010739
#
# Parameters Current Step:
# ROH In 1748.635
# ROH Out 1393.362
# ROH Jump: 92.278
# Reference Number: 792
# Total Log likelihood: -22021.695
# LL: -22021.695114
#
# Parameters Current Step:
# ROH In 1821.387
# ROH Out 1280.523
# ROH Jump: 337.626
# Reference Number: 792
# Total Log likelihood: -22015.390
# LL: -22015.389990
#
# Parameters Current Step:
# ROH In 2230.047
# ROH Out 1484.977
# ROH Jump: 173.087
# Reference Number: 792
# Total Log likelihood: -22018.916
# LL: -22018.916470
#
# Parameters Current Step:
# ROH In 1717.830
# ROH Out 1273.484
# ROH Jump: 296.930
# Reference Number: 792
# Total Log likelihood: -22014.855
# LL: -22014.855191
#
# Parameters Current Step:
# ROH In 1630.411
# ROH Out 1097.396
# ROH Jump: 277.199
# Reference Number: 792
# Total Log likelihood: -22019.573
# LL: -22019.573428
#
# Parameters Current Step:
# ROH In 1888.978
# ROH Out 1372.150
# ROH Jump: 263.723
# Reference Number: 792
# Total Log likelihood: -22014.776
# LL: -22014.776056
#
# Parameters Current Step:
# ROH In 1749.646
# ROH Out 1329.751
# ROH Jump: 428.764
# Reference Number: 792
# Total Log likelihood: -22020.398
# LL: -22020.398170
#
# Parameters Current Step:
# ROH In 1839.275
# ROH Out 1298.203
# ROH Jump: 234.758
# Reference Number: 792
# Total Log likelihood: -22014.266
# LL: -22014.265562
#
# Parameters Current Step:
# ROH In 1809.335
# ROH Out 1348.701
# ROH Jump: 192.647
# Reference Number: 792
# Total Log likelihood: -22015.022
# LL: -22015.021808
#
# Parameters Current Step:
# ROH In 1812.348
# ROH Out 1331.657
# ROH Jump: 228.892
# Reference Number: 792
# Total Log likelihood: -22014.367
# LL: -22014.367012
#
# Parameters Current Step:
# ROH In 1975.904
# ROH Out 1394.522
# ROH Jump: 187.986
# Reference Number: 792
# Total Log likelihood: -22015.111
# LL: -22015.111190
#
# Parameters Current Step:
# ROH In 1782.348
# ROH Out 1303.744
# ROH Jump: 269.694
# Reference Number: 792
# Total Log likelihood: -22014.339
# LL: -22014.338675
#
# Parameters Current Step:
# ROH In 1733.669
# ROH Out 1250.253
# ROH Jump: 225.172
# Reference Number: 792
# Total Log likelihood: -22014.988
# LL: -22014.987996
#
# Parameters Current Step:
# ROH In 1850.151
# ROH Out 1341.675
# ROH Jump: 254.085
# Reference Number: 792
# Total Log likelihood: -22014.320
# LL: -22014.320121
#
# Parameters Current Step:
# ROH In 1835.501
# ROH Out 1297.425
# ROH Jump: 276.799
# Reference Number: 792
# Total Log likelihood: -22014.312
# LL: -22014.311847
#
# Parameters Current Step:
# ROH In 1900.936
# ROH Out 1321.125
# ROH Jump: 240.735
# Reference Number: 792
# Total Log likelihood: -22014.399
# LL: -22014.398850
#
# Parameters Current Step:
# ROH In 1811.995
# ROH Out 1308.089
# ROH Jump: 262.454
# Reference Number: 792
# Total Log likelihood: -22014.206
# LL: -22014.205792
#
# Parameters Current Step:
# ROH In 1807.697
# ROH Out 1260.803
# ROH Jump: 261.922
# Reference Number: 792
# Total Log likelihood: -22014.476
# LL: -22014.476486
#
# Parameters Current Step:
# ROH In 1839.537
# ROH Out 1321.457
# ROH Jump: 256.044
# Reference Number: 792
# Total Log likelihood: -22014.195
# LL: -22014.195288
#
# Parameters Current Step:
# ROH In 1825.037
# ROH Out 1321.075
# ROH Jump: 225.372
# Reference Number: 792
# Total Log likelihood: -22014.270
# LL: -22014.269954
#
# Parameters Current Step:
# ROH In 1827.653
# ROH Out 1315.162
# ROH Jump: 238.228
# Reference Number: 792
# Total Log likelihood: -22014.179
# LL: -22014.178665
#
# Parameters Current Step:
# ROH In 1813.516
# ROH Out 1331.603
# ROH Jump: 269.727
# Reference Number: 792
# Total Log likelihood: -22014.469
# LL: -22014.469002
#
# Parameters Current Step:
# ROH In 1832.835
# ROH Out 1306.553
# ROH Jump: 243.500
# Reference Number: 792
# Total Log likelihood: -22014.167
# LL: -22014.167199
#
# Parameters Current Step:
# ROH In 1854.688
# ROH Out 1320.693
# ROH Jump: 229.395
# Reference Number: 792
# Total Log likelihood: -22014.221
# LL: -22014.221437
#
# Parameters Current Step:
# ROH In 1822.669
# ROH Out 1311.240
# ROH Jump: 254.189
# Reference Number: 792
# Total Log likelihood: -22014.168
# LL: -22014.168360
#
# Parameters Current Step:
# ROH In 1815.900
# ROH Out 1300.513
# ROH Jump: 234.567
# Reference Number: 792
# Total Log likelihood: -22014.226
# LL: -22014.225943
#
# Parameters Current Step:
# ROH In 1833.628
# ROH Out 1316.221
# ROH Jump: 250.675
# Reference Number: 792
# Total Log likelihood: -22014.164
# LL: -22014.164207
#
# Parameters Current Step:
# ROH In 1831.768
# ROH Out 1307.514
# ROH Jump: 260.681
# Reference Number: 792
# Total Log likelihood: -22014.183
# LL: -22014.183154
#
# Parameters Current Step:
# ROH In 1828.682
# ROH Out 1313.250
# ROH Jump: 243.842
# Reference Number: 792
# Total Log likelihood: -22014.161
# LL: -22014.161489
#
# Parameters Current Step:
# ROH In 1840.761
# ROH Out 1312.776
# ROH Jump: 237.822
# Reference Number: 792
# Total Log likelihood: -22014.178
# LL: -22014.178233
#
# Parameters Current Step:
# ROH In 1827.192
# ROH Out 1311.624
# ROH Jump: 250.097
# Reference Number: 792
# Total Log likelihood: -22014.159
# LL: -22014.158582
#
# Parameters Current Step:
# ROH In 1826.833
# ROH Out 1320.844
# ROH Jump: 252.909
# Reference Number: 792
# Total Log likelihood: -22014.197
# LL: -22014.196875
#
# Parameters Current Step:
# ROH In 1831.334
# ROH Out 1310.126
# ROH Jump: 245.852
# Reference Number: 792
# Total Log likelihood: -22014.157
# LL: -22014.157190
#
# Parameters Current Step:
# ROH In 1824.510
# ROH Out 1307.112
# ROH Jump: 242.519
# Reference Number: 792
# Total Log likelihood: -22014.167
# LL: -22014.166840
#
# Parameters Current Step:
# ROH In 1831.349
# ROH Out 1313.944
# ROH Jump: 248.636
# Reference Number: 792
# Total Log likelihood: -22014.159
# LL: -22014.158601
#
# Parameters Current Step:
# ROH In 1831.235
# ROH Out 1310.546
# ROH Jump: 252.549
# Reference Number: 792
# Total Log likelihood: -22014.159
# LL: -22014.159448
#
# Parameters Current Step:
# ROH In 1830.597
# ROH Out 1311.222
# ROH Jump: 250.372
# Reference Number: 792
# Total Log likelihood: -22014.157
# LL: -22014.157085
#
# Parameters Current Step:
# ROH In 1828.066
# ROH Out 1308.037
# ROH Jump: 248.912
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156124
#
# Parameters Current Step:
# ROH In 1826.425
# ROH Out 1305.084
# ROH Jump: 249.050
# Reference Number: 792
# Total Log likelihood: -22014.158
# LL: -22014.158448
#
# Parameters Current Step:
# ROH In 1832.806
# ROH Out 1307.966
# ROH Jump: 246.660
# Reference Number: 792
# Total Log likelihood: -22014.159
# LL: -22014.159084
#
# Parameters Current Step:
# ROH In 1828.595
# ROH Out 1310.709
# ROH Jump: 249.238
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156446
#
# Parameters Current Step:
# ROH In 1826.838
# ROH Out 1309.853
# ROH Jump: 253.162
# Reference Number: 792
# Total Log likelihood: -22014.160
# LL: -22014.160498
#
# Parameters Current Step:
# ROH In 1830.210
# ROH Out 1310.058
# ROH Jump: 247.680
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155936
#
# Parameters Current Step:
# ROH In 1827.318
# ROH Out 1307.981
# ROH Jump: 246.848
# Reference Number: 792
# Total Log likelihood: -22014.157
# LL: -22014.157262
#
# Parameters Current Step:
# ROH In 1829.777
# ROH Out 1310.412
# ROH Jump: 249.491
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156137
#
# Parameters Current Step:
# ROH In 1830.107
# ROH Out 1308.295
# ROH Jump: 248.150
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156458
#
# Parameters Current Step:
# ROH In 1828.973
# ROH Out 1310.106
# ROH Jump: 248.966
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155976
#
# Parameters Current Step:
# ROH In 1828.390
# ROH Out 1308.389
# ROH Jump: 247.547
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156456
#
# Parameters Current Step:
# ROH In 1829.430
# ROH Out 1309.906
# ROH Jump: 249.005
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155876
#
# Parameters Current Step:
# ROH In 1831.009
# ROH Out 1312.009
# ROH Jump: 248.189
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156428
#
# Parameters Current Step:
# ROH In 1828.802
# ROH Out 1309.030
# ROH Jump: 248.731
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155872
#
# Parameters Current Step:
# ROH In 1829.988
# ROH Out 1309.223
# ROH Jump: 247.978
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156000
#
# Parameters Current Step:
# ROH In 1829.227
# ROH Out 1309.885
# ROH Jump: 248.719
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155856
#
# Parameters Current Step:
# ROH In 1828.096
# ROH Out 1309.156
# ROH Jump: 249.957
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.156179
#
# Parameters Current Step:
# ROH In 1829.682
# ROH Out 1309.832
# ROH Jump: 248.249
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155832
#
# Parameters Current Step:
# ROH In 1829.044
# ROH Out 1309.259
# ROH Jump: 248.128
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155921
#
# Parameters Current Step:
# ROH In 1829.334
# ROH Out 1309.744
# ROH Jump: 248.786
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155833
#
# Parameters Current Step:
# ROH In 1830.026
# ROH Out 1310.611
# ROH Jump: 248.438
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155916
#
# Parameters Current Step:
# ROH In 1829.108
# ROH Out 1309.425
# ROH Jump: 248.658
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155832
#
# Parameters Current Step:
# ROH In 1829.522
# ROH Out 1309.449
# ROH Jump: 248.409
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155837
#
# Parameters Current Step:
# ROH In 1829.448
# ROH Out 1309.558
# ROH Jump: 248.487
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155822
#
# Parameters Current Step:
# ROH In 1829.492
# ROH Out 1309.466
# ROH Jump: 248.143
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155878
#
# Parameters Current Step:
# ROH In 1829.373
# ROH Out 1309.675
# ROH Jump: 248.625
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155820
#
# Parameters Current Step:
# ROH In 1829.894
# ROH Out 1309.952
# ROH Jump: 248.250
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155826
#
# Parameters Current Step:
# ROH In 1829.462
# ROH Out 1309.624
# ROH Jump: 248.659
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155816
#
# Parameters Current Step:
# ROH In 1829.352
# ROH Out 1309.520
# ROH Jump: 248.863
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155828
#
# Parameters Current Step:
# ROH In 1828.961
# ROH Out 1309.287
# ROH Jump: 248.931
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155849
#
# Parameters Current Step:
# ROH In 1829.661
# ROH Out 1309.785
# ROH Jump: 248.420
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155817
#
# Parameters Current Step:
# ROH In 1829.549
# ROH Out 1309.831
# ROH Jump: 248.649
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155820
#
# Parameters Current Step:
# ROH In 1829.741
# ROH Out 1309.819
# ROH Jump: 248.526
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155811
#
# Parameters Current Step:
# ROH In 1829.925
# ROH Out 1309.891
# ROH Jump: 248.477
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1829.816
# ROH Out 1309.703
# ROH Jump: 248.388
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155818
#
# Parameters Current Step:
# ROH In 1829.749
# ROH Out 1309.735
# ROH Jump: 248.453
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155813
#
# Parameters Current Step:
# ROH In 1829.763
# ROH Out 1309.715
# ROH Jump: 248.639
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1830.163
# ROH Out 1309.936
# ROH Jump: 248.388
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155813
#
# Parameters Current Step:
# ROH In 1829.988
# ROH Out 1309.858
# ROH Jump: 248.456
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1830.035
# ROH Out 1309.908
# ROH Jump: 248.595
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1829.964
# ROH Out 1309.865
# ROH Jump: 248.559
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1830.154
# ROH Out 1310.028
# ROH Jump: 248.355
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155815
#
# Parameters Current Step:
# ROH In 1829.861
# ROH Out 1309.793
# ROH Jump: 248.568
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.845
# ROH Out 1309.841
# ROH Jump: 248.614
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1829.881
# ROH Out 1309.845
# ROH Jump: 248.575
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.879
# ROH Out 1309.778
# ROH Jump: 248.658
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155810
#
# Parameters Current Step:
# ROH In 1829.913
# ROH Out 1309.863
# ROH Jump: 248.522
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.945
# ROH Out 1309.835
# ROH Jump: 248.525
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.976
# ROH Out 1309.830
# ROH Jump: 248.501
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.933
# ROH Out 1309.799
# ROH Jump: 248.580
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.928
# ROH Out 1309.815
# ROH Jump: 248.565
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.859
# ROH Out 1309.764
# ROH Jump: 248.547
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.937
# ROH Out 1309.839
# ROH Jump: 248.556
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1830.012
# ROH Out 1309.867
# ROH Jump: 248.530
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.899
# ROH Out 1309.811
# ROH Jump: 248.559
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.898
# ROH Out 1309.809
# ROH Jump: 248.595
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.933
# ROH Out 1309.828
# ROH Jump: 248.543
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.918
# ROH Out 1309.838
# ROH Jump: 248.540
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.925
# ROH Out 1309.821
# ROH Jump: 248.559
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.901
# ROH Out 1309.801
# ROH Jump: 248.551
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.928
# ROH Out 1309.830
# ROH Jump: 248.555
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.902
# ROH Out 1309.813
# ROH Jump: 248.572
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155809
#
# Parameters Current Step:
# ROH In 1829.925
# ROH Out 1309.825
# ROH Jump: 248.550
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.954
# ROH Out 1309.839
# ROH Jump: 248.551
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.913
# ROH Out 1309.818
# ROH Jump: 248.557
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.919
# ROH Out 1309.828
# ROH Jump: 248.549
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.914
# ROH Out 1309.826
# ROH Jump: 248.557
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.902
# ROH Out 1309.818
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.922
# ROH Out 1309.827
# ROH Jump: 248.554
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.914
# ROH Out 1309.820
# ROH Jump: 248.563
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.917
# ROH Out 1309.826
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.923
# ROH Out 1309.819
# ROH Jump: 248.550
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.927
# ROH Out 1309.831
# ROH Jump: 248.549
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.916
# ROH Out 1309.821
# ROH Jump: 248.555
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.921
# ROH Out 1309.821
# ROH Jump: 248.555
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.918
# ROH Out 1309.824
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.915
# ROH Out 1309.818
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.825
# ROH Jump: 248.554
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.923
# ROH Out 1309.825
# ROH Jump: 248.551
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.918
# ROH Out 1309.822
# ROH Jump: 248.554
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.919
# ROH Out 1309.823
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.823
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.918
# ROH Out 1309.821
# ROH Jump: 248.554
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.921
# ROH Out 1309.823
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.921
# ROH Out 1309.823
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.823
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.919
# ROH Out 1309.821
# ROH Jump: 248.553
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.822
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
#
# Parameters Current Step:
# ROH In 1829.920
# ROH Out 1309.821
# ROH Jump: 248.552
# Reference Number: 792
# Total Log likelihood: -22014.156
# LL: -22014.155808
# Optimization terminated successfully.
#          Current function value: 22014.155808
#          Iterations: 152
#          Function evaluations: 290

# %% [markdown]
# # Optimize LL for TSI copies
# Idea: Have array of hmms [hmm, hmm1, ... ]. The LL Function updates the jump parameters, and calculates the total ll in parallel

# %% [markdown]
# ### 1) Load HDF5

# %%
h5_path = "Simulated/1000G_Mosaic/TSI0/ch3/data.h5"  ### Which HDF to look into
f = h5py.File(h5_path, "r") # Load for Sanity Check. See below!
samples = f["samples"][:]

print(f"Loaded {len(samples)} targets")
# Out:
# Loaded 107 targets

# %% [markdown]
# ### 2) Prepare HMM Object vector hmms

# %%
# %%time
n_lls = 20 # How many Individuals to use from target
ch=3
n_ref=503
path_mosaic = "./Simulated/1000G_Mosaic/TSI0/ch3/"
exclude_pops = ["TSI", ]

### Load all TSI hmm workers
hmms = [prep_hmm_object(path_mosaic, exclude_pops=exclude_pops, iid=iid, 
                        ch=ch, n_ref=n_ref) for iid in samples[:n_lls]]
# Out:
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
# CPU times: user 3min 9s, sys: 2.23 s, total: 3min 11s
# Wall time: 3min 13s

# %%
### Some Functions for Printing of output
org_print = sys.stdout
def blockPrint():
    """Block Printing to Console"""
    sys.stdout = open(os.devnull, 'w')

# Restore
def enablePrint():
    """Reanable Printing to Console"""
    sys.stdout = org_print

### Likelihood Functions
def ll_worker(hmm, roh_in, roh_out, roh_jump):
    """Update Parameters, and calculate Likelihood for worker hmm"""
    hmm.t_obj.set_params(roh_in=roh_in, roh_out=roh_out, roh_jump=roh_jump) # Set the Parameters
    _, _, _, ll = hmm.calc_posterior(save = False, full = True)  # Calculate the LL
    return ll

def ll_mosaic_individuals(prms):
    """Calculate the log likelihood of Mosaic individual.
    ASSUME THAT hmms [:] array IS INITIALIZED PROPERLY!!!
    global parameter 'procses' determines number of parallel Processes"""
    roh_in, roh_out, roh_jump = prms
    print("\nParameters Current Step:")
    print(f"ROH In {roh_in:.3f}")
    print(f"ROH Out {roh_out:.3f}")
    print(f"ROH Jump: {roh_jump:.3f}")
    
    ### Return infinite value for infeasible params:
    if np.min(prms)<0:   
        return np.inf 
    
    ### Prepare the Parameter Array:
    arguments = [[hmm0, roh_in, roh_out, roh_jump] for hmm0 in hmms]
    
    
    ### Do the Multiprocessing
    blockPrint()
    ll_vec = multi_run(ll_worker, arguments, procses)
    enablePrint()
    
    tot_ll = np.sum(ll_vec)
    print(f"Mean LL: {np.mean(ll_vec)}")
    print(f"STD LL: {np.std(ll_vec)}")
    print(f"Sum LL: {tot_ll:.8f}")
    
    return -tot_ll  # Return Negetive one (for minimization)

def multi_run(fun, prms, processes = 4):
    """Implementation of running in Parallel.
    fun: Function
    prms: The Parameter Files
    processes: How many Processes to use"""
    print(f"Running {len(prms)} jobs in parallel.")
    
    with mp.Pool(processes = processes) as pool:
        results = pool.starmap(fun, prms)
    return results

# %%
# %%time
### Run the Optimization (hmms array needs to be initialized!!)
procses = 10 ### How many processes in parallel 

x0 = np.array([2500, 2500, 200])  # The Starting Value (chosen according to single run)
res = minimize(ll_mosaic_individuals, x0, method='nelder-mead', options={'fatol': 1e-1, 'disp': True})
# Out:
# Parameters Current Step:
# ROH In 2500.000
# ROH Out 2500.000
# ROH Jump: 200.000
# Mean LL: -25580.235358344504
# STD LL: 396.0469902531018
# Sum LL: -511604.70716689
#
# Parameters Current Step:
# ROH In 2625.000
# ROH Out 2500.000
# ROH Jump: 200.000
# Mean LL: -25579.499445558024
# STD LL: 396.9173172558023
# Sum LL: -511589.98891116
#
# Parameters Current Step:
# ROH In 2500.000
# ROH Out 2625.000
# ROH Jump: 200.000
# Mean LL: -25581.46306689112
# STD LL: 394.3694720260241
# Sum LL: -511629.26133782
#
# Parameters Current Step:
# ROH In 2500.000
# ROH Out 2500.000
# ROH Jump: 210.000
# Mean LL: -25580.192168559275
# STD LL: 396.05219142731374
# Sum LL: -511603.84337119
#
# Parameters Current Step:
# ROH In 2583.333
# ROH Out 2375.000
# ROH Jump: 206.667
# Mean LL: -25581.34239427759
# STD LL: 398.3653618777517
# Sum LL: -511626.84788555
#
# Parameters Current Step:
# ROH In 2562.500
# ROH Out 2437.500
# ROH Jump: 205.000
# Mean LL: -25580.162532089817
# STD LL: 397.34677086970055
# Sum LL: -511603.25064180
#
# Parameters Current Step:
# ROH In 2625.000
# ROH Out 2458.333
# ROH Jump: 210.000
# Mean LL: -25579.92680815801
# STD LL: 397.4951346114033
# Sum LL: -511598.53616316
#
# Parameters Current Step:
# ROH In 2708.333
# ROH Out 2430.556
# ROH Jump: 200.000
# Mean LL: -25581.189389502644
# STD LL: 398.44750776745116
# Sum LL: -511623.78779005
#
# Parameters Current Step:
# ROH In 2552.083
# ROH Out 2482.639
# ROH Jump: 207.500
# Mean LL: -25579.785798024597
# STD LL: 396.6536382716589
# Sum LL: -511595.71596049
#
# Parameters Current Step:
# ROH In 2638.889
# ROH Out 2523.148
# ROH Jump: 206.667
# Mean LL: -25579.28875562184
# STD LL: 396.6987551975215
# Sum LL: -511585.77511244
#
# Parameters Current Step:
# ROH In 2677.083
# ROH Out 2565.972
# ROH Jump: 207.500
# Mean LL: -25579.041835420572
# STD LL: 396.3756748492323
# Sum LL: -511580.83670841
#
# Parameters Current Step:
# ROH In 2611.111
# ROH Out 2574.074
# ROH Jump: 200.000
# Mean LL: -25579.331437739664
# STD LL: 395.8160357421398
# Sum LL: -511586.62875479
#
# Parameters Current Step:
# ROH In 2723.380
# ROH Out 2610.725
# ROH Jump: 197.500
# Mean LL: -25578.91657629556
# STD LL: 396.07794882821435
# Sum LL: -511578.33152591
#
# Parameters Current Step:
# ROH In 2809.028
# ROH Out 2674.769
# ROH Jump: 192.500
# Mean LL: -25578.92850582063
# STD LL: 395.7812819432364
# Sum LL: -511578.57011641
#
# Parameters Current Step:
# ROH In 2716.049
# ROH Out 2667.181
# ROH Jump: 203.333
# Mean LL: -25579.09221875295
# STD LL: 395.2767190736991
# Sum LL: -511581.84437506
#
# Parameters Current Step:
# ROH In 2799.897
# ROH Out 2655.178
# ROH Jump: 205.556
# Mean LL: -25578.919871767877
# STD LL: 395.9867266316224
# Sum LL: -511578.39743536
#
# Parameters Current Step:
# ROH In 2750.857
# ROH Out 2554.070
# ROH Jump: 203.704
# Mean LL: -25579.3131140628
# STD LL: 397.02960510446934
# Sum LL: -511586.26228126
#
# Parameters Current Step:
# ROH In 2724.751
# ROH Out 2638.903
# ROH Jump: 203.426
# Mean LL: -25578.926763811894
# STD LL: 395.71111671282335
# Sum LL: -511578.53527624
#
# Parameters Current Step:
# ROH In 2821.602
# ROH Out 2703.899
# ROH Jump: 196.821
# Mean LL: -25578.99688449158
# STD LL: 395.47677454616235
# Sum LL: -511579.93768983
#
# Parameters Current Step:
# ROH In 2785.472
# ROH Out 2669.417
# ROH Jump: 199.491
# Mean LL: -25578.907998623803
# STD LL: 395.70144691704394
# Sum LL: -511578.15997248
#
# Parameters Current Step:
# ROH In 2814.415
# ROH Out 2651.311
# ROH Jump: 198.272
# Mean LL: -25578.965774363973
# STD LL: 396.13118082901065
# Sum LL: -511579.31548728
#
# Parameters Current Step:
# ROH In 2747.167
# ROH Out 2642.005
# ROH Jump: 202.137
# Mean LL: -25578.890466250938
# STD LL: 395.81722186696874
# Sum LL: -511577.80932502
#
# Parameters Current Step:
# ROH In 2704.116
# ROH Out 2626.253
# ROH Jump: 193.863
# Mean LL: -25578.967752058998
# STD LL: 395.7401047112327
# Sum LL: -511579.35504118
#
# Parameters Current Step:
# ROH In 2775.952
# ROH Out 2647.947
# ROH Jump: 202.632
# Mean LL: -25578.88873105983
# STD LL: 395.9267271539613
# Sum LL: -511577.77462120
#
# Parameters Current Step:
# ROH In 2815.681
# ROH Out 2695.521
# ROH Jump: 205.340
# Mean LL: -25578.981982107845
# STD LL: 395.55135833014333
# Sum LL: -511579.63964216
#
# Parameters Current Step:
# ROH In 2746.455
# ROH Out 2631.924
# ROH Jump: 199.460
# Mean LL: -25578.886986726466
# STD LL: 395.9467344555432
# Sum LL: -511577.73973453
#
# Parameters Current Step:
# ROH In 2727.577
# ROH Out 2611.834
# ROH Jump: 203.329
# Mean LL: -25578.905437896832
# STD LL: 396.0927823454759
# Sum LL: -511578.10875794
#
# Parameters Current Step:
# ROH In 2742.051
# ROH Out 2626.230
# ROH Jump: 202.370
# Mean LL: -25578.888501262227
# STD LL: 395.994891918124
# Sum LL: -511577.77002524
#
# Parameters Current Step:
# ROH In 2762.471
# ROH Out 2628.729
# ROH Jump: 200.837
# Mean LL: -25578.894868459764
# STD LL: 396.09543434406686
# Sum LL: -511577.89736920
#
# Parameters Current Step:
# ROH In 2750.993
# ROH Out 2638.686
# ROH Jump: 201.812
# Mean LL: -25578.884728120636
# STD LL: 395.88673160271605
# Sum LL: -511577.69456241
#
# Parameters Current Step:
# ROH In 2717.048
# ROH Out 2616.613
# ROH Jump: 199.796
# Mean LL: -25578.91694477318
# STD LL: 395.9575715113256
# Sum LL: -511578.33889546
#
# Parameters Current Step:
# ROH In 2761.226
# ROH Out 2640.114
# ROH Jump: 201.923
# Mean LL: -25578.883098693033
# STD LL: 395.9349084428735
# Sum LL: -511577.66197386
#
# Parameters Current Step:
# ROH In 2763.732
# ROH Out 2647.586
# ROH Jump: 199.761
# Mean LL: -25578.885217206975
# STD LL: 395.85078029761286
# Sum LL: -511577.70434414
#
# Parameters Current Step:
# ROH In 2770.845
# ROH Out 2652.333
# ROH Jump: 202.871
# Mean LL: -25578.88810093402
# STD LL: 395.83473701173494
# Sum LL: -511577.76201868
#
# Parameters Current Step:
# ROH In 2752.553
# ROH Out 2637.026
# ROH Jump: 200.313
# Mean LL: -25578.884176981097
# STD LL: 395.9187970599421
# Sum LL: -511577.68353962
#
# Parameters Current Step:
# ROH In 2746.116
# ROH Out 2629.631
# ROH Jump: 202.938
# Mean LL: -25578.88571047452
# STD LL: 395.9762383655978
# Sum LL: -511577.71420949
#
# Parameters Current Step:
# ROH In 2759.328
# ROH Out 2643.097
# ROH Jump: 200.555
# Mean LL: -25578.88376122016
# STD LL: 395.8821364668322
# Sum LL: -511577.67522440
#
# Parameters Current Step:
# ROH In 2764.411
# ROH Out 2641.472
# ROH Jump: 200.048
# Mean LL: -25578.884156271724
# STD LL: 395.93711570879594
# Sum LL: -511577.68312543
#
# Parameters Current Step:
# ROH In 2770.757
# ROH Out 2646.096
# ROH Jump: 201.372
# Mean LL: -25578.885705540764
# STD LL: 395.91718988913084
# Sum LL: -511577.71411082
#
# Parameters Current Step:
# ROH In 2757.104
# ROH Out 2639.294
# ROH Jump: 200.578
# Mean LL: -25578.883331059966
# STD LL: 395.91844243172045
# Sum LL: -511577.66662120
#
# Parameters Current Step:
# ROH In 2754.027
# ROH Out 2640.198
# ROH Jump: 201.989
# Mean LL: -25578.88393288992
# STD LL: 395.8865028061287
# Sum LL: -511577.67865780
#
# Parameters Current Step:
# ROH In 2756.623
# ROH Out 2640.516
# ROH Jump: 201.504
# Mean LL: -25578.883318546163
# STD LL: 395.8991719574916
# Sum LL: -511577.66637092
#
# Parameters Current Step:
# ROH In 2757.307
# ROH Out 2636.852
# ROH Jump: 202.115
# Mean LL: -25578.883112710777
# STD LL: 395.9529082404421
# Sum LL: -511577.66225422
#
# Parameters Current Step:
# ROH In 2759.667
# ROH Out 2639.027
# ROH Jump: 203.117
# Mean LL: -25578.882840193524
# STD LL: 395.93952772580553
# Sum LL: -511577.65680387
#
# Parameters Current Step:
# ROH In 2760.949
# ROH Out 2638.894
# ROH Jump: 204.386
# Mean LL: -25578.883098409988
# STD LL: 395.95003733511055
# Sum LL: -511577.66196820
#
# Parameters Current Step:
# ROH In 2762.177
# ROH Out 2636.812
# ROH Jump: 203.266
# Mean LL: -25578.88435016347
# STD LL: 395.9857247633513
# Sum LL: -511577.68700327
#
# Parameters Current Step:
# ROH In 2758.012
# ROH Out 2639.590
# ROH Jump: 201.944
# Mean LL: -25578.882905353013
# STD LL: 395.920811635184
# Sum LL: -511577.65810706
#
# Parameters Current Step:
# ROH In 2761.962
# ROH Out 2642.302
# ROH Jump: 202.542
# Mean LL: -25578.88312899517
# STD LL: 395.9105986749677
# Sum LL: -511577.66257990
#
# Parameters Current Step:
# ROH In 2758.471
# ROH Out 2638.214
# ROH Jump: 202.221
# Mean LL: -25578.882932987406
# STD LL: 395.94232972074406
# Sum LL: -511577.65865975
#
# Parameters Current Step:
# ROH In 2756.207
# ROH Out 2637.774
# ROH Jump: 202.932
# Mean LL: -25578.88280624219
# STD LL: 395.9335314684268
# Sum LL: -511577.65612484
#
# Parameters Current Step:
# ROH In 2753.698
# ROH Out 2636.604
# ROH Jump: 203.436
# Mean LL: -25578.88301379275
# STD LL: 395.93282937811495
# Sum LL: -511577.66027586
#
# Parameters Current Step:
# ROH In 2757.453
# ROH Out 2639.380
# ROH Jump: 203.107
# Mean LL: -25578.88278086163
# STD LL: 395.9202546682076
# Sum LL: -511577.65561723
#
# Parameters Current Step:
# ROH In 2756.944
# ROH Out 2639.963
# ROH Jump: 203.550
# Mean LL: -25578.88293001691
# STD LL: 395.90921553194073
# Sum LL: -511577.65860034
#
# Parameters Current Step:
# ROH In 2757.540
# ROH Out 2637.864
# ROH Jump: 204.160
# Mean LL: -25578.882731736514
# STD LL: 395.9413899257179
# Sum LL: -511577.65463473
#
# Parameters Current Step:
# ROH In 2757.304
# ROH Out 2637.001
# ROH Jump: 205.267
# Mean LL: -25578.8828772729
# STD LL: 395.95166370828514
# Sum LL: -511577.65754546
#
# Parameters Current Step:
# ROH In 2754.467
# ROH Out 2637.652
# ROH Jump: 203.682
# Mean LL: -25578.882944253768
# STD LL: 395.92391568291384
# Sum LL: -511577.65888508
#
# Parameters Current Step:
# ROH In 2758.367
# ROH Out 2638.683
# ROH Jump: 203.258
# Mean LL: -25578.882742161866
# STD LL: 395.9356284545657
# Sum LL: -511577.65484324
#
# Parameters Current Step:
# ROH In 2759.366
# ROH Out 2639.511
# ROH Jump: 204.085
# Mean LL: -25578.88278686378
# STD LL: 395.93130955178145
# Sum LL: -511577.65573728
#
# Parameters Current Step:
# ROH In 2758.576
# ROH Out 2639.077
# ROH Jump: 203.797
# Mean LL: -25578.882730843332
# STD LL: 395.9318683216879
# Sum LL: -511577.65461687
#
# Parameters Current Step:
# ROH In 2758.869
# ROH Out 2637.703
# ROH Jump: 204.369
# Mean LL: -25578.882892900943
# STD LL: 395.9523352531882
# Sum LL: -511577.65785802
#
# Parameters Current Step:
# ROH In 2757.807
# ROH Out 2638.961
# ROH Jump: 203.423
# Mean LL: -25578.8827229212
# STD LL: 395.92827567361496
# Sum LL: -511577.65445842
#
# Parameters Current Step:
# ROH In 2757.582
# ROH Out 2638.584
# ROH Jump: 204.328
# Mean LL: -25578.882729114015
# STD LL: 395.93205826413873
# Sum LL: -511577.65458228
#
# Parameters Current Step:
# ROH In 2758.437
# ROH Out 2639.884
# ROH Jump: 203.538
# Mean LL: -25578.882773043377
# STD LL: 395.9200813518832
# Sum LL: -511577.65546087
#
# Parameters Current Step:
# ROH In 2757.764
# ROH Out 2638.369
# ROH Jump: 204.004
# Mean LL: -25578.882715336094
# STD LL: 395.93606221627965
# Sum LL: -511577.65430672
#
# Parameters Current Step:
# ROH In 2756.859
# ROH Out 2638.199
# ROH Jump: 204.040
# Mean LL: -25578.8827203006
# STD LL: 395.93239611443903
# Sum LL: -511577.65440601
#
# Parameters Current Step:
# ROH In 2757.372
# ROH Out 2638.435
# ROH Jump: 203.317
# Mean LL: -25578.882725707183
# STD LL: 395.9324289013549
# Sum LL: -511577.65451414
#
# Parameters Current Step:
# ROH In 2757.424
# ROH Out 2638.472
# ROH Jump: 203.570
# Mean LL: -25578.882713950246
# STD LL: 395.93233734406857
# Sum LL: -511577.65427900
#
# Parameters Current Step:
# ROH In 2756.891
# ROH Out 2637.733
# ROH Jump: 204.320
# Mean LL: -25578.882727722932
# STD LL: 395.93892089921326
# Sum LL: -511577.65455446
#
# Parameters Current Step:
# ROH In 2757.578
# ROH Out 2638.654
# ROH Jump: 203.647
# Mean LL: -25578.882712870312
# STD LL: 395.930937428895
# Sum LL: -511577.65425741
#
# Parameters Current Step:
# ROH In 2758.319
# ROH Out 2638.797
# ROH Jump: 203.441
# Mean LL: -25578.882727189764
# STD LL: 395.9338276016772
# Sum LL: -511577.65454380
#
# Parameters Current Step:
# ROH In 2757.224
# ROH Out 2638.349
# ROH Jump: 203.890
# Mean LL: -25578.88271191534
# STD LL: 395.932754486897
# Sum LL: -511577.65423831
#
# Parameters Current Step:
# ROH In 2757.053
# ROH Out 2638.614
# ROH Jump: 203.400
# Mean LL: -25578.882734464976
# STD LL: 395.927956276824
# Sum LL: -511577.65468930
#
# Parameters Current Step:
# ROH In 2757.586
# ROH Out 2638.430
# ROH Jump: 203.853
# Mean LL: -25578.882710145186
# STD LL: 395.9340361781849
# Sum LL: -511577.65420290
#
# Parameters Current Step:
# ROH In 2757.502
# ROH Out 2638.483
# ROH Jump: 204.024
# Mean LL: -25578.882713032806
# STD LL: 395.93281424163615
# Sum LL: -511577.65426066
#
# Parameters Current Step:
# ROH In 2757.482
# ROH Out 2638.480
# ROH Jump: 203.910
# Mean LL: -25578.88271087813
# STD LL: 395.9326952358159
# Sum LL: -511577.65421756
#
# Parameters Current Step:
# ROH In 2757.284
# ROH Out 2638.186
# ROH Jump: 204.122
# Mean LL: -25578.882714609754
# STD LL: 395.9353861158357
# Sum LL: -511577.65429220
#
# Parameters Current Step:
# ROH In 2757.505
# ROH Out 2638.537
# ROH Jump: 203.766
# Mean LL: -25578.88271072908
# STD LL: 395.93204976045104
# Sum LL: -511577.65421458
#
# Parameters Current Step:
# ROH In 2757.825
# ROH Out 2638.616
# ROH Jump: 203.796
# Mean LL: -25578.882711729013
# STD LL: 395.93309953671894
# Sum LL: -511577.65423458
#
# Parameters Current Step:
# ROH In 2757.675
# ROH Out 2638.549
# ROH Jump: 203.820
# Mean LL: -25578.882710495876
# STD LL: 395.9330133207183
# Sum LL: -511577.65420992
#
# Parameters Current Step:
# ROH In 2757.695
# ROH Out 2638.531
# ROH Jump: 203.715
# Mean LL: -25578.88271089895
# STD LL: 395.93337084782576
# Sum LL: -511577.65421798
#
# Parameters Current Step:
# ROH In 2757.535
# ROH Out 2638.493
# ROH Jump: 203.862
# Mean LL: -25578.882710288002
# STD LL: 395.9328641778546
# Sum LL: -511577.65420576
#
# Parameters Current Step:
# ROH In 2757.693
# ROH Out 2638.445
# ROH Jump: 203.924
# Mean LL: -25578.88271167504
# STD LL: 395.9345592830059
# Sum LL: -511577.65423350
#
# Parameters Current Step:
# ROH In 2757.552
# ROH Out 2638.514
# ROH Jump: 203.805
# Mean LL: -25578.882710178656
# STD LL: 395.93267716946224
# Sum LL: -511577.65420357
#
# Parameters Current Step:
# ROH In 2757.441
# ROH Out 2638.409
# ROH Jump: 203.860
# Mean LL: -25578.88271004407
# STD LL: 395.9333716828923
# Sum LL: -511577.65420088
#
# Parameters Current Step:
# ROH In 2757.324
# ROH Out 2638.338
# ROH Jump: 203.881
# Mean LL: -25578.88271050594
# STD LL: 395.9335508407867
# Sum LL: -511577.65421012
#
# Parameters Current Step:
# ROH In 2757.517
# ROH Out 2638.409
# ROH Jump: 203.818
# Mean LL: -25578.882709894668
# STD LL: 395.933859179536
# Sum LL: -511577.65419789
#
# Parameters Current Step:
# ROH In 2757.509
# ROH Out 2638.367
# ROH Jump: 203.796
# Mean LL: -25578.88271014144
# STD LL: 395.9343566771767
# Sum LL: -511577.65420283
#
# Parameters Current Step:
# ROH In 2757.478
# ROH Out 2638.318
# ROH Jump: 203.882
# Mean LL: -25578.882710354454
# STD LL: 395.9348342103313
# Sum LL: -511577.65420709
#
# Parameters Current Step:
# ROH In 2757.533
# ROH Out 2638.465
# ROH Jump: 203.825
# Mean LL: -25578.882709939484
# STD LL: 395.93321642524205
# Sum LL: -511577.65419879
#
# Parameters Current Step:
# ROH In 2757.408
# ROH Out 2638.425
# ROH Jump: 203.815
# Mean LL: -25578.882710243328
# STD LL: 395.9329286660815
# Sum LL: -511577.65420487
#
# Parameters Current Step:
# ROH In 2757.542
# ROH Out 2638.429
# ROH Jump: 203.844
# Mean LL: -25578.882709939848
# STD LL: 395.93375930689433
# Sum LL: -511577.65419880
#
# Parameters Current Step:
# ROH In 2757.621
# ROH Out 2638.460
# ROH Jump: 203.797
# Mean LL: -25578.88271018971
# STD LL: 395.93385157386615
# Sum LL: -511577.65420379
#
# Parameters Current Step:
# ROH In 2757.486
# ROH Out 2638.422
# ROH Jump: 203.845
# Mean LL: -25578.88270991122
# STD LL: 395.93349166250783
# Sum LL: -511577.65419822
#
# Parameters Current Step:
# ROH In 2757.483
# ROH Out 2638.435
# ROH Jump: 203.814
# Mean LL: -25578.88270990892
# STD LL: 395.93328553431394
# Sum LL: -511577.65419818
#
# Parameters Current Step:
# ROH In 2757.457
# ROH Out 2638.379
# ROH Jump: 203.826
# Mean LL: -25578.882709890604
# STD LL: 395.93387449468855
# Sum LL: -511577.65419781
#
# Parameters Current Step:
# ROH In 2757.419
# ROH Out 2638.335
# ROH Jump: 203.827
# Mean LL: -25578.88271003461
# STD LL: 395.93420353107825
# Sum LL: -511577.65420069
#
# Parameters Current Step:
# ROH In 2757.486
# ROH Out 2638.393
# ROH Jump: 203.794
# Mean LL: -25578.88270994243
# STD LL: 395.9338544696436
# Sum LL: -511577.65419885
#
# Parameters Current Step:
# ROH In 2757.486
# ROH Out 2638.414
# ROH Jump: 203.832
# Mean LL: -25578.882709863017
# STD LL: 395.93358236677966
# Sum LL: -511577.65419726
#
# Parameters Current Step:
# ROH In 2757.491
# ROH Out 2638.367
# ROH Jump: 203.837
# Mean LL: -25578.88270997279
# STD LL: 395.9342584960142
# Sum LL: -511577.65419946
#
# Parameters Current Step:
# ROH In 2757.485
# ROH Out 2638.418
# ROH Jump: 203.820
# Mean LL: -25578.882709866615
# STD LL: 395.9335287736871
# Sum LL: -511577.65419733
#
# Parameters Current Step:
# ROH In 2757.435
# ROH Out 2638.398
# ROH Jump: 203.834
# Mean LL: -25578.882709963404
# STD LL: 395.9334645748604
# Sum LL: -511577.65419927
#
# Parameters Current Step:
# ROH In 2757.497
# ROH Out 2638.406
# ROH Jump: 203.822
# Mean LL: -25578.882709865284
# STD LL: 395.933760529216
# Sum LL: -511577.65419731
#
# Parameters Current Step:
# ROH In 2757.521
# ROH Out 2638.447
# ROH Jump: 203.823
# Mean LL: -25578.88270988804
# STD LL: 395.9333732860713
# Sum LL: -511577.65419776
#
# Parameters Current Step:
# ROH In 2757.505
# ROH Out 2638.430
# ROH Jump: 203.824
# Mean LL: -25578.882709868103
# STD LL: 395.93349858797643
# Sum LL: -511577.65419736
#
# Parameters Current Step:
# ROH In 2757.473
# ROH Out 2638.396
# ROH Jump: 203.825
# Mean LL: -25578.88270987248
# STD LL: 395.9337491924156
# Sum LL: -511577.65419745
#
# Parameters Current Step:
# ROH In 2757.497
# ROH Out 2638.421
# ROH Jump: 203.824
# Mean LL: -25578.882709856924
# STD LL: 395.93356123898707
# Sum LL: -511577.65419714
#
# Parameters Current Step:
# ROH In 2757.502
# ROH Out 2638.410
# ROH Jump: 203.832
# Mean LL: -25578.8827098682
# STD LL: 395.9337406492818
# Sum LL: -511577.65419736
#
# Parameters Current Step:
# ROH In 2757.489
# ROH Out 2638.416
# ROH Jump: 203.823
# Mean LL: -25578.88270986658
# STD LL: 395.93358174300766
# Sum LL: -511577.65419733
#
# Parameters Current Step:
# ROH In 2757.497
# ROH Out 2638.412
# ROH Jump: 203.829
# Mean LL: -25578.88270986825
# STD LL: 395.93368768094734
# Sum LL: -511577.65419736
#
# Parameters Current Step:
# ROH In 2757.491
# ROH Out 2638.415
# ROH Jump: 203.824
# Mean LL: -25578.88270986005
# STD LL: 395.93360822711134
# Sum LL: -511577.65419720
#
# Parameters Current Step:
# ROH In 2757.486
# ROH Out 2638.428
# ROH Jump: 203.832
# Mean LL: -25578.88270988813
# STD LL: 395.93340735978427
# Sum LL: -511577.65419776
#
# Parameters Current Step:
# ROH In 2757.494
# ROH Out 2638.412
# ROH Jump: 203.824
# Mean LL: -25578.88270985587
# STD LL: 395.93367223672436
# Sum LL: -511577.65419712
#
# Parameters Current Step:
# ROH In 2757.502
# ROH Out 2638.418
# ROH Jump: 203.817
# Mean LL: -25578.88270986874
# STD LL: 395.9336454351957
# Sum LL: -511577.65419737
#
# Parameters Current Step:
# ROH In 2757.490
# ROH Out 2638.415
# ROH Jump: 203.828
# Mean LL: -25578.882709861027
# STD LL: 395.9335981337767
# Sum LL: -511577.65419722
#
# Parameters Current Step:
# ROH In 2757.498
# ROH Out 2638.417
# ROH Jump: 203.820
# Mean LL: -25578.882709872858
# STD LL: 395.93362966859786
# Sum LL: -511577.65419746
#
# Parameters Current Step:
# ROH In 2757.492
# ROH Out 2638.416
# ROH Jump: 203.826
# Mean LL: -25578.882709861333
# STD LL: 395.9336060173737
# Sum LL: -511577.65419723
#
# Parameters Current Step:
# ROH In 2757.496
# ROH Out 2638.416
# ROH Jump: 203.824
# Mean LL: -25578.88270985838
# STD LL: 395.93361673790105
# Sum LL: -511577.65419717
#
# Parameters Current Step:
# ROH In 2757.493
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.88270985656
# STD LL: 395.9336402318887
# Sum LL: -511577.65419713
#
# Parameters Current Step:
# ROH In 2757.492
# ROH Out 2638.413
# ROH Jump: 203.826
# Mean LL: -25578.88270985906
# STD LL: 395.9336351853782
# Sum LL: -511577.65419718
#
# Parameters Current Step:
# ROH In 2757.496
# ROH Out 2638.414
# ROH Jump: 203.822
# Mean LL: -25578.882709857164
# STD LL: 395.93365095223345
# Sum LL: -511577.65419714
#
# Parameters Current Step:
# ROH In 2757.493
# ROH Out 2638.410
# ROH Jump: 203.823
# Mean LL: -25578.882709858346
# STD LL: 395.93369220971965
# Sum LL: -511577.65419717
#
# Parameters Current Step:
# ROH In 2757.494
# ROH Out 2638.411
# ROH Jump: 203.823
# Mean LL: -25578.882709861235
# STD LL: 395.9336733415575
# Sum LL: -511577.65419722
#
# Parameters Current Step:
# ROH In 2757.493
# ROH Out 2638.412
# ROH Jump: 203.824
# Mean LL: -25578.882709863836
# STD LL: 395.9336562343483
# Sum LL: -511577.65419728
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.823
# Mean LL: -25578.882709863043
# STD LL: 395.9336615946336
# Sum LL: -511577.65419726
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.414
# ROH Jump: 203.824
# Mean LL: -25578.88270986006
# STD LL: 395.9336444873441
# Sum LL: -511577.65419720
#
# Parameters Current Step:
# ROH In 2757.496
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.88270985599
# STD LL: 395.93366264464197
# Sum LL: -511577.65419712
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.825
# Mean LL: -25578.88270986206
# STD LL: 395.93365798437827
# Sum LL: -511577.65419724
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709854974
# STD LL: 395.93365888687845
# Sum LL: -511577.65419710
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.411
# ROH Jump: 203.824
# Mean LL: -25578.882709865364
# STD LL: 395.9336846917218
# Sum LL: -511577.65419731
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709856636
# STD LL: 395.93365453835463
# Sum LL: -511577.65419713
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.412
# ROH Jump: 203.824
# Mean LL: -25578.882709856724
# STD LL: 395.9336746403801
# Sum LL: -511577.65419713
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.88270985869
# STD LL: 395.9336595637591
# Sum LL: -511577.65419717
#
# Parameters Current Step:
# ROH In 2757.494
# ROH Out 2638.412
# ROH Jump: 203.824
# Mean LL: -25578.882709857706
# STD LL: 395.9336655616951
# Sum LL: -511577.65419715
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709860838
# STD LL: 395.9336607658861
# Sum LL: -511577.65419722
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.88270985777
# STD LL: 395.9336567127749
# Sum LL: -511577.65419716
#
# Parameters Current Step:
# ROH In 2757.494
# ROH Out 2638.413
# ROH Jump: 203.825
# Mean LL: -25578.882709863752
# STD LL: 395.9336600083692
# Sum LL: -511577.65419728
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709856163
# STD LL: 395.93366057632784
# Sum LL: -511577.65419712
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.412
# ROH Jump: 203.824
# Mean LL: -25578.882709862482
# STD LL: 395.93366663762316
# Sum LL: -511577.65419725
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709860543
# STD LL: 395.933659193929
# Sum LL: -511577.65419721
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709858564
# STD LL: 395.9336597318553
# Sum LL: -511577.65419717
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709860813
# STD LL: 395.93366222477005
# Sum LL: -511577.65419722
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709855272
# STD LL: 395.9336577997399
# Sum LL: -511577.65419711
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709858015
# STD LL: 395.9336553878219
# Sum LL: -511577.65419716
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824
# Mean LL: -25578.882709857815
# STD LL: 395.933654984801
# Sum LL: -511577.65419716
#
# Parameters Current Step:
# ROH In 2757.495
# ROH Out 2638.413
# ROH Jump: 203.824

# %% [markdown]
# # Test 20 phased TSI individuals and make LL Plot

# %%
### 1) Load HDF5
h5_path = "Simulated/1000G_Mosaic/TSI0/ch3/data.h5"  ### Which HDF to look into
f = h5py.File(h5_path, "r") # Load for Sanity Check. See below!
samples = f["samples"][:]

print(f"Loaded {len(samples)} targets")
# Out:
# Loaded 107 targets

# %%
# %%time
### 2) Prepare hmms worker array (with diploid = False)
n_lls = 20 # How many Individuals to use from target
ch = 3
n_ref=503
path_mosaic = "./Simulated/1000G_Mosaic/TSI0/ch3/"
exclude_pops = ["TSI", ]

### Load all TSI hmm workers
hmms = [prep_hmm_object(path_mosaic, exclude_pops=exclude_pops, iid=iid, ch=ch, n_ref=n_ref, diploid=False) for iid in samples[:n_lls]]
# Out:
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
#
# Loaded 77652 variants
# Loaded 107 individuals
# HDF5 loaded from ./Simulated/1000G_Mosaic/TSI0/ch3/data.h5
#
# Loaded 77652 variants
# Loaded 503 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/Eur1240chr3.hdf5
# 396 / 503 Individuals included in Reference
# CPU times: user 3min 9s, sys: 1.81 s, total: 3min 11s
# Wall time: 3min 10s

# %%
# %%time
### 3) Calculate LL for array of ROH Jump Rates
roh_jumps = np.logspace(2, 3, 30)
prms_vec = [[1, 10, rj] for rj in roh_jumps]

procses = 10 # On Cluster
ll_vec1 = [-ll_mosaic_individuals(prms) for prms in prms_vec]  # Calculate full LL vector
# Out:
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 100.000
# Mean LL: -4874.371208931805
# STD LL: 217.23007652519098
# Sum LL: -97487.42417864
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 108.264
# Mean LL: -4843.77289580304
# STD LL: 215.7673682139665
# Sum LL: -96875.45791606
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 117.210
# Mean LL: -4814.105284059951
# STD LL: 214.2804270976561
# Sum LL: -96282.10568120
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 126.896
# Mean LL: -4785.452232101297
# STD LL: 212.76845953800813
# Sum LL: -95709.04464203
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 137.382
# Mean LL: -4757.90390306369
# STD LL: 211.23069570735908
# Sum LL: -95158.07806127
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 148.735
# Mean LL: -4731.557141812134
# STD LL: 209.66638136335092
# Sum LL: -94631.14283624
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 161.026
# Mean LL: -4706.51585197733
# STD LL: 208.07476244100636
# Sum LL: -94130.31703955
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 174.333
# Mean LL: -4682.891370736698
# STD LL: 206.45506345478205
# Sum LL: -93657.82741473
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 188.739
# Mean LL: -4660.802838305042
# STD LL: 204.8064616079931
# Sum LL: -93216.05676610
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 204.336
# Mean LL: -4640.377557939637
# STD LL: 203.12805929544058
# Sum LL: -92807.55115879
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 221.222
# Mean LL: -4621.751341722154
# STD LL: 201.41885815951758
# Sum LL: -92435.02683444
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 239.503
# Mean LL: -4605.06883735058
# STD LL: 199.67773743896495
# Sum LL: -92101.37674701
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 259.294
# Mean LL: -4590.483830755465
# STD LL: 197.90343822694905
# Sum LL: -91809.67661511
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 280.722
# Mean LL: -4578.159516940942
# STD LL: 196.09455478081492
# Sum LL: -91563.19033882
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 303.920
# Mean LL: -4568.268722206292
# STD LL: 194.2495364903378
# Sum LL: -91365.37444413
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 329.034
# Mean LL: -4560.994044089716
# STD LL: 192.36671158338595
# Sum LL: -91219.88088179
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 356.225
# Mean LL: -4556.5278583793615
# STD LL: 190.4443533067838
# Sum LL: -91130.55716759
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 385.662
# Mean LL: -4555.072139095939
# STD LL: 188.48080931917102
# Sum LL: -91101.44278192
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 417.532
# Mean LL: -4556.8380473875695
# STD LL: 186.47468851201396
# Sum LL: -91136.76094775
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 452.035
# Mean LL: -4562.045248247449
# STD LL: 184.42504609567817
# Sum LL: -91240.90496495
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 489.390
# Mean LL: -4570.920904893409
# STD LL: 182.331468775891
# Sum LL: -91418.41809787
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 529.832
# Mean LL: -4583.6983026005855
# STD LL: 180.19399573700784
# Sum LL: -91673.96605201
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 573.615
# Mean LL: -4600.615082311662
# STD LL: 178.0129145442289
# Sum LL: -92012.30164623
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 621.017
# Mean LL: -4621.911090255597
# STD LL: 175.78855948795248
# Sum LL: -92438.22180511
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 672.336
# Mean LL: -4647.825836822978
# STD LL: 173.5212441060234
# Sum LL: -92956.51673646
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 727.895
# Mean LL: -4678.595507155218
# STD LL: 171.21139327740806
# Sum LL: -93571.91014310
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 788.046
# Mean LL: -4714.449417572096
# STD LL: 168.85985685685534
# Sum LL: -94288.98835144
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 853.168
# Mean LL: -4755.605811604907
# STD LL: 166.46832545697626
# Sum LL: -95112.11623210
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 923.671
# Mean LL: -4802.266969935169
# STD LL: 164.03974976958386
# Sum LL: -96045.33939870
#
# Parameters Current Step:
# ROH In 1.000
# ROH Out 10.000
# ROH Jump: 1000.000
# Mean LL: -4854.613816893323
# STD LL: 161.57869712548404
# Sum LL: -97092.27633787
# CPU times: user 28.3 s, sys: 1min 20s, total: 1min 48s
# Wall time: 31min 8s

# %%
ll_vec = np.array(ll_vec1)
#ll_vec = np.array(ll_vec)

# %% [markdown]
# ### Do the Plot
# LL of 20 TSI indivdiuals (phased) with Ref rest of EUR 1000 Genomes

# %%
fs = 18
true_val = 0.1

ll_plot = ll_vec - np.max(ll_vec)
i = np.argmax(ll_plot)

print(f"Maximum Likelihood at {roh_jumps[i]} : {ll_vec[i]}")

plt.figure(figsize=(8,6))
plt.plot(roh_jumps, ll_plot, "o-", color="maroon", label="Data")
plt.xscale("log")
plt.ylabel("Log Likelihood", fontsize=fs)
plt.xlabel("ROH Jump Probability", fontsize=fs)
#plt.axvline(x=0.1, linewidth=3, color="lawngreen", label="True Value")
#plt.axhline(y=-2, label="LL=-2", color="gray", zorder=0)
plt.legend(fontsize=fs*0.8)
plt.ylim([-5000,200])
plt.title("LogLikelihood ROH Jump phased 20 TSI")
plt.savefig("./figures_test/ll_curve_ROH_jump_20phasedTSI.pdf", bbox_inches = 'tight', pad_inches = 0)
plt.show()
# Out:
# Maximum Likelihood at 385.6620421163472 : -91101.44278191877

# %% [markdown]
# # Area51

# %% [markdown]
# ### Plot of LL Copying with unphased data
# (should be much lower LL and peak at higher ROH-Jump)

# %%
fs = 18
true_val = 0.1

ll_plot = ll_vec - np.max(ll_vec)
ll_plot1 = ll_vec1 - np.max(ll_vec1)
i = np.argmax(ll_plot)
i1 = np.argmax(ll_plot1)

print(f"Maximum Likelihood at {roh_jumps[i]} : {ll_vec[i]}")
print(f"Maximum Likelihood at {roh_jumps[i1]} : {ll_vec1[i]}")

plt.figure(figsize=(8,6))
plt.plot(roh_jumps, ll_plot, "o-", color="maroon", label="Phased Haploid")
plt.plot(roh_jumps, ll_plot1, "o-", color="blue", label="Not phased Pseudohaploid")

plt.xscale("log")
plt.ylabel("Log Likelihood", fontsize=fs)
plt.xlabel("ROH Jump Probability", fontsize=fs)
#plt.axvline(x=0.1, linewidth=3, color="lawngreen", label="True Value")
#plt.axhline(y=-2, label="LL=-2", color="gray", zorder=0)
plt.legend(fontsize=fs*0.8)
plt.ylim([-10000,200])
plt.title("LogLikelihood ROH Jump phased 20 TSI", fontsize=fs)
#plt.savefig("../figures_test/ll_curveSardX.pdf", bbox_inches = 'tight', pad_inches = 0)
plt.show()
# Out:
# Maximum Likelihood at 379.26901907322497 : -91102.36189653994
# Maximum Likelihood at 1000.0 : -568815.9494010495

# %%
# Out:
# array([  10.        ,   16.68100537,   27.82559402,   46.41588834,
#          77.42636827,  129.1549665 ,  215.443469  ,  359.38136638,
#         599.48425032, 1000.        ])
