# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pandas as pd
import socket
import os as os
import sys as sys
import multiprocessing as mp
from scipy import stats

socket_name = socket.gethostname()
print(socket_name)

if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine

elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster

else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")

sys.path.append("./PackagesSupport/")  # Since now we are in the Root Directory
from pp_individual_roh_csvs import post_process_roh_df, merge_called_blocks, individual_roh_statistic  # Import PP Functions
#from createMosaicsMulti import Mosaic_1000G_Multi  # Import the object that can create the Multiruns

### For Arial Font
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'   # Set the defaul
rcParams['font.sans-serif'] = ['Arial']  # Make sure to have the font installed (it is on cluster for Harald)

########## Some key Parameters
meta_path = "./Data/Marcus2019_1240k/meta_rev_final.csv"
#meta_path = "./Data/Marcus2019_1240k/meta_rev_unique_ids.csv"  ### Important: Meta with unique IDs!
meta_df = pd.read_csv(meta_path)  # Load the Meta File
anc_sardind= 85
anc_ind =  1087
# Out:
# midway2-0401.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# # Helper Function

# %%
def merge_to_one_df(df1, df2, on="iid", min_snps=500000, max_age=1e6, only_inc_alt=True):
    """Merge Two Dataframes to one"""
    
    df_merge = pd.merge(df1, df2, on="iid")
    print(f"Merged to {len(df_merge)} Inds. (from {len(df1)} and {len(df2)}) resp.")
    
    ### Filter to High Coverage Individuals
    df_merge = df_merge[df_merge["n_cov_snp_x"] > min_snps]
    df_merge = df_merge[df_merge["age_x"] < max_age]
    if only_inc_alt:
        df_merge = df_merge[df_merge["include_alt_x"] > 0]
    print(f"Further filtered to {len(df_merge)} Individuals")
    return df_merge

def plot_correlation_roh(df_merge, xlim=[0,380], ylim=[0,380], savepath="", 
                         col1="sum_roh>4_y", col2="sum_roh>4_x", c_col="age_x", 
                         barlabel="Age [y BP]", figsize=(8,8), pad=20,
                         c_line="gray", lw=0.2, s=20, fs=14, fs_t=8, 
                         vrange=[0.3,30], cmap="viridis"):
    """Plot correlation between ROH inferred on pseudo-haploid
    and on Readcount data. Print Pearson product-moment correlation coefficient"""
    r = np.corrcoef(df_merge[col1], df_merge[col2])[0,1]

    fig=plt.figure(figsize=figsize)
    ax=plt.gca()
    sc=ax.scatter(df_merge[col1], df_merge[col2], c=df_merge[c_col],
                s=s, ec="k", lw=lw, zorder=1, norm=colors.Normalize(vmin=vrange[0], vmax=vrange[1]),
                   cmap=cmap) #LogNorm
    ax.plot(xlim, xlim, c=c_line, alpha=0.8, zorder=0)
    ax.set_xlabel("Full Readcount Data", fontsize=fs)
    ax.set_ylabel("Pseudohaploid Data only", fontsize=fs)
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.tick_params(labelsize=fs_t)
    text1=f"$r={r:.3f}$"
    text2=f"Sum ROH>4cm for \n{len(df_merge)} individuals \n>300k SNPs covered"
    ax.text(0.67, 0.05, text1, transform=ax.transAxes, fontsize=fs)
    ax.text(0.06, 0.81, text2, transform=ax.transAxes, fontsize=fs)
    #ax.set_title(f"{len(df_merge)} intersecting individuals >0.5x avg. depth",
    #            fontsize=fs)
    
    #cax = divider.append_axes('right', size='5%', pad=0.05)
    cb = fig.colorbar(sc, ax=ax, orientation='vertical', extend="max")
    cb.ax.set_ylabel(barlabel, rotation=270, fontsize=fs, labelpad=pad)
    cb.ax.tick_params(labelsize=fs_t, direction="in")


    if len(savepath)>0:
        plt.savefig(savepath, bbox_inches = 'tight', pad_inches = 0)
        print(f"Saved to {savepath}")
    plt.show()

# %%
df_rc = pd.read_csv("./Empirical/1240k/MarcusAncs/combined_roh05.csv", "\t")
df_es = pd.read_csv("./Empirical/Eigenstrat/Reichall/combined_roh05.csv", '\t')  # Load ES Data
df_all = pd.read_csv("./Empirical/roh_all_inds.csv", '\t')  # Load final filtered Dataframe
#df_es = pd.read_csv("./Empirical/1240k/MarcusAncsPH/combined_roh.csv", "\t")

# %%
df_merge = merge_to_one_df(df_all, df_rc, min_snps=300000) # max_age=7000
# Out:
# Merged to 511 Inds. (from 3232 and 557) resp.
# Further filtered to 511 Individuals

# %%
df_merge = df_merge.sort_values(by="mean_cov_x")
plot_correlation_roh(df_merge, xlim=[0,500], ylim=[0,500], savepath="", c_col="mean_cov_x",
                     lw=0.2, s=10, figsize=(2.25,2), fs=6, fs_t=6, pad=7,
                    barlabel="Avg. Coverage on 1240k SNPs", vrange=[0.5,5.5])

# %% [markdown]
# # Area 51

# %%
#df_merge.sort_values(by="age_x")[["iid", "clst_y", "age_x", "age_y"]]

# %%
plt.figure()
plt.hist(df_merge["mean_cov_x"])
plt.show()

# %%
df_merge.sort_values(by="mean_cov_x")
# Out:
#         iid                       pop_x  max_roh_x  sum_roh>4_x  n_roh>4_x  \
# 363   I0234             Russia_Srubnaya   4.427800     4.427800          1
# 510  SNN003                     Sar-Med   0.000000     0.000000          0
# 68    I1906          Hungary_Lengyel_LN  14.995602    50.090284          6
# 184   I4184            Hungary_Sopot_LN   4.510802    17.151599          4
# 322   I7628                 England_MBA   5.669701     5.669701          1
# 492   S1252                    Sar-EMBA   0.000000     0.000000          0
# 12    I2534          Romania_Mesolithic  32.756996   141.714581         16
# 192   I6480           Czech_Bell_Beaker   7.035297    16.677898          3
# 13    I4626                   Latvia_HG  25.191399   135.194705         19
# 37    I5401        Serbia_Iron_Gates_HG   9.790004    80.135114         16
# 455   I5529         Germany_Bell_Beaker   0.000000     0.000000          0
# 260   I4253          Poland_Bell_Beaker   5.501402    10.838796          2
# 412   I1102                  Anatolia_N   0.000000     0.000000          0
# 131   I0781                  Bulgaria_C  11.900198    25.617901          4
# 384   I1532         Germany_Corded_Ware   4.017103     4.017103          1
# 472  VIL006                     Sar-Pun  41.487693    74.970095          5
# 493  VIL007                     Sar-Pun   0.000000     0.000000          0
# 367   I5665          Iberia_Bell_Beaker   4.310798     4.310798          1
# 181   I3590         Germany_Bell_Beaker   4.718500    17.331683          4
# 41    I5882                  Ukraine_EN  14.579403    74.281905         10
# 74    I4076     Netherlands_Bell_Beaker  17.442608    47.844118          5
# 117   I1390          France_Bell_Beaker   7.622897    28.305290          5
# 494  MSR003                     Sar-Pun   0.000000     0.000000          0
# 123   I0124            Russia_Samara_HG   7.817199    26.437392          5
# 146   I3715                   Ukraine_N  13.877901    22.920701          3
# 193   I1901          Hungary_Lengyel_LN   6.415102    16.618093          3
# 157   I7635              England_CA_EBA  11.787300    20.649000          3
# 486  ORC004                     Sar-Nur   5.075598     5.075598          1
# 177   I0357       Russia_Yamnaya_Samara   4.782999    18.212697          4
# 145   I1909  Hungary_Balaton_Lasinja_CA   5.090600    22.954303          5
# ..      ...                         ...        ...          ...        ...
# 75    I2630                  Scotland_N  10.978204    47.781304          7
# 83    I2932                  Scotland_N  18.643200    39.794301          4
# 249   I2860                Scotland_LBA   7.230401    11.525199          2
# 126   I2520                Bulgaria_EBA   7.733893    26.097595          5
# 342   I2794            Hungary_Koros_EN   4.859901     4.859901          1
# 323   I2366           Hungary_Baden_LCA   5.654200     5.654200          1
# 376   I2510                Bulgaria_EBA   4.137599     4.137599          1
# 309   I2445         England_Bell_Beaker   6.930202     6.930202          1
# 328   I2450         England_Bell_Beaker   5.264601     5.264601          1
# 173   I2636                  Scotland_N   7.717597    19.020598          3
# 324   I0449            Hungary_Tisza_LN   5.626500     5.626500          1
# 348   I0100              Germany_LBK_EN   4.669600     4.669600          1
# 264   I0708                  Anatolia_N  10.302282    10.302282          1
# 189   I0071      Greece_Minoan_Lassithi  16.932500    16.932500          1
# 76    I2452         England_Bell_Beaker  20.922089    45.492587          5
# 341   I0745                  Anatolia_N   4.866898     4.866898          1
# 429   I2495                Anatolia_EBA   0.000000     0.000000          0
# 386   I0746                  Anatolia_N   0.000000     0.000000          0
# 420   I2790    Hungary_Protoboleraz_LCA   0.000000     0.000000          0
# 390   I0707                  Anatolia_N   0.000000     0.000000          0
# 104   I0018              Germany_LBK_EN  14.470899    31.726804          4
# 290   I0709                  Anatolia_N   4.412701     8.624306          2
# 307   I0581                    Iberia_C   7.694203     7.694203          1
# 274   I0118       Germany_Alberstedt_LN   4.737699     9.403598          2
# 302   I1583                  Anatolia_N   8.090001     8.090001          1
# 165   I0412                   Iberia_EN  10.660404    19.524801          3
# 147   I0103         Germany_Corded_Ware   9.558093    22.659194          3
# 410   I0054              Germany_LBK_EN   0.000000     0.000000          0
# 227   I0585                   Iberia_HG   5.082297    13.731587          3
# 270   I0172       Germany_Esperstedt_MN   5.040496     9.577795          2
#
#      sum_roh>8_x  n_roh>8_x  sum_roh>12_x  n_roh>12_x      lat_x     ...      \
# 363     0.000000          0      0.000000           0  53.140000     ...
# 510     0.000000          0      0.000000           0  40.726921     ...
# 68     29.939095          2     29.939095           2  47.510620     ...
# 184     0.000000          0      0.000000           0  46.025398     ...
# 322     0.000000          0      0.000000           0        NaN     ...
# 492     0.000000          0      0.000000           0  39.868827     ...
# 12     74.199299          4     64.433599           3  44.027196     ...
# 192     0.000000          0      0.000000           0  50.166667     ...
# 13     54.481395          4     25.191399           1  56.283300     ...
# 37      9.790004          1      0.000000           0  44.640262     ...
# 455     0.000000          0      0.000000           0  48.691000     ...
# 260     0.000000          0      0.000000           0  50.649000     ...
# 412     0.000000          0      0.000000           0  40.300000     ...
# 131    11.900198          1      0.000000           0  42.232227     ...
# 384     0.000000          0      0.000000           0  51.420000     ...
# 472    60.785698          2     60.785698           2  39.618016     ...
# 493     0.000000          0      0.000000           0  39.618016     ...
# 367     0.000000          0      0.000000           0        NaN     ...
# 181     0.000000          0      0.000000           0  48.883300     ...
# 41     38.112502          3     28.970604           2  48.914220     ...
# 74     27.214408          2     17.442608           1  52.733563     ...
# 117     0.000000          0      0.000000           0  47.390000     ...
# 494     0.000000          0      0.000000           0  39.183931     ...
# 123     0.000000          0      0.000000           0  53.680623     ...
# 146    13.877901          1     13.877901           1  47.954300     ...
# 193     0.000000          0      0.000000           0  47.102645     ...
# 157    11.787300          1      0.000000           0  54.522812     ...
# 486     0.000000          0      0.000000           0  39.667222     ...
# 177     0.000000          0      0.000000           0  53.380000     ...
# 145     0.000000          0      0.000000           0  45.993000     ...
# ..           ...        ...           ...         ...        ...     ...
# 75     29.069298          3      0.000000           0  58.740000     ...
# 83     29.899500          2     18.643200           1  58.740000     ...
# 249     0.000000          0      0.000000           0  57.721000     ...
# 126     0.000000          0      0.000000           0  43.160890     ...
# 342     0.000000          0      0.000000           0  47.191612     ...
# 323     0.000000          0      0.000000           0  47.620940     ...
# 376     0.000000          0      0.000000           0  43.160890     ...
# 309     0.000000          0      0.000000           0  51.795683     ...
# 328     0.000000          0      0.000000           0        NaN     ...
# 173     0.000000          0      0.000000           0  59.350000     ...
# 324     0.000000          0      0.000000           0  46.355870     ...
# 348     0.000000          0      0.000000           0  51.895833     ...
# 264    10.302282          1      0.000000           0  40.300000     ...
# 189    16.932500          1     16.932500           1  35.080000     ...
# 76     30.442786          2     20.922089           1  52.150000     ...
# 341     0.000000          0      0.000000           0  40.300000     ...
# 429     0.000000          0      0.000000           0  37.917740     ...
# 386     0.000000          0      0.000000           0  40.300000     ...
# 420     0.000000          0      0.000000           0  47.189141     ...
# 390     0.000000          0      0.000000           0  40.300000     ...
# 104    14.470899          1     14.470899           1  48.780000     ...
# 290     0.000000          0      0.000000           0  40.300000     ...
# 307     0.000000          0      0.000000           0  42.333333     ...
# 274     0.000000          0      0.000000           0  51.450000     ...
# 302     8.090001          1      0.000000           0  40.300000     ...
# 165    10.660404          1      0.000000           0  42.500000     ...
# 147    17.991596          2      0.000000           0  51.420000     ...
# 410     0.000000          0      0.000000           0  51.660000     ...
# 227     0.000000          0      0.000000           0  42.911000     ...
# 270     0.000000          0      0.000000           0  51.420000     ...
#
#                    study_y         clst_alt period_alt include_alt_y  \
# 363  Lazaridis et al. 2016           Steppe       MLBA             1
# 510     Marcus et al. 2018              Sar  Medieval?             1
# 68      Lipson et al. 2017          Lengyel         LN             1
# 184     Lipson et al. 2017            Sopot         LN             1
# 322     Olalde et al. 2018          England        MBA             1
# 492     Marcus et al. 2018              Sar         BA             1
# 12   Mathieson et al. 2018          Romania         HG             1
# 192     Olalde et al. 2018   Central Europe         Bk             1
# 13   Mathieson et al. 2018           Latvia         HG             1
# 37   Mathieson et al. 2018       Iron_Gates         HG             1
# 455     Olalde et al. 2018   Central Europe         Bk             1
# 260     Olalde et al. 2018   Central Europe         Bk             1
# 412  Lazaridis et al. 2016         Anatolia          N             1
# 131  Mathieson et al. 2018          Balkans        ChL             1
# 384  Lazaridis et al. 2016           Europe       LNBA             1
# 472     Marcus et al. 2018              Sar      Punic             1
# 493     Marcus et al. 2018              Sar      Punic             1
# 367     Olalde et al. 2018           Iberia         Bk             1
# 181     Olalde et al. 2018   Central Europe         Bk             1
# 41   Mathieson et al. 2018          Ukraine         CA             1
# 74      Olalde et al. 2018  The Netherlands         Bk             1
# 117     Olalde et al. 2018   Central Europe         Bk             1
# 494     Marcus et al. 2018              Sar      Punic             1
# 123  Lazaridis et al. 2016              EHG         HG             1
# 146  Mathieson et al. 2018          Ukraine          N             1
# 193     Lipson et al. 2017          Lengyel         LN             1
# 157     Olalde et al. 2018          England        EBA             1
# 486     Marcus et al. 2018              Sar        Nur             1
# 177  Lazaridis et al. 2016           Steppe       EMBA             1
# 145     Lipson et al. 2017          Balaton        MCA             1
# ..                     ...              ...        ...           ...
# 75      Olalde et al. 2018         Scotland          N             1
# 83      Olalde et al. 2018         Scotland          N             1
# 249     Olalde et al. 2018         Scotland        LBA             1
# 126  Mathieson et al. 2018          Balkans         BA             1
# 342     Lipson et al. 2017            Koros         EN             1
# 323     Lipson et al. 2017            Baden        LCA             1
# 376  Mathieson et al. 2018          Balkans         BA             1
# 309     Olalde et al. 2018          Britain         Bk             1
# 328     Olalde et al. 2018          Britain         Bk             1
# 173     Olalde et al. 2018         Scotland          N             1
# 324     Lipson et al. 2017            Tisza         LN             1
# 348  Lazaridis et al. 2016           Europe         EN             1
# 264  Lazaridis et al. 2016         Anatolia          N             1
# 189  Mathieson et al. 2018           Minoan         BA             1
# 76      Olalde et al. 2018          Britain         Bk             1
# 341  Lazaridis et al. 2016         Anatolia          N             1
# 429  Mathieson et al. 2018         Anatolia         BA             1
# 386  Lazaridis et al. 2016         Anatolia          N             1
# 420     Lipson et al. 2017     Protoboleraz        LCA             1
# 390  Lazaridis et al. 2016         Anatolia          N             1
# 104     Lipson et al. 2017              LBK         EN             1
# 290  Lazaridis et al. 2016         Anatolia          N             1
# 307     Lipson et al. 2017           Iberia         CA             1
# 274  Lazaridis et al. 2016           Europe       LNBA             1
# 302  Lazaridis et al. 2016         Anatolia          N             1
# 165  Lazaridis et al. 2016           Europe         EN             1
# 147  Lazaridis et al. 2016           Europe       LNBA             1
# 410  Lazaridis et al. 2016           Europe         EN             1
# 227  Lazaridis et al. 2016              WHG         HG             1
# 270  Lazaridis et al. 2016           Europe      MNChL             1
#
#              clst_y  mean_cov_y  med_cov n_cov_snp_read          full_iid  \
# 363     Steppe-MLBA    0.506768      0.0       434825.0             I0234
# 510         Sar-Med    0.513644      0.0       396943.0  SNN003.A0102.TF2
# 68     Balkans-MNCA    0.525677      0.0       433002.0             I1906
# 184    Balkans-MNCA    0.519393      0.0       414284.0             I4184
# 322          GB-LBA    0.521264      0.0       391395.0             I7628
# 492        Sar-EMBA    0.524741      0.0       381082.0             S1252
# 12    Iron_Gates-HG    0.526566      0.0       405946.0             I2534
# 192          CE-EBA    0.533502      0.0       409813.0             I6480
# 13        Latvia-HG    0.537568      0.0       363502.0             I4626
# 37    Iron_Gates-HG    0.542621      0.0       449486.0             I5401
# 455          CE-EBA    0.545135      0.0       433235.0             I5529
# 260          CE-EBA    0.551907      0.0       435928.0             I4253
# 412      Anatolia-N    0.535255      0.0       391472.0             I1102
# 131    Balkans-MNCA    0.543313      0.0       444513.0             I0781
# 384          CE-EBA    0.548961      0.0       435996.0             I1532
# 472         Sar-Pun    0.568857      0.0       455710.0  VIL006.A0102.TF1
# 493         Sar-Pun    0.569303      0.0       429813.0  VIL007.A0102.TF1
# 367       Iberia-BA    0.572065      0.0       465312.0             I5665
# 181          CE-EBA    0.563774      0.0       409654.0             I3590
# 41       Ukraine-CA    0.574869      0.0       389873.0             I5882
# 74   Netherlands-BA    0.583959      0.0       423767.0             I4076
# 117          CE-EBA    0.579294      0.0       424663.0             I1390
# 494         Sar-Pun    0.597020      0.0       455061.0  MSR003.A0102.TF2
# 123          EHG-HG    0.596131      0.0       458046.0             I0124
# 146       Ukraine-N    0.619254      0.0       448089.0             I3715
# 193    Balkans-MNCA    0.619217      0.0       467435.0             I1901
# 157          GB-EBA    0.620414      0.0       471411.0             I7635
# 486         Sar-Nur    0.623948      0.0       476388.0      ORC004.A0101
# 177     Steppe-EMBA    0.611937      0.0       504074.0             I0357
# 145    Balkans-MNCA    0.634743      0.0       476601.0             I1909
# ..              ...         ...      ...            ...               ...
# 75           GB-EBA    5.561419      4.0       901361.0             I2630
# 83           GB-EBA    5.162315      2.0       760479.0             I2932
# 249          GB-LBA    5.351814      2.0       802758.0             I2860
# 126      Balkans-BA    5.373476      2.0       770028.0             I2520
# 342    Balkans-MNCA    2.438818      2.0       808283.0             I2794
# 323      Balkans-BA    1.974700      1.0       772215.0             I2366
# 376      Balkans-BA    5.884657      2.0       796616.0             I2510
# 309          GB-EBA    5.892443      2.0       826023.0             I2445
# 328          GB-EBA    6.173275      3.0       892754.0             I2450
# 173           GB-LN    5.976174      3.0       836761.0             I2636
# 324    Balkans-MNCA    6.384698      3.0       923026.0             I0449
# 348           CE-EN    6.453228      4.0       969802.0             I0100
# 264      Anatolia-N    6.119573      3.0       945582.0             I0708
# 189       Minoan-BA    6.920955      4.0       940254.0             I0071
# 76           GB-EBA    6.645494      3.0       882564.0             I2452
# 341      Anatolia-N    6.951696      4.0       961969.0             I0745
# 429     Anatolia-BA    1.912487      1.0       612103.0             I2495
# 386      Anatolia-N    7.618757      4.0       969462.0             I0746
# 420    Balkans-MNCA    4.573420      3.0       932743.0             I2790
# 390      Anatolia-N    8.274645      4.0       975559.0             I0707
# 104           CE-EN    8.051218      3.0       908992.0             I0018
# 290      Anatolia-N    8.476118      4.0       954427.0             I0709
# 307      Iberia-LCA    9.410948      5.0       993338.0             I0581
# 274          CE-EBA   10.494840      7.0      1040762.0             I0118
# 302      Anatolia-N    7.835180      4.0       944914.0             I1583
# 165       Iberia-EN   11.640242      6.0       969717.0             I0412
# 147          CE-EBA   15.032998      9.0      1059708.0             I0103
# 410           CE-EN   15.708981      7.0       995026.0             I0054
# 227          WHG-HG   15.359844      5.0       992582.0             I0585
# 270         CE-MNCA   20.644154     11.0      1086738.0             I0172
#
#     n_cov_snp_y
# 363      434825
# 510      396943
# 68       433002
# 184      414284
# 322      391395
# 492      381082
# 12       405946
# 192      409813
# 13       363502
# 37       449486
# 455      433235
# 260      435928
# 412      391472
# 131      444513
# 384      435996
# 472      455710
# 493      429813
# 367      465312
# 181      409654
# 41       389873
# 74       423767
# 117      424663
# 494      455061
# 123      458046
# 146      448089
# 193      467435
# 157      471411
# 486      476388
# 177      504074
# 145      476601
# ..          ...
# 75       901361
# 83       760479
# 249      802758
# 126      770028
# 342      808283
# 323      772215
# 376      796616
# 309      826023
# 328      892754
# 173      836761
# 324      923026
# 348      969802
# 264      945582
# 189      940254
# 76       882564
# 341      961969
# 429      612103
# 386      969462
# 420      932743
# 390      975559
# 104      908992
# 290      954427
# 307      993338
# 274     1040762
# 302      944914
# 165      969717
# 147     1059708
# 410      995026
# 227      992582
# 270     1086738
#
# [511 rows x 43 columns]
