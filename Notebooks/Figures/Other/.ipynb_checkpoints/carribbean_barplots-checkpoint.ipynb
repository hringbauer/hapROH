# %% [markdown]
# # Plot ROH bar figures of the Caribbean Data

# %%
import numpy as np
import os  # For Saving to Folder
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colorbar as clb
import matplotlib.colors as cls
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
#from mpl_toolkits.basemap import Basemap

import socket
import os as os
import sys as sys
import multiprocessing as mp

### For Arial Font
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'   # Set the defaul
rcParams['font.sans-serif'] = ['Arial']  # Make sure to have the font installed (it is on cluster for Harald)

### To do lowess smoothing
#import statsmodels.api as sm
#lowess = sm.nonparametric.lowess

socket_name = socket.gethostname()
print(socket_name)
if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
elif socket_name.startswith("Harald-Laptop"):
    print("Midway jnovmbre partition detected.")
    path = "/home/hringbauer/git/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")

sys.path.append("./package/") # Append Hapsburg Folder
#from PackagesSupport.roh_expectations import Expected_Roh
from hapsburg.figures.plot_bars import prepare_dfs_plot, plot_panel_row
# Out:
# midway2-0407.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %%
def calc_average_roh(df, cms=[4,8,12,20]):
    """Calcualte the average ROH in df.
    in columns cmss [list]
    Return new dataframe"""
    cs = [4,8,12,20]
    labels = [f"sum_roh>{c}" for c in cs]

    df_new = pd.DataFrame({"iid": ["Average"], "clst":["Average"]})

    for l in labels:
        df_new[l] = np.mean(df[l])
    return df_new

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
plot_dfs, cols = prepare_dfs_plot(df1, cms=[4, 8, 12, 20])

plot_panel_row(plot_dfs,
               wspace=0.1, r_title=80, leg_pos=-14, 
               ylim=[0,320], figsize=(len(df1)/8, 3.5),
               hspace_leg=3,
               savepath="./figures_test/Carib/share_april/all_sites.pdf"
               ) # ./figures_test/Carib/roh_final_set_bar.pdf
# Out:
# Saved figure to ./figures_test/Carib/share_april/all_sites.pdf

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
plot_dfs, cols = prepare_dfs_plot(df1, cms=[4, 8, 12, 20])

plot_panel_row(plot_dfs,
               wspace=0.1, r_title=80, leg_pos=-14, 
               ylim=[0,320], figsize=(len(df1)/8, 3.5),
               hspace_leg=3,
               savepath="./figures_test/Carib/share_april/all_sites.pdf"
               ) # ./figures_test/Carib/roh_final_set_bar.pdf

# %% [markdown]
# ### Plot La Caleta

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
df2 = df1[df1["pop"].str.contains("LaCaleta")].copy()
df2["clst"] = "La Caleta"
plot_dfs, cols = prepare_dfs_plot(df2, cms=[4, 8, 12, 20])

df_avg = calc_average_roh(df2)
plot_dfs += [df_avg]
#plot_dfs = [df_avg]

plot_panel_row(plot_dfs,
               wspace=0.1, r_title=45, leg_pos=-2, 
               ylim=[0,200], figsize=(len(df2)/6, 3.5),
               bins=[[0.04,0.08], [0.08, 0.12], [0.12, 0.2], [0.2, 3.0]],
               cols = ["sum_roh>4", 'sum_roh>8', 'sum_roh>12', 'sum_roh>20'],
               hspace_leg=0,
               savepath="./figures_test/Carib/share_april/la_caleta.pdf",
               Ns=[600, 900, 1200, 1500, 1800, 5000, 10000]
               ) # ./figures_test/Carib/roh_final_set_bar.pdf
# Out:
# Saved figure to ./figures_test/Carib/share_april/la_caleta.pdf

# %%
len(plot_dfs[0])
# Out:
# 57

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
df2 = df1[df1["pop"].str.contains("LaCaleta")].copy()
df2["clst"] = "La Caleta"
plot_dfs, cols = prepare_dfs_plot(df2, cms=[4, 8, 12, 20])

df_avg = calc_average_roh(df2)
#plot_dfs += [df_avg]
plot_dfs = [df_avg]

plot_panel_row(plot_dfs,
               wspace=0.1, r_title=45, leg_pos=-2, 
               ylim=[0,150], figsize=(3, 3.5),
               bins=[[0.04,0.08], [0.08, 0.12], [0.12, 0.2], [0.2, 3.0]],
               cols = ["sum_roh>4", 'sum_roh>8', 'sum_roh>12', 'sum_roh>20'],
               hspace_leg=0,
               savepath="",
               degrees=[],
               Ns=[500, 700, 900, 1200, 1500, 1800]
               ) # ./figures_test/Carib/roh_final_set_bar.pdf

# %%
chr_lgts = [2.8426, 2.688187, 2.232549, 2.14201, 2.040477, 1.917145, 1.871491, 1.680018, 
                1.661367, 1.8090949, 1.5821669, 1.745901, 1.2551429, 1.1859521, 1.413411, 
                1.340264, 1.2849959, 1.175495, 1.0772971, 1.082123, 0.636394, 0.724438]
np.sum(chr_lgts)
# Out:
# 35.388519800000005

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
plot_dfs, cols = prepare_dfs_plot(df1, cms=[4, 8, 12, 20])


### Pull out Dominican
#dom_idx = ["Dominican" in df["pop"].values[0] for df in plot_dfs]
plot_dfs1 = [df for df in plot_dfs if ("Dominican" in df["pop"].values[0])]
plot_dfs2 = [df for df in plot_dfs if ("Dominican" not in df["pop"].values[0])]

l1 = np.sum([len(df) for df in plot_dfs1])
l2 = np.sum([len(df) for df in plot_dfs2]) + 9

plot_panel_row(plot_dfs1[:], savepath="./figures_test/Carib/all_bars_dom1.pdf", 
               wspace=0.1, r_title=80, leg_pos=-10,
               ylim=[0, 280], figsize=(l1/8, 3.5), legends=False)

plot_panel_row(plot_dfs2[:], savepath="./figures_test/Carib/all_bars_nondom1.pdf", 
               wspace=0.1, r_title=80, leg_pos=-20,
               ylim=[0, 280], figsize=(l2/8, 3.5), legends=True)
# Out:
# Saved figure to ./figures_test/Carib/all_bars_dom1.pdf
# Saved figure to ./figures_test/Carib/all_bars_nondom1.pdf

# %% [markdown]
# # Plot only the Cuban ones

# %%
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
df2 = df1[df1["clst"].str.contains("Cuba")].copy()
plot_dfs, cols = prepare_dfs_plot(df2, cms=[4, 8, 12, 20])

plot_panel_row(plot_dfs, savepath="./figures_test/Carib/roh_cuban_bar.pdf", 
               wspace=0.1, r_title=80, leg_pos=-14, 
               ylim=[0,230], figsize=((len(df2)+8)/5, 3.5))
# Out:
# Saved figure to ./figures_test/Carib/roh_cuban_bar.pdf

# %%
df2.sort_values(by="age")

# %% [markdown]
# # Plot all of them

# %%
### Extract all for one Region
df1 = pd.read_csv("./Empirical/Eigenstrat/Sirak20/combined_roh05.csv", sep='\t')
pops = ["Cuba", "Venezuela", "Dominican", "Bahamas", "Curacao", "PuertoRico", "Haiti"]
save_path_base = "./figures_test/Carib/islands/"

for p in pops:
    df_t = df1[df1["pop"].str.contains(p)].copy()
    #print(df_t.sort_values(by="age", ascending=False)[["iid","pop","age", "sum_roh>20"]])
    savepath = os.path.join(save_path_base, str(p) + ".pdf")
    plot_dfs, cols = prepare_dfs_plot(df_t, cms=[4, 8, 12, 20])
    
    plot_panel_row(plot_dfs, savepath=savepath, 
                   wspace=0.1, r_title=80, leg_pos=0, 
                   ylim=[0,275], figsize=((len(df_t)+8)/4, 3.5))
# Out:
# Saved figure to ./figures_test/Carib/islands/Cuba.pdf
# Saved figure to ./figures_test/Carib/islands/Venezuela.pdf
# Saved figure to ./figures_test/Carib/islands/Dominican.pdf
# Saved figure to ./figures_test/Carib/islands/Bahamas.pdf
# Saved figure to ./figures_test/Carib/islands/Curacao.pdf
# Saved figure to ./figures_test/Carib/islands/PuertoRico.pdf
# Saved figure to ./figures_test/Carib/islands/Haiti.pdf

# %%
path_folder = "./figures_test/Carib/islands/"
path_zip = "./figures_test/Carib/islands/all_figures.zip"
# !zip -r $path_zip $path_folder
# Out:
#   adding: figures_test/Carib/islands/ (stored 0%)
#   adding: figures_test/Carib/islands/Curacao.pdf (deflated 29%)
#   adding: figures_test/Carib/islands/PuertoRico.pdf (deflated 28%)
#   adding: figures_test/Carib/islands/.ipynb_checkpoints/ (stored 0%)
#   adding: figures_test/Carib/islands/Dominican.pdf (deflated 20%)
#   adding: figures_test/Carib/islands/Haiti.pdf (deflated 30%)
#   adding: figures_test/Carib/islands/Venezuela.pdf (deflated 29%)
#   adding: figures_test/Carib/islands/Bahamas.pdf (deflated 27%)
#   adding: figures_test/Carib/islands/Cuba.pdf (deflated 29%)
