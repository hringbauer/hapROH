# %% [markdown]
# # Make bar plots of ROH tracts
# Make admixture style plots of ROH, both expected as well as for empirical Individuals

# %%
import numpy as np
import os  # For Saving to Folder
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colorbar as clb
import matplotlib.colors as cls
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.basemap import Basemap
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

import socket
import os as os
import sys as sys
import multiprocessing as mp

### For Arial Font
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'   # Set the defaul
rcParams['font.sans-serif'] = ['Arial']  # Make sure to have the font installed (it is on cluster for Harald)

### To do lowess smoothing
import statsmodels.api as sm
lowess = sm.nonparametric.lowess

socket_name = socket.gethostname()
print(socket_name)
if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")

sys.path.append("./PackagesSupport/")
from roh_expectations import Expected_Roh
# Out:
# midway2-0401.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# ### Calculate some expectations

# %%
# %%time
bins = [[0.04,0.08],[0.08,0.12],[0.12,3.00]]  # The bins I want to plot (eventually maybe do 12,16 as welll)

cousins = [1, 2, 3]  # Which Cousins to Plot
Ns= [500, 1000, 2000, 4000, 8000]

e_roh = Expected_Roh()

### Calcualte Expectations Cousins:
c_roh = np.zeros((len(cousins),len(bins))) # Container for results Cousins
for i,c in enumerate(cousins):
    for j,b in enumerate(bins):
        m = c*2 + 4
        c_roh[i,j] = e_roh.exp_roh_len_in_bin_rel(l=b, m=m, comm_anc=4, bins=10000)
        
### Calculate Expectations Ne:
n_roh = np.zeros((len(Ns),len(bins))) # Container for results Cousins
for i,N in enumerate(Ns):
    for j,b in enumerate(bins):
        n_roh[i,j] = e_roh.exp_roh_len_in_bin_N(b, N=N, bins=10000)
# Out:
# CPU times: user 369 ms, sys: 22.2 ms, total: 391 ms
# Wall time: 389 ms

# %%
c_roh
# Out:
# array([[0.15417107, 0.1989896 , 1.79197005],
#        [0.0579345 , 0.06908513, 0.39969971],
#        [0.01947492, 0.02146337, 0.08786535]])

# %%
n_roh
# Out:
# array([[0.83738322, 0.28607663, 0.53889548],
#        [0.43030857, 0.14522717, 0.27116666],
#        [0.21814277, 0.07316938, 0.13601662],
#        [0.10982935, 0.03672473, 0.06811708],
#        [0.05510554, 0.01839751, 0.03408579]])

# %% [markdown]
# # Code for the Main Figure

# %% [markdown]
# ### Idea:
# Code should be very modular: The large figure uses gridspec to split
# up axis space, and on each axis I plot the bars, with legends / colors for populations below
# (and maybe small age inlets).
#
# The big code splits up the space according to sample Nr. The small axis do the lifting

# %% [markdown]
# ### Do a subfigure

# %%
def plot_bar_ax(ax, fracs, bins=[], c=["purple", "MediumBlue", "DeepPink"], x_ticks = ["1st C.", "2nd C.", "3rd C."], 
                ec = "silver", fs_l=10, fs = 10, fs_x=8, barWidth=0.95, ylim = [0,220], stds = [], title="", 
                yticks=False, legend=False, r_title=0):
    """Plot bars of ROH on Axis.
    ax: Where to Plot on
    fracs: Fractions of Expected ROH: [n Inds, n Bins]
    c: Which colors to plot
    bins: List of Bins (needed for legend - plotted if len()>0)
    yticks: Whether to plot Y tick Labels
    legend: Whether to plot Legend
    fs_x: Fontsize on the x Labels
    r_title: Rotation of the title"""
    y = fracs ### Fractions (along 1st axis length classses)
    x = np.arange(len(y))

    for i in range(len(y[0,:])): # From last to first (For Legend)
        b = np.sum(y[:,:i], axis=1)
        ax.bar(x, y[:,i], bottom=b, color=c[i], edgecolor=ec, width=barWidth, label=f"{bins[i,0]}-{bins[i,1]} cM", alpha=0.9)
        if len(stds)>0 and i>0: # Plot some standard deviations.
            ax1.errorbar(r, b, yerr=stds[:,i], fmt='none', linewidth=2, color="k")
    if legend:
        ax.legend(fontsize=fs_l, loc="upper right", title="Sum ROH in")
    ax.set_ylabel("Expected Sum ROH [cM]", fontsize=fs)
    ax.set_ylim(ylim)
    ax.set_xlim(x[0] - 0.7*barWidth, x[-1] + 0.7*barWidth)
    if len(x_ticks)>0:
        ax.set_xticks(x)
        ax.set_xticklabels(x_ticks, fontsize=fs_x, rotation=270)
    if not yticks:
        ax.set_yticklabels([])
        ax.set_ylabel("")
    if len(title)>0:
        ax.set_title(title, fontsize=fs, rotation=r_title)

# %%
wspace, hspace=0.05,0.01
figsize=(7,6)
width_ratios = [len(c_roh), len(n_roh)]
bins_cM=(np.array(bins)*100).astype("int")
savepath="./figures/bar_expectations.pdf"

fig = plt.figure(figsize=figsize)
gs = gridspec.GridSpec(1, 2, width_ratios=width_ratios, figure=fig)
ax_cousin = plt.subplot(gs[0])    # The left subplot (Timeline)
ax_Ne = plt.subplot(gs[1])
gs.update(wspace=wspace, hspace=hspace) # set the spacing between axes

### Do the Plotting
plot_bar_ax(ax_cousin, c_roh*100, bins_cM, yticks=True, legend=False,
           x_ticks = ["1st C.", "2nd C.", "3rd C."], title="Recent Loops")

ticks_N = [f"2N={i}" for i in Ns]
plot_bar_ax(ax_Ne, n_roh*100, bins_cM, yticks=False, legend=True,
           x_ticks = ticks_N, title="Small Pop. Size")

if len(savepath)>0:
    plt.savefig(savepath, bbox_inches = 'tight', pad_inches = 0, dpi=300)
    print(f"Saved figure to {savepath}")
    
plt.show()
# Out:
# Saved figure to ./figures/bar_expectations.pdf

# %% [markdown]
# ## Do the Plot for empirical data

# %% [markdown]
# ### Start with Roman Data

# %%
### Maybe move this to be a Python Helper Function at some Point
def prepare_dfs_plot(df, cms):
    """Prepare the Dataframe which to plot
    Return split up (and sorted) list of df, return list of column names
    df: Master Dataframe
    cms: Minimum Length of Chromosomes
    """
    plot_dfs = [df for _, df in df1.groupby('clst')]

    ### Sort by age
    idx = np.argsort([-df["age"].values[0] for df in plot_dfs])
    plot_dfs = [plot_dfs[i] for i in idx] ## Sort
    
    ### Sort by 
    cms = [4,8,12]
    cols = [f"sum_roh>{cm}" for cm in cms]
    for df in plot_dfs:
        df.sort_values(by=cols[0], inplace=True, ascending=False)
    return plot_dfs, cols
    
def pre_process_roman_df(df, age_error=0, remove_sard=False):
    """Preprocess and return roman df and adds colors"""
    color_dict = {"Medieval/EarlyModern":"yellow", "Imperial":"red", "Iron/Republic":"magenta", "LateAntiquity":"orange", 
              "Copper Age":"aquamarine", "Neolithic":"dodgerblue", "Mesolithic":"purple", "(not included in analyses)":"gray"}
    df["color"] = df["clst"].map(color_dict)
    if age_error>0:
        df["age"]+= np.random.random(len(df))*age_error - age_error/2
        
    ### Remove the 
    if remove_sard:
        del_idx = (df["clst"] == "(not included in analyses)")
        df = df[~del_idx]
    return df

# %%
df1 = pd.read_csv("./Empirical/1240k/Antonio/combined_roh05.csv", sep="\t")
df1 = pre_process_roman_df(df1, age_error=100, remove_sard=True)

plot_dfs, cols = prepare_dfs_plot(df1, cms)

# %%
wspace, hspace=0.05,0.01
figsize=(24,3.5)
bins_cM=(np.array(bins)*100).astype("int")
savepath="./figures/roh_"
wspace=0.03
n_plots = len(plot_dfs)+2

width_ratios = [len(df) for df in plot_dfs]+[len(c_roh),len(n_roh)]

fig = plt.figure(figsize=figsize)
gs = gridspec.GridSpec(1, n_plots, width_ratios=width_ratios, figure=fig)
gs.update(wspace=wspace, hspace=hspace) # set the spacing between axes

for i,df in enumerate(plot_dfs):   
    if i==0:
        ytick=True
    else:
        ytick=False
        
    if i == (len(plot_dfs)-1):
        legend=True
    else:
        legend=False
        
    ax = plt.subplot(gs[i])    # Extract the Sub Plot to Plot onto
    obs_roh = df[cols].values
    obs_roh[:,0] = obs_roh[:,0] - obs_roh[:,1]
    obs_roh[:,1] = obs_roh[:,1] - obs_roh[:,2]
    obs_roh[:,2] = obs_roh[:,2]

    plot_bar_ax(ax, obs_roh, bins_cM, yticks=ytick, legend=legend, 
                x_ticks = df["iid"].values, title=df["pop"].values[0], ylim=[0,400])

#### Plot the legend bars:

### Do the Plotting
ax = plt.subplot(gs[-2])    # The left subplot (Timeline)
plot_bar_ax(ax, c_roh*100, bins_cM, yticks=False, legend=False,
           x_ticks = ["1st C.", "2nd C.", "3rd C."], title="Recent Loops", r_title=45)

ax = plt.subplot(gs[-1])
ticks_N = [f"2N={i}" for i in Ns]
plot_bar_ax(ax, n_roh*100, bins_cM, yticks=False, legend=False,
           x_ticks = ticks_N, title="Small Pop. Size", r_title=45)
    
#### Save if needed
if len(savepath)>0:
    plt.savefig(savepath, bbox_inches = 'tight', pad_inches = 0, dpi=300)
    print(f"Saved figure to {savepath}")
    
plt.show()

# %% [markdown]
# # Area 51

# %%
plot_dfs[-1]
# Out:
#            iid                   pop    max_roh  sum_roh>4  n_roh>4  \
# 8    RMPR-1286  Medieval/EarlyModern  21.918601  35.594499        3
# 13     RMPR-52  Medieval/EarlyModern   9.521901  22.073316        3
# 15     RMPR-56  Medieval/EarlyModern  12.597394  16.789698        2
# 25    RMPR-973  Medieval/EarlyModern   8.993816   8.993816        1
# 27     RMPR-65  Medieval/EarlyModern   4.436099   8.493995        2
# 29    RMPR-970  Medieval/EarlyModern   6.677801   6.677801        1
# 31     RMPR-57  Medieval/EarlyModern   4.897201   4.897201        1
# 37   RMPR-1224  Medieval/EarlyModern   4.436099   4.436099        1
# 72     RMPR-59  Medieval/EarlyModern   0.000000   0.000000        0
# 69   RMPR-1285  Medieval/EarlyModern   0.000000   0.000000        0
# 71     RMPR-63  Medieval/EarlyModern   0.000000   0.000000        0
# 77   RMPR-1289  Medieval/EarlyModern   0.000000   0.000000        0
# 73     RMPR-60  Medieval/EarlyModern   0.000000   0.000000        0
# 74   RMPR-1283  Medieval/EarlyModern   0.000000   0.000000        0
# 75   RMPR-1288  Medieval/EarlyModern   0.000000   0.000000        0
# 67     RMPR-54  Medieval/EarlyModern   0.000000   0.000000        0
# 68   RMPR-1287  Medieval/EarlyModern   0.000000   0.000000        0
# 63     RMPR-53  Medieval/EarlyModern   0.000000   0.000000        0
# 66     RMPR-64  Medieval/EarlyModern   0.000000   0.000000        0
# 65     RMPR-62  Medieval/EarlyModern   0.000000   0.000000        0
# 64   RMPR-1290  Medieval/EarlyModern   0.000000   0.000000        0
# 62     RMPR-55  Medieval/EarlyModern   0.000000   0.000000        0
# 61     RMPR-58  Medieval/EarlyModern   0.000000   0.000000        0
# 54   RMPR-1221  Medieval/EarlyModern   0.000000   0.000000        0
# 48   RMPR-1220  Medieval/EarlyModern   0.000000   0.000000        0
# 46   RMPR-1219  Medieval/EarlyModern   0.000000   0.000000        0
# 41     RMPR-61  Medieval/EarlyModern   0.000000   0.000000        0
# 130   RMPR-969  Medieval/EarlyModern   0.000000   0.000000        0
#
#      sum_roh>8  n_roh>8  sum_roh>12  n_roh>12        lat        lon  \
# 8    21.918601        1   21.918601         1        NaN        NaN
# 13   17.964005        2    0.000000         0  41.687731  13.086495
# 15   12.597394        1   12.597394         1  41.687731  13.086495
# 25    8.993816        1    0.000000         0  41.955917  12.754282
# 27    0.000000        0    0.000000         0  41.687731  13.086495
# 29    0.000000        0    0.000000         0  41.955917  12.754282
# 31    0.000000        0    0.000000         0  41.687731  13.086495
# 37    0.000000        0    0.000000         0        NaN        NaN
# 72    0.000000        0    0.000000         0  41.687731  13.086495
# 69    0.000000        0    0.000000         0        NaN        NaN
# 71    0.000000        0    0.000000         0  41.687731  13.086495
# 77    0.000000        0    0.000000         0        NaN        NaN
# 73    0.000000        0    0.000000         0  41.687731  13.086495
# 74    0.000000        0    0.000000         0        NaN        NaN
# 75    0.000000        0    0.000000         0        NaN        NaN
# 67    0.000000        0    0.000000         0  41.687731  13.086495
# 68    0.000000        0    0.000000         0        NaN        NaN
# 63    0.000000        0    0.000000         0  41.687731  13.086495
# 66    0.000000        0    0.000000         0  41.687731  13.086495
# 65    0.000000        0    0.000000         0  41.687731  13.086495
# 64    0.000000        0    0.000000         0        NaN        NaN
# 62    0.000000        0    0.000000         0  41.687731  13.086495
# 61    0.000000        0    0.000000         0  41.687731  13.086495
# 54    0.000000        0    0.000000         0        NaN        NaN
# 48    0.000000        0    0.000000         0        NaN        NaN
# 46    0.000000        0    0.000000         0        NaN        NaN
# 41    0.000000        0    0.000000         0  41.687731  13.086495
# 130   0.000000        0    0.000000         0  41.955917  12.754282
#
#              age          age_range        study                  clst  \
# 8     506.376017  1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 13    547.756204  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 15    607.404889  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 25    282.389291       1600-1700 CE  Antonio2019  Medieval/EarlyModern
# 27    804.437283  1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 29    335.057597       1600-1700 CE  Antonio2019  Medieval/EarlyModern
# 31    835.836461  1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 37    470.592337       1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 72   1043.388274    820 - 990 calCE  Antonio2019  Medieval/EarlyModern
# 69    901.560160   974 - 1035 calCE  Antonio2019  Medieval/EarlyModern
# 71    963.261752   970 - 1010 calCE  Antonio2019  Medieval/EarlyModern
# 77    502.233543  1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 73   1031.816039    820 - 990 calCE  Antonio2019  Medieval/EarlyModern
# 74   1070.072341    771 - 947 calCE  Antonio2019  Medieval/EarlyModern
# 75    513.241843  1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 67    641.962114  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 68    519.004162  1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 63    554.155343  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 66    883.587658  1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 65    739.832906  1130 - 1300 calCE  Antonio2019  Medieval/EarlyModern
# 64    599.412368  1295 - 1400 calCE  Antonio2019  Medieval/EarlyModern
# 62    576.439781  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 61    875.526211      700 - 1500 CE  Antonio2019  Medieval/EarlyModern
# 54    437.984459       1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 48    421.110991       1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 46    526.347530  1417 - 1463 calCE  Antonio2019  Medieval/EarlyModern
# 41    602.372577  1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 130   255.030063       1600-1700 CE  Antonio2019  Medieval/EarlyModern
#
#      mean_cov  n_cov_snp  include_alt   color
# 8        1.05     349979            1  yellow
# 13       0.67     273478            1  yellow
# 15       0.92     311581            1  yellow
# 25       1.15     353636            1  yellow
# 27       2.04     438123            1  yellow
# 29       0.61     259155            1  yellow
# 31       1.23     361222            1  yellow
# 37       1.10     344821            1  yellow
# 72       1.44     391580            1  yellow
# 69       0.99     340817            1  yellow
# 71       1.97     437544            1  yellow
# 77       0.76     296503            1  yellow
# 73       1.91     428944            1  yellow
# 74       1.04     350515            1  yellow
# 75       1.14     358402            1  yellow
# 67       0.81     302155            1  yellow
# 68       1.14     361495            1  yellow
# 63       1.22     382883            1  yellow
# 66       1.93     435049            1  yellow
# 65       1.69     416894            1  yellow
# 64       1.08     357974            1  yellow
# 62       1.43     397654            1  yellow
# 61       1.49     407668            1  yellow
# 54       1.32     378458            1  yellow
# 48       1.02     338580            1  yellow
# 46       1.61     407981            1  yellow
# 41       1.45     399332            1  yellow
# 130      2.38     454015            1  yellow

# %%
df1.sort_values(by="age", ascending=False)
# Out:
#            iid                   pop    max_roh   sum_roh>4  n_roh>4  \
# 2      RMPR-11            Mesolithic  10.980404  191.567313       31
# 0       RMPR-7            Mesolithic  37.333095  346.216686       33
# 7      RMPR-15            Mesolithic  10.150099   60.890585       10
# 10      RMPR-2             Neolithic  18.690200   23.214896        2
# 26      RMPR-3             Neolithic   8.915007    8.915007        1
# 17      RMPR-8             Neolithic   9.852400   15.053700        2
# 35     RMPR-10             Neolithic   4.449797    4.449797        1
# 103     RMPR-9             Neolithic   0.000000    0.000000        0
# 6      RMPR-18             Neolithic  19.562900   64.587696        6
# 16     RMPR-17             Neolithic   5.937898   16.723502        3
# 39     RMPR-16             Neolithic   4.129300    4.129300        1
# 33      RMPR-6             Neolithic   4.640800    4.640800        1
# 22   RMPR-1014            Copper Age   5.460197    9.570694        2
# 21      RMPR-5            Copper Age   5.276799    9.766596        2
# 102     RMPR-4            Copper Age   0.000000    0.000000        0
# 14      RMPR-1         Iron/Republic   9.731700   18.263896        2
# 1    RMPR-1015         Iron/Republic  33.832001  295.741615       22
# 11   RMPR-1021         Iron/Republic  10.643700   23.087696        3
# 5    RMPR-474b         Iron/Republic  39.824103   96.374095        4
# 3     RMPR-473         Iron/Republic  54.987099  181.709890       11
# 99    RMPR-850         Iron/Republic   0.000000    0.000000        0
# 23    RMPR-851         Iron/Republic   9.278000    9.278000        1
# 98   RMPR-475b         Iron/Republic   0.000000    0.000000        0
# 30   RMPR-435b         Iron/Republic   6.303501    6.303501        1
# 97   RMPR-437b         Iron/Republic   0.000000    0.000000        0
# 96     RMPR-42              Imperial   0.000000    0.000000        0
# 28     RMPR-80              Imperial   7.488703    7.488703        1
# 81    RMPR-114              Imperial   0.000000    0.000000        0
# 92    RMPR-111              Imperial   0.000000    0.000000        0
# 87     RMPR-76              Imperial   0.000000    0.000000        0
# ..         ...                   ...        ...         ...      ...
# 49    RMPR-106         LateAntiquity   0.000000    0.000000        0
# 24    RMPR-104         LateAntiquity   4.888302    9.082192        2
# 74   RMPR-1283  Medieval/EarlyModern   0.000000    0.000000        0
# 72     RMPR-59  Medieval/EarlyModern   0.000000    0.000000        0
# 73     RMPR-60  Medieval/EarlyModern   0.000000    0.000000        0
# 71     RMPR-63  Medieval/EarlyModern   0.000000    0.000000        0
# 69   RMPR-1285  Medieval/EarlyModern   0.000000    0.000000        0
# 66     RMPR-64  Medieval/EarlyModern   0.000000    0.000000        0
# 31     RMPR-57  Medieval/EarlyModern   4.897201    4.897201        1
# 27     RMPR-65  Medieval/EarlyModern   4.436099    8.493995        2
# 61     RMPR-58  Medieval/EarlyModern   0.000000    0.000000        0
# 65     RMPR-62  Medieval/EarlyModern   0.000000    0.000000        0
# 67     RMPR-54  Medieval/EarlyModern   0.000000    0.000000        0
# 62     RMPR-55  Medieval/EarlyModern   0.000000    0.000000        0
# 13     RMPR-52  Medieval/EarlyModern   9.521901   22.073316        3
# 41     RMPR-61  Medieval/EarlyModern   0.000000    0.000000        0
# 63     RMPR-53  Medieval/EarlyModern   0.000000    0.000000        0
# 15     RMPR-56  Medieval/EarlyModern  12.597394   16.789698        2
# 75   RMPR-1288  Medieval/EarlyModern   0.000000    0.000000        0
# 64   RMPR-1290  Medieval/EarlyModern   0.000000    0.000000        0
# 8    RMPR-1286  Medieval/EarlyModern  21.918601   35.594499        3
# 68   RMPR-1287  Medieval/EarlyModern   0.000000    0.000000        0
# 37   RMPR-1224  Medieval/EarlyModern   4.436099    4.436099        1
# 46   RMPR-1219  Medieval/EarlyModern   0.000000    0.000000        0
# 54   RMPR-1221  Medieval/EarlyModern   0.000000    0.000000        0
# 77   RMPR-1289  Medieval/EarlyModern   0.000000    0.000000        0
# 48   RMPR-1220  Medieval/EarlyModern   0.000000    0.000000        0
# 130   RMPR-969  Medieval/EarlyModern   0.000000    0.000000        0
# 29    RMPR-970  Medieval/EarlyModern   6.677801    6.677801        1
# 25    RMPR-973  Medieval/EarlyModern   8.993816    8.993816        1
#
#       sum_roh>8  n_roh>8  sum_roh>12  n_roh>12        lat        lon  \
# 2     68.404394        7    0.000000         0  41.960000  13.540000
# 0    246.960992       15  200.666098        10  41.960000  13.540000
# 7     19.474089        2    0.000000         0  41.960000  13.540000
# 10    18.690200        1   18.690200         1  41.960000  13.540000
# 26     8.915007        1    0.000000         0  41.960000  13.540000
# 17     9.852400        1    0.000000         0  41.960000  13.540000
# 35     0.000000        0    0.000000         0  41.960000  13.540000
# 103    0.000000        0    0.000000         0  41.960000  13.540000
# 6     48.383302        3   48.383302         3  43.722396  13.033897
# 16     0.000000        0    0.000000         0  43.722396  13.033897
# 39     0.000000        0    0.000000         0  43.722396  13.033897
# 33     0.000000        0    0.000000         0  41.960000  13.540000
# 22     0.000000        0    0.000000         0  41.367018  13.291351
# 21     0.000000        0    0.000000         0  41.960000  13.540000
# 102    0.000000        0    0.000000         0  41.960000  13.540000
# 14    18.263896        2    0.000000         0  42.880140  13.893765
# 1    251.714607       15  221.255304        12  42.016838  12.100415
# 11    10.643700        1    0.000000         0  41.643329  12.912691
# 5     96.374095        4   96.374095         4  42.088860  11.765646
# 3    170.238493        9  138.308689         6  42.088860  11.765646
# 99     0.000000        0    0.000000         0  41.602678  12.508636
# 23     9.278000        1    0.000000         0  41.602678  12.508636
# 98     0.000000        0    0.000000         0  42.088860  11.765646
# 30     0.000000        0    0.000000         0  41.795242  12.778956
# 97     0.000000        0    0.000000         0  41.795242  12.778956
# 96     0.000000        0    0.000000         0  41.747882  12.259475
# 28     0.000000        0    0.000000         0        NaN        NaN
# 81     0.000000        0    0.000000         0        NaN        NaN
# 92     0.000000        0    0.000000         0        NaN        NaN
# 87     0.000000        0    0.000000         0        NaN        NaN
# ..          ...      ...         ...       ...        ...        ...
# 49     0.000000        0    0.000000         0  41.894776  12.476266
# 24     0.000000        0    0.000000         0  41.894776  12.476266
# 74     0.000000        0    0.000000         0        NaN        NaN
# 72     0.000000        0    0.000000         0  41.687731  13.086495
# 73     0.000000        0    0.000000         0  41.687731  13.086495
# 71     0.000000        0    0.000000         0  41.687731  13.086495
# 69     0.000000        0    0.000000         0        NaN        NaN
# 66     0.000000        0    0.000000         0  41.687731  13.086495
# 31     0.000000        0    0.000000         0  41.687731  13.086495
# 27     0.000000        0    0.000000         0  41.687731  13.086495
# 61     0.000000        0    0.000000         0  41.687731  13.086495
# 65     0.000000        0    0.000000         0  41.687731  13.086495
# 67     0.000000        0    0.000000         0  41.687731  13.086495
# 62     0.000000        0    0.000000         0  41.687731  13.086495
# 13    17.964005        2    0.000000         0  41.687731  13.086495
# 41     0.000000        0    0.000000         0  41.687731  13.086495
# 63     0.000000        0    0.000000         0  41.687731  13.086495
# 15    12.597394        1   12.597394         1  41.687731  13.086495
# 75     0.000000        0    0.000000         0        NaN        NaN
# 64     0.000000        0    0.000000         0        NaN        NaN
# 8     21.918601        1   21.918601         1        NaN        NaN
# 68     0.000000        0    0.000000         0        NaN        NaN
# 37     0.000000        0    0.000000         0        NaN        NaN
# 46     0.000000        0    0.000000         0        NaN        NaN
# 54     0.000000        0    0.000000         0        NaN        NaN
# 77     0.000000        0    0.000000         0        NaN        NaN
# 48     0.000000        0    0.000000         0        NaN        NaN
# 130    0.000000        0    0.000000         0  41.955917  12.754282
# 29     0.000000        0    0.000000         0  41.955917  12.754282
# 25     8.993816        1    0.000000         0  41.955917  12.754282
#
#               age            age_range        study                  clst  \
# 2    11904.406617  10100 - 9816 calBCE  Antonio2019            Mesolithic
# 0    10642.649438   8821 - 8642 calBCE  Antonio2019            Mesolithic
# 7     9157.981902  7284 - 7065  calBCE  Antonio2019            Mesolithic
# 10    7972.743159   6066 - 6002 calBCE  Antonio2019             Neolithic
# 26    7777.967242   5836 - 5723 calBCE  Antonio2019             Neolithic
# 17    7686.833604   5832 - 5715 calBCE  Antonio2019             Neolithic
# 35    7657.574384   5717 - 5641 calBCE  Antonio2019             Neolithic
# 103   7543.808667   5607 - 5485 calBCE  Antonio2019             Neolithic
# 6     7343.482689   5465 - 5232 calBCE  Antonio2019             Neolithic
# 16    7199.864780   5324 - 5223 calBCE  Antonio2019             Neolithic
# 39    7186.684674   5301 - 5214 calBCE  Antonio2019             Neolithic
# 33    7179.699117   5242 - 5177 calBCE  Antonio2019             Neolithic
# 22    4931.658389      3500 - 2500 BCE  Antonio2019            Copper Age
# 21    4881.043376   2902 - 2877 calBCE  Antonio2019            Copper Age
# 102   4865.224757   2950 - 2880 calBCE  Antonio2019            Copper Age
# 14    2818.603825     930 - 839 calBCE  Antonio2019         Iron/Republic
# 1     2809.567274        900 - 800 BCE  Antonio2019         Iron/Republic
# 11    2644.602368        700 - 600 BCE  Antonio2019         Iron/Republic
# 5     2627.107853        700 - 600 BCE  Antonio2019         Iron/Republic
# 3     2570.126131        700 - 600 BCE  Antonio2019         Iron/Republic
# 99    2568.122513        800 - 500 BCE  Antonio2019         Iron/Republic
# 23    2565.476104        800 - 500 BCE  Antonio2019         Iron/Republic
# 98    2555.722932        700 - 600 BCE  Antonio2019         Iron/Republic
# 30    2384.877313        600 - 200 BCE  Antonio2019         Iron/Republic
# 97    2200.674230        400 - 200 BCE  Antonio2019         Iron/Republic
# 96    1918.703982       22 - 120 calCE  Antonio2019              Imperial
# 28    1911.985209       23 - 130 calCE  Antonio2019              Imperial
# 81    1897.108628           0 - 200 CE  Antonio2019              Imperial
# 92    1890.942356           0 - 200 CE  Antonio2019              Imperial
# 87    1879.747691           0 - 200 CE  Antonio2019              Imperial
# ..            ...                  ...          ...                   ...
# 49    1422.239138         400 - 600 CE  Antonio2019         LateAntiquity
# 24    1408.033233         400 - 600 CE  Antonio2019         LateAntiquity
# 74    1075.611595      771 - 947 calCE  Antonio2019  Medieval/EarlyModern
# 72    1008.060794      820 - 990 calCE  Antonio2019  Medieval/EarlyModern
# 73     997.780094      820 - 990 calCE  Antonio2019  Medieval/EarlyModern
# 71     972.590485     970 - 1010 calCE  Antonio2019  Medieval/EarlyModern
# 69     942.763637     974 - 1035 calCE  Antonio2019  Medieval/EarlyModern
# 66     883.955052    1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 31     841.086441    1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 27     822.596730    1070 - 1150 calCE  Antonio2019  Medieval/EarlyModern
# 61     802.140689        700 - 1500 CE  Antonio2019  Medieval/EarlyModern
# 65     701.083799    1130 - 1300 calCE  Antonio2019  Medieval/EarlyModern
# 67     635.558639    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 62     633.233893    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 13     610.741976    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 41     607.703871    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 63     602.769872    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 15     564.249302    1280 - 1430 calCE  Antonio2019  Medieval/EarlyModern
# 75     558.036632    1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 64     552.558918    1295 - 1400 calCE  Antonio2019  Medieval/EarlyModern
# 8      552.154400    1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 68     538.524246    1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 37     511.518567         1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 46     499.292208    1417 - 1463 calCE  Antonio2019  Medieval/EarlyModern
# 54     497.911379         1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 77     495.210869    1411 - 1447 calCE  Antonio2019  Medieval/EarlyModern
# 48     450.794546         1480-1490 CE  Antonio2019  Medieval/EarlyModern
# 130    342.762234         1600-1700 CE  Antonio2019  Medieval/EarlyModern
# 29     322.151024         1600-1700 CE  Antonio2019  Medieval/EarlyModern
# 25     272.507128         1600-1700 CE  Antonio2019  Medieval/EarlyModern
#
#      mean_cov  n_cov_snp  include_alt       color
# 2        0.92     359115            1      purple
# 0        3.03     468510            1      purple
# 7        2.95     468010            1      purple
# 10       3.64     472906            1  dodgerblue
# 26       3.99     475146            1  dodgerblue
# 17       0.52     226962            1  dodgerblue
# 35       1.30     382391            1  dodgerblue
# 103      3.88     475616            1  dodgerblue
# 6        0.62     251333            1  dodgerblue
# 16       0.54     237489            1  dodgerblue
# 39       0.56     228382            1  dodgerblue
# 33       0.58     244292            1  dodgerblue
# 22       0.59     259160            1  aquamarine
# 21       1.48     406488            1  aquamarine
# 102      3.53     472937            1  aquamarine
# 14       3.94     474732            1     magenta
# 1        0.87     290827            1     magenta
# 11       0.56     246980            1     magenta
# 5        1.27     369527            1     magenta
# 3        1.55     447936            1     magenta
# 99       0.64     273039            1     magenta
# 23       0.69     283736            1     magenta
# 98       1.25     362655            1     magenta
# 30       1.00     339031            1     magenta
# 97       1.41     388778            1     magenta
# 96       2.35     473507            1         red
# 28       1.90     432984            1         red
# 81       1.17     365698            1         red
# 92       0.59     243940            1         red
# 87       0.64     267796            1         red
# ..        ...        ...          ...         ...
# 49       1.06     347498            1      orange
# 24       0.85     308078            1      orange
# 74       1.04     350515            1      yellow
# 72       1.44     391580            1      yellow
# 73       1.91     428944            1      yellow
# 71       1.97     437544            1      yellow
# 69       0.99     340817            1      yellow
# 66       1.93     435049            1      yellow
# 31       1.23     361222            1      yellow
# 27       2.04     438123            1      yellow
# 61       1.49     407668            1      yellow
# 65       1.69     416894            1      yellow
# 67       0.81     302155            1      yellow
# 62       1.43     397654            1      yellow
# 13       0.67     273478            1      yellow
# 41       1.45     399332            1      yellow
# 63       1.22     382883            1      yellow
# 15       0.92     311581            1      yellow
# 75       1.14     358402            1      yellow
# 64       1.08     357974            1      yellow
# 8        1.05     349979            1      yellow
# 68       1.14     361495            1      yellow
# 37       1.10     344821            1      yellow
# 46       1.61     407981            1      yellow
# 54       1.32     378458            1      yellow
# 77       0.76     296503            1      yellow
# 48       1.02     338580            1      yellow
# 130      2.38     454015            1      yellow
# 29       0.61     259155            1      yellow
# 25       1.15     353636            1      yellow
#
# [124 rows x 19 columns]
