# %% [markdown]
# # Notebook to call ROH for individuals within a Eigenstrat folder
# Notebooks that import the code for the calling ROHs on pseudohaploid genotype individuals, and then a function to parallelize it.
#
# Very similar to parallel_mosaic_callroh.ipynb
#
#
# @Author: Harald Ringbauer, September 2019
# All rights reserved.

# %%
import numpy as np
import os as os
import sys as sys
import multiprocessing as mp
import pandas as pd
import socket

### Pick the right path (whether on cluster or at home)
socket_name = socket.gethostname()
print(socket_name)

if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)

# Assume that now we are in the root directory
sys.path.append("./package/")  

from hapsburg.hmm_inference import HMM_Analyze   # The HMM core object

from hapsburg.PackagesSupport.hapsburg_run import hapsb_chrom, hapsb_ind
#from hapsburg.PackagesSupport.parallel_runs.helper_functions import prepare_path, multi_run, combine_individual_data
from hapsburg.PackagesSupport.pp_individual_roh_csvs import create_combined_ROH_df, give_iid_paths, pp_individual_roh

print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")
# Out:
# midway2-0401.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# ## Call ROH single Individual
# For reanalysis with delete=True (saves all data) to plot that indivdual / further analysis of posterior

# %%
# %%time
hapsb_ind(iid="TAF010", chs=range(22,23), processes=1, delete=False, 
          output=True, save=True, save_fp=False, n_ref=2504, 
          exclude_pops=[], e_model="haploid", p_model="EigenstratPacked", readcounts=False, destroy_phase=True,
          post_model="Standard", path_targets = "./Data/ReichLabEigenstrat/Raw/v37.2.1240K",
          h5_path1000g = "./Data/1000Genomes/HDF5/1240kHDF5/all1240int8/chr", 
          meta_path_ref = "./Data/1000Genomes/Individuals/meta_df_all.csv",
          base_out_folder="./Empirical/Eigenstrat/Reichall/test/", prefix_out="",
          roh_in=1, roh_out=10, roh_jump=300, e_rate=0.01, e_rate_ref=0.00, 
          max_gap=0, cutoff = 0.999, l_cutoff = 0.01, logfile=False, 
          combine=True, file_name="_roh_full.csv")

# %% [markdown]
# ### Run full Individual

# %%
hapsb_ind(iid="Yaghan895.SG", chs=range(1,23), processes=8, delete=False, output=True, 
          save=True, save_fp=False, n_ref=2504, 
          exclude_pops=[], e_model="haploid", p_model="EigenstratPacked", readcounts=False, destroy_phase=True,
          post_model="Standard", path_targets = "./Data/ReichLabEigenstrat/Raw/v37.2.1240K",
          h5_path1000g = "./Data/1000Genomes/HDF5/1240kHDF5/all1240int8/chr", 
          meta_path_ref = "./Data/1000Genomes/Individuals/meta_df_all.csv",
          base_out_folder="./Empirical/Eigenstrat/Reichall/test/", prefix_out="",
          roh_in=1, roh_out=10, roh_jump=300, e_rate=0.01, e_rate_ref=0.00, 
          max_gap=0, cutoff = 0.999, l_cutoff = 0.01, logfile=True, combine=True, file_name="_roh_full.csv")
# Out:
# Doing Individual Loschbour_published.DG...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr9/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr10/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr11/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr12/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr13/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Reichall/test/Loschbour_published.DG/chr14/hmm_run_log.txt

# %% [markdown]
# # Post-Process the individual output files into one summary .csv
# (Standalone from here - but **need imports** from above)

# %% [markdown]
# ### Decide which IIDs to post-process

# %%
def load_eigenstrat_anno(path="./Data/ReichLabEigenstrat/Raw/v37.2.1240K.clean4.anno", 
                         anc_only=True, min_snps=400000):
    """Load annotated Eigenstrat (from D. Reich's group).
    anc_only: Return only the ancients with age>0"""
    df_anno = pd.read_csv(path, sep="\t", engine="python")
    coverage = pd.to_numeric(df_anno["Coverage"], errors='coerce')
    df_anno["coverage"]=coverage

    # Convert the Ages as well
    ages = df_anno["Average of 95.4% date range in calBP (defined as 1950 CE)  "]
    df_anno["ages"] = pd.to_numeric(ages, errors='coerce')  #

    ### Convert Longitude and Latitude
    lat = df_anno["Lat."]
    lon = df_anno["Long."]
    df_anno["lat"] = pd.to_numeric(lat, errors='coerce')
    df_anno["lon"] = pd.to_numeric(lon, errors='coerce')
    
    df_anc = df_anno[df_anno["ages"]>0]

    print(f"Loaded {len(df_anc)} / {len(df_anno)} ancient Indivdiuals Anno File.")
    
    if anc_only:
        df_anno=df_anc
        
    df_anno = df_anno[df_anno["SNPs hit on autosomes"]>min_snps]
    print(f"Loaded {len(df_anno)} Individuals with >{min_snps} SNPs covered")
    return df_anno

def load_meta_csv(path="", anc_only=True, min_snps=400000,
                 cov_col="n_cov_snp"):
    """Load dataframe from pre-processed Metafile"""
    df = pd.read_csv(path, sep=",")
    
    if anc_only:
        df_anc = df[df["age"]>0]
        print(f"Loaded {len(df_anc)} / {len(df)} ancient Indivdiuals Anno File.")
        df=df_anc
        
    df[cov_col] = pd.to_numeric(df[cov_col], errors="coerce")
    df = df[df[cov_col]>min_snps]
    print(f"Loaded {len(df)} Individuals with >{min_snps} SNPs covered")
    return df

# %% [markdown]
# ### Post-process v37

# %%
df_anno = load_eigenstrat_anno(path="./Data/ReichLabEigenstrat/Raw/v37.2.1240K.clean4.anno")
iids = df_anno["Instance ID"]
# Out:
# Loaded 2106 / 5081 ancient Indivdiuals Anno File.
# Loaded 1095 Individuals with >400000 SNPs covered

# %%
# %%time
df1 = pp_individual_roh(iids=iids, meta_path="./Data/ReichLabEigenstrat/Raw/meta.csv", base_folder="./Empirical/Eigenstrat/Reichall/final/",
                        save_path="./Empirical/Eigenstrat/Reichall/final/combined_roh05.csv", output=False, min_cm=[4,8,12,20], 
                        snp_cm=50, gap=0.5, min_len1=2, min_len2=4)
# Out:
# Loaded 1095 / 2106 Individuals from Meta
# Warning, could not find 1 Paths:
# ['./Empirical/Eigenstrat/Reichall/final/IPY10.SG_roh_full.csv']
# Saved to: ./Empirical/Eigenstrat/Reichall/final/combined_roh05.csv
# CPU times: user 8min 13s, sys: 893 ms, total: 8min 14s
# Wall time: 8min 46s

# %% [markdown]
# # Do additional Individuals from V42 anno

# %%
df_t = load_meta_csv(path = "./Data/ReichLabEigenstrat/Raw/meta.v42.csv",
                        min_snps=400000)
iids = df_t["iid"]
# Out:
# Loaded 3723 / 3723 ancient Indivdiuals Anno File.
# Loaded 1924 Individuals with >400000 SNPs covered

# %%
# %%time
df1 = pp_individual_roh(iids=iids, meta_path="./Data/ReichLabEigenstrat/Raw/meta.v42.csv", 
                        base_folder="./Empirical/Eigenstrat/Reichall/v42_core/",
                        save_path="./Empirical/Eigenstrat/Reichall/combined_roh_v42.csv", 
                        output=False, min_cm=[4, 8, 12, 20], 
                        snp_cm=50, gap=0.5, min_len1=2, min_len2=4)
# Out:
# Loaded 1924 / 3723 Individuals from Meta
# Warning, could not find 1 Paths:
# ['./Empirical/Eigenstrat/Reichall/v42_core/I3041_all.SG_roh_full.csv']
# Saved to: ./Empirical/Eigenstrat/Reichall/combined_roh_v42.csv
# CPU times: user 13min 3s, sys: 980 ms, total: 13min 4s
# Wall time: 13min 55s

# %%
df1.sort_values(by="sum_roh>20", ascending=False)[:50]
# Out:
#                             iid  \
# 4                         I1178
# 9                      MJ-41.SG
# 24                        I2521
# 37                    tem003.SG
# 11                        I5320
# 5                      SN-44.SG
# 10                        I6671
# 12                     SN-13.SG
# 21                    ans017.SG
# 23                        I0308
# 32                        I1131
# 101                      SIJ003
# 60                     DA249.SG
# 17                   Andaman.SG
# 25                    ElMiron_d
# 45                       TAF010
# 100                       I7550
# 38                        I6940
# 56                        I4068
# 74                         CL25
# 0              Vindija_snpAD.DG
# 44                        I2606
# 121                       I2597
# 51                        I1752
# 53                        I4916
# 35                       FUT001
# 31                     R1015.SG
# 26                        R7.SG
# 34                     DA337.SG
# 28                     SN-11.SG
# 27                        I1357
# 1    Goyet_final_provisional.SG
# 69                        I7457
# 62                      R473.SG
# 95                        I2551
# 111                 RISE1249.SG
# 58                        I7340
# 139                     R121.SG
# 128                BOO006.A0101
# 3            Altai_published.DG
# 41                   Villabruna
# 36                        I5321
# 47                        I1118
# 184                       I7278
# 116                 RISE1161.SG
# 84                        I4634
# 159                     R474.SG
# 197                      I12982
# 151                      I11028
# 189                   I2937_all
#
#                                                    pop     max_roh  \
# 4                                             Israel_C   91.121798
# 9               Russia_EarlySarmatian_SouthernUrals.SG   39.571500
# 24                                          Bulgaria_N   68.662197
# 37                            Russia_Late_Sarmatian.SG  151.873398
# 11   USA_AK_Ancient_Athabaskan_1100BP_father.or.son...   58.043503
# 5                           USA_CA_Early_SanNicolas.SG   65.982402
# 10                            Turkmenistan_EBA_Parkhai   74.193197
# 12                           USA_CA_Late_SanNicolas.SG   59.737399
# 21                                Sweden_Megalithic.SG   61.531306
# 23                        Argentina_ArroyoSeco2_7700BP   46.770900
# 32                                           Serbia_EN   39.808393
# 101             Russia_LateMaikop_1d.rel.I11131.I11133   47.704199
# 60                       Russia_Shamanka_Eneolithic.SG   28.501499
# 17                        Indian_GreatAndaman_100BP.SG   43.705002
# 25                                      Iberia_ElMiron   37.929303
# 45                              Morocco_Iberomaurusian   29.580699
# 100                                          Iberia_MN   44.744998
# 38                                     India_RoopkundC   52.987200
# 56                              Netherlands_BellBeaker   54.575903
# 74                Italy_North_EarlyMedieval_Langobards   78.044004
# 0                                           Vindija.DG   28.103200
# 44                                           England_N   36.143899
# 121                                      England_C_EBA   37.800604
# 51                                Chile_Conchali_700BP   66.499400
# 53                         Serbia_Mesolithic_IronGates   45.695900
# 35                                      Vanuatu_1100BP   41.143793
# 31                                Italy_IA_Republic.SG   45.504404
# 26                                 Italy_Mesolithic.SG   37.298292
# 34                              Russia_Shamanka_EBA.SG   37.571603
# 28                           USA_CA_Late_SanNicolas.SG   36.820000
# 27                                 Peru_Laramate_900BP   23.552300
# 1                                 Goyet_Neanderthal.SG   32.282496
# 69                              Iberia_Muslim_Almohade   84.789699
# 62                                Italy_IA_Republic.SG   58.669200
# 95                                 Peru_Laramate_900BP   36.748397
# 111                            Poland_Ksiaznice_GAC.SG   29.679096
# 58                           Russia_OldBeringSea_Ekven   27.873201
# 139                                        Italy_LA.SG   30.516600
# 128                                     Russia_Bolshoy   26.702786
# 3                       Altai_Neanderthal_published.DG   28.093502
# 101       WangNatureCommunications2019
# 60                 DamgaardScience2018
# 17              MorenoMayarScience2018
# 25                        FuNature2016
# 45          vandeLoosdrechtScience2018
# 100                  OlaldeScience2019
# 38      HarneyNatureCommunications2019
# 56                    OlaldeNature2018
# 74      AmorimNatureCommunications2018
# 0                          Pruefer2017
# 44                    OlaldeNature2018
# 121                   OlaldeNature2018
# 51              PosthNakatsukaCell2018
# 53                 MathiesonNature2018
# 35     PosthNatureEcologyEvolution2018
# 31          AntonioGaoMootsScience2019
# 26          AntonioGaoMootsScience2019
# 34                 DamgaardScience2018
# 28                   ScheibScience2018
# 27              PosthNakatsukaCell2018
# 1                  HajdinjakNature2018
# 69                   OlaldeScience2019
# 62          AntonioGaoMootsScience2019
# 95              PosthNakatsukaCell2018
# 111                  SchroederPNAS2019
# 58                 FlegontovNature2019
# 139         AntonioGaoMootsScience2019
# 128   LamnidisNatureCommunications2018
# 3                    PrueferNature2013
# 41                        FuNature2016
# 36                 FlegontovNature2019
# 47                 FlegontovNature2019
# 184                   OlaldeNature2018
# 116                  SchroederPNAS2019
# 84      NarasimhanPattersonScience2019
# 159         AntonioGaoMootsScience2019
# 197     NarasimhanPattersonScience2019
# 151     NarasimhanPattersonScience2019
# 189                LazaridisNature2017
#
#                                                   clst   mean_cov  n_cov_snp  \
# 4                                             Israel_C      2.383     719331
# 9               Russia_EarlySarmatian_SouthernUrals.SG   0.439047     407399
# 24                                          Bulgaria_N      5.493     802956
# 37                            Russia_Late_Sarmatian.SG   1.128012     795721
# 11   USA_AK_Ancient_Athabaskan_1100BP_father.or.son...  12.788392    1004830
# 5                           USA_CA_Early_SanNicolas.SG    3.09714    1111229
# 10                            Turkmenistan_EBA_Parkhai   3.746394     863817
# 12                           USA_CA_Late_SanNicolas.SG   0.580568     509837
# 21                                Sweden_Megalithic.SG   2.961673    1109883
# 23                        Argentina_ArroyoSeco2_7700BP       0.53     454002
# 32                                           Serbia_EN      2.922     776289
# 101             Russia_LateMaikop_1d.rel.I11131.I11133   1.875562     745919
# 60                       Russia_Shamanka_Eneolithic.SG        4.5    1113894
# 17                        Indian_GreatAndaman_100BP.SG  18.180248    1163016
# 25                                      Iberia_ElMiron      1.012     627275
# 45                              Morocco_Iberomaurusian   3.060592     846250
# 100                                          Iberia_MN   1.185428     638374
# 38                                     India_RoopkundC    0.48852     419098
# 56                              Netherlands_BellBeaker      0.803     469691
# 74                Italy_North_EarlyMedieval_Langobards   1.089118     677055
# 0                                           Vindija.DG         30    1061414
# 44                                           England_N   1.180875     676373
# 121                                      England_C_EBA   3.235122     824991
# 51                                Chile_Conchali_700BP      2.271     789137
# 53                         Serbia_Mesolithic_IronGates      2.577     804977
# 35                                      Vanuatu_1100BP   1.182296     648761
# 31                                Italy_IA_Republic.SG   0.942467     656616
# 26                                 Italy_Mesolithic.SG   3.438531    1129613
# 34                              Russia_Shamanka_EBA.SG        1.1     685820
# 28                           USA_CA_Late_SanNicolas.SG   1.850441     975879
# 27                                 Peru_Laramate_900BP       1.22     721235
# 1                                 Goyet_Neanderthal.SG    1.49073     887911
# 69                              Iberia_Muslim_Almohade   0.601835     497137
# 62                                Italy_IA_Republic.SG   2.498703    1046443
# 95                                 Peru_Laramate_900BP      3.093     781443
# 111                            Poland_Ksiaznice_GAC.SG   0.944539     710701
# 58                           Russia_OldBeringSea_Ekven   0.968185     650411
# 139                                        Italy_LA.SG   0.666054     566906
# 128                                     Russia_Bolshoy    0.99568     602052
# 3                       Altai_Neanderthal_published.DG         52    1149663
# 41                           Italy_North_Villabruna_HG      3.137     902419
# 36                    USA_AK_Ancient_Athabaskan_1100BP  13.640076     998037
# 47                                     USA_AK_NeoAleut      3.551     759975
# 184                                   Czech_BellBeaker   3.567538     795922
# 116                              Poland_Koszyce_GAC.SG   1.224078     813323
# 84                              Turkmenistan_C_Parkhai      3.801     781276
# 159                               Italy_IA_Republic.SG   1.335601     860621
# 197                                Pakistan_IA_Loebanr    2.26158     768526
# 151                       Uzbekistan_Bustan_Eneolithic   1.127197     644891
# 189                           Greece_Peloponnese_N_all       2.02     747172
#
#      include_alt
# 4              1
# 9              1
# 24             1
# 37             1
# 11             1
# 5              1
# 10             1
# 12             1
# 21             1
# 23             1
# 32             1
# 101            1
# 60             1
# 17             1
# 25             1
# 45             1
# 100            1
# 38             0
# 56             1
# 74             1
# 0              1
# 44             1
# 121            1
# 51             1
# 53             1
# 35             1
# 31             1
# 26             1
# 34             1
# 28             1
# 27             1
# 1              1
# 69             0
# 62             1
# 95             1
# 111            1
# 58             0
# 139            1
# 128            1
# 3              1
# 41             1
# 36             1
# 47             0
# 184            1
# 116            1
# 84             1
# 159            1
# 197            1
# 151            1
# 189            1

# %% [markdown]
# # Legacy (for refactored Code)

# %%
analyze_chromosome_es(*prms[2])

# %%
### Legacy Cell for early Post-processing of IIDs
meta_path="./Data/ReichLabEigenstrat/Raw/meta.csv"
df_anno = pd.read_csv(meta_path)
df_ana = df_anno[df_anno["mean_cov"]>0.5]
print(len(df_ana))
df_ana = df_ana[:]  # how many individuals to extract
iids = df_ana["iid"].values

### Delete IPY10.SG (missing data for Chr.11-23)
d = np.where(iids=="IPY10.SG")[0][0]
iids = np.delete(iids, d)
print(f"Loaded {len(iids)} Individuals")
# Out:
# 1099
# Loaded 1098 Individuals

# %% [markdown]
# # Area 51
# Area to test code here

# %% [markdown]
# ### Test one Eigenstrat individual

# %%
analyze_chromosome_es(iid="I7579", ch=3, n_ref=500, save=True, save_fp=False, exclude_pops=[], 
                      base_out_folder="./Empirical/Eigenstrat/Reichall/test/", prefix_out="",
                      roh_in=100, roh_out=100, roh_jump=300, e_rate=0.01, e_rate_ref=0.001, 
                      max_gap=0, logfile=False)

# %%
#df_test = pd.read_csv("./Empirical/Eigenstrat/Reichall/IPY10.SG_roh_full.csv")
df_test = pd.read_csv("./Empirical/Eigenstrat/Reichall/IPK12.SG_roh_full.csv")
