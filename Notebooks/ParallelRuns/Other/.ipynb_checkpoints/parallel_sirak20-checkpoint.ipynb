# %%
import numpy as np
import os as os
import sys as sys
import multiprocessing as mp
import pandas as pd
import socket

### Pick the right path (whether on cluster or at home)
socket_name = socket.gethostname()
print(socket_name)
if socket_name == "VioletQueen":
    path = "/home/harald/git/HAPSBURG/"   # The Path on Harald's machine
elif socket_name.startswith("midway2"):
    print("Midway jnovmbre partition detected.")
    path = "/project2/jnovembre/hringbauer/HAPSBURG/"  # The Path on Midway Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd()) # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(f"CPU Count: {mp.cpu_count()}")

### Assume that now we are in the root directory
sys.path.append("./Python3/")  
sys.path.append("./PackagesSupport/parallel_runs/")
sys.path.append("./PackagesSupport/")

from hmm_inference import HMM_Analyze   # The HMM core object
from helper_functions import prepare_path, multi_run, combine_individual_data
from hapsburg_run import hapsb_chrom, hapsb_ind
from pp_individual_roh_csvs import create_combined_ROH_df, give_iid_paths, pp_individual_roh
# Out:
# midway2-0401.rcc.local
# Midway jnovmbre partition detected.
# /project2/jnovembre/hringbauer/HAPSBURG
# CPU Count: 28

# %% [markdown]
# ### Test single Individual

# %%
hapsb_ind(iid="I12575", chs=range(21,22), processes=1, 
          path_targets = "./Data/Sirak20/v421_CaribIllu1000GancSam_bySite_PAM",
          base_out_folder="./Empirical/Eigenstrat/Sirak20/",
          e_model="haploid", p_model="EigenstratPacked", n_ref=2504,
          destroy_phase=True, readcounts=False,
          delete=False, logfile=False, combine=True)
# Out:
# Doing Individual I12575...
# Running 1 total jobs; 1 in parallel.
# Using Low-Mem Cython Linear Speed Up.
# Loaded Pre Processing Model: EigenstratPacked
# Loading Individual: I12575
#
# Loaded 16038 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000Genomes/HDF5/1240kHDF5/all1240/chr21.hdf5
# 3 Eigenstrat Files with 1488 Individuals and 1233013 SNPs
#
# Intersection on Positions: 16038
# Nr of Matching Refs: 4101 / 16038
# Ref/Alt Matching: 4101 / 16038
# Flipped Ref/Alt Matching: 11930
# Together: 16031 / 16038
# 2504 / 2504 Individuals included in Reference
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt in target for 11930 SNPs...
# Reduced to markers called 13478 / 16031
# (Fraction SNP: 0.8407460545193687)
# Successfully saved to: ./Empirical/Eigenstrat/Sirak20/I12575/chr21/
# Shuffling phase of target...
# Successfully loaded Data from: ./Empirical/Eigenstrat/Sirak20/I12575/chr21/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
# Minimum Genetic Map: -0.0085
# Maximum Genetic Map: 0.6277
# Gaps bigger than 0.1 cM: 84
# Maximum Gap: 1.7139 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 13478)
# Loaded Observations:
# (2, 13478)
# Memory Usage: 798.818304 mB
# Reference Number: 5008
# Total Log likelihood: -3755.809
# Memory Usage: 799.760384 mB
# Finished Calculation State Posteriors
# Saved Zero State Posterior to ./Empirical/Eigenstrat/Sirak20/I12575/chr21/.
# Successfully loaded for PP. from ./Empirical/Eigenstrat/Sirak20/I12575/chr21/
# Fraction Markers in ROH: 0.6285
# Merged n=0 gaps < 0 M
# Called n=10 ROH Blocks > 1.0 cM
# Longest Block: 4.577
# Successfully saved to ./Empirical/Eigenstrat/Sirak20/I12575/chr21/roh.csv
# Run finished successfully!

# %% [markdown]
# # Run all Individuals

# %%
meta_path="./Data/Sirak20/meta_processed.csv"
df = pd.read_csv(meta_path)
df = df[(df["n_cov_snp"]>400000)  & (df["include_alt"]>=1)]
len(df["iid"])
# Out:
# 170

# %%
for iid in df["iid"].values[:]:
    print(f"Doing Individual: {iid}")
    hapsb_ind(iid=iid, chs=range(1,23), processes=8, 
              path_targets = "./Data/Sirak20/v421_CaribIllu1000GancSam_bySite_PAM",
              base_out_folder="./Empirical/Eigenstrat/Sirak20/",
              e_model="haploid", p_model="EigenstratPacked", n_ref=2504,
              destroy_phase=True, readcounts=False,
              delete=False, logfile=True, combine=True)
# Out:
# Doing Individual: I14875
# Doing Individual I14875...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14875/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14922
# Doing Individual I14922...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14922/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14923
# Doing Individual I14923...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14923/chr3/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13318
# Doing Individual I13318...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13318/chr6/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13319
# Doing Individual I13319...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13319/chr4/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14921
# Doing Individual I14921...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14921/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13320
# Doing Individual I13320...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13320/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13321
# Doing Individual I13321...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13321/chr5/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14920
# Doing Individual I14920...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14920/chr7/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14878
# Doing Individual I14878...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr8/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14878/chr6/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13322
# Doing Individual I13322...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13322/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I13737
# Doing Individual I13737...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I13737/chr8/hmm_run_log.txt
# Combining Information for 22 Chromosomes...
# Run finished successfully!
# Doing Individual: I14879
# Doing Individual I14879...
# Running 22 total jobs; 8 in parallel.
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr1/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr3/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr7/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr6/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr2/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr4/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr5/hmm_run_log.txt
# Set Output Log path: ./Empirical/Eigenstrat/Sirak20/I14879/chr8/hmm_run_log.txt

# %% [markdown]
# ### Postprocess Freilich20 Individuals into one .csv

# %%
meta_path="./Data/Freilich20/meta_processed.csv"
df_anno = pd.read_csv(meta_path)
df_ana = df_anno[df_anno["n_cov_snp"]>4e5]
print(f"{len(df_ana)} Individuals with coverage >{4e5:.0f}")
iids = df_ana["iid"].values
len(iids)
# Out:
# 28 Individuals with coverage >400000
# 28

# %%
# %%time
df1 = pp_individual_roh(iids, meta_path="./Data/Freilich20/meta_processed.csv", base_folder="./Empirical/Eigenstrat/Freilich20/",
                        save_path="./Empirical/Eigenstrat/Freilich20/combined_roh05.csv", 
                        output=False, min_cm=[4,8,12], snp_cm=50, gap=0.5)
# Out:
# Loaded 28 / 28 Individuals from Meta
# Saved to: ./Empirical/Eigenstrat/Freilich20/combined_roh05.csv
# CPU times: user 12.6 s, sys: 0 ns, total: 12.6 s
# Wall time: 13.1 s

# %%
df
# Out:
#           iid        lat        lon   age  \
# 0      I14875  26.499876 -76.999074   950
# 1      I14922  26.531918 -76.964377   950
# 2      I14923  26.302129 -77.554447   950
# 3      I13318  22.640000 -74.000000   750
# 4      I13319  22.640000 -74.000000   750
# 5      I14921  25.366574 -76.520014  1429
# 6      I13320  24.930000 -76.190000   750
# 7      I13321  24.930000 -76.190000   750
# 9      I14920  25.366574 -76.520014   950
# 11     I14878  25.557109 -76.695171  1630
# 12     I13322  23.170000 -75.100000   750
# 15     I13737  23.093788 -74.972805   750
# 18     I14879  24.099860 -77.553099   626
# 19     I14880  24.099860 -77.553099   950
# 21     I14882  24.099860 -77.553099   621
# 22     I14883  24.099860 -77.553099   950
# 24   PC537.SG  25.557109 -76.695171   995
# 25     I10756  23.038894 -81.495252   868
# 26     I10757  23.038894 -81.495252  2050
# 27     I11169  23.038894 -81.495252  1322
# 28     I10937  23.038894 -81.495252  3046
# 29     I13487  23.038894 -81.495252  2050
# 39     I12967  12.145532 -68.956408  1500
# 40     I13472  12.145532 -68.956408  1500
# 41     I10758  12.305889 -69.145267  1500
# 42     I13483  12.180562 -68.948082   450
# 43      I8547  18.440364 -69.642231  1100
# 44      I8548  18.440364 -69.642231  1100
# 45      I8549  18.440364 -69.642231  1100
# 46      I8550  18.440364 -69.642231  1100
# ..        ...        ...        ...   ...
# 171    I12575  19.660000 -71.840000   950
# 172    I12576  19.660000 -71.840000   950
# 173    I13539  18.120000 -66.540000  1050
# 174    I13326  18.380000 -65.730000   600
# 175    I13540  18.380000 -65.730000   600
# 176    I13541  18.380000 -65.730000   600
# 177    I13441  18.090000 -67.150000   950
# 178    I13323  18.030000 -66.790000   900
# 179    I13324  18.030000 -66.790000   900
# 180    I13538  18.030000 -66.790000   900
# 182    I17889   9.910411 -69.613486  1100
# 183    I17890   9.910411 -69.613486  1100
# 184    I17891   9.910411 -69.613486  1100
# 185    I17892   9.910411 -69.613486  1100
# 186    I17893   9.910411 -69.613486  1100
# 187    I17894   9.910411 -69.613486  1100
# 188    I17895   9.910411 -69.613486  1100
# 189    I17896   9.910411 -69.613486  1100
# 190    I16999   7.340086 -66.027418  1700
# 191    I17000   7.340086 -66.027418  1700
# 194    I17003   7.340086 -66.027418  1700
# 195    I17006   7.340086 -66.027418  1700
# 198    I18675   7.340086 -66.027418  1700
# 200    I18677   7.340086 -66.027418  1700
# 201    I18678   7.340086 -66.027418  1700
# 204    I18683   7.340086 -66.027418  1700
# 205    I18684   7.340086 -66.027418  1700
# 206    I18685   7.340086 -66.027418  1700
# 208    I17897   9.264945 -70.613497   878
# 209    I12207  10.090000 -67.580000   700
#
#                                       age_range    study  \
# 0                                   500-1500 CE  Sirak20
# 1                                   500-1500 CE  Sirak20
# 2                                   500-1500 CE  Sirak20
# 3                                   900-1500 CE  Sirak20
# 4                                   900-1500 CE  Sirak20
# 5       435-608 calCE (1510±20 BP, PSUAMS-6837)  Sirak20
# 6                                   900-1500 CE  Sirak20
# 7                                   900-1500 CE  Sirak20
# 9                                   500-1500 CE  Sirak20
# 11                                230-410 calCE  Sirak20
# 12                                  900-1500 CE  Sirak20
# 15    1100-1300 CE [layer date 1160-1220 calCE]  Sirak20
# 18     1268-1380 calCE (700±20 BP, PSUAMS-6793)  Sirak20
# 19                                  500-1500 CE  Sirak20
# 21     1273-1385 calCE (685±20 BP, PSUAMS-6794)  Sirak20
# 22                                  500-1500 CE  Sirak20
# 24   894-1017 calCE (1082±29 BP, OxA-X-2623-21)  Sirak20
# 25     1016-1148 calCE (980±15 BP, PSUAMS-5340)  Sirak20
# 26                           1400 BCE - 1200 CE  Sirak20
# 27      605-651 calCE (1425±15 BP, PSUAMS-4868)  Sirak20
# 28   1187-1004 calBCE (2890±20 BP, PSUAMS-4864)  Sirak20
# 29                           1400 BCE - 1200 CE  Sirak20
# 39                            500 BCE - 1400 CE  Sirak20
# 40                            500 BCE - 1400 CE  Sirak20
# 41                            500 BCE - 1400 CE  Sirak20
# 42                                 1450-1550 CE  Sirak20
# 43                                   800-900 CE  Sirak20
# 44                                   800-900 CE  Sirak20
# 45                                   800-900 CE  Sirak20
# 46                                   800-900 CE  Sirak20
# ..                                          ...      ...
# 171                                 800-1200 CE  Sirak20
# 172                                 800-1200 CE  Sirak20
# 173                                 600-1200 CE  Sirak20
# 174                                1200-1500 CE  Sirak20
# 175                                1200-1500 CE  Sirak20
# 176                                1200-1500 CE  Sirak20
# 177                                 500-1500 CE  Sirak20
# 178                                 900-1200 CE  Sirak20
# 179                                 900-1200 CE  Sirak20
# 180                                 900-1200 CE  Sirak20
# 182                                 300-1400 CE  Sirak20
# 183                                 300-1400 CE  Sirak20
# 184                                 300-1400 CE  Sirak20
# 185                                 300-1400 CE  Sirak20
# 186                                 300-1400 CE  Sirak20
# 187                                 300-1400 CE  Sirak20
# 188                                 300-1400 CE  Sirak20
# 189                                 300-1400 CE  Sirak20
# 190                                  100-400 CE  Sirak20
# 191                                  100-400 CE  Sirak20
# 194                                  100-400 CE  Sirak20
# 195                                  100-400 CE  Sirak20
# 198                                  100-400 CE  Sirak20
# 200                                  100-400 CE  Sirak20
# 201                                  100-400 CE  Sirak20
# 204                                  100-400 CE  Sirak20
# 205                                  100-400 CE  Sirak20
# 206                                  100-400 CE  Sirak20
# 208                                 792-1352 CE  Sirak20
# 209                                1000-1500 CE  Sirak20
#
#                                    clst  mean_cov  n_cov_snp  include_alt
# 0              Bahamas_Lucayan_AbacoIsl  0.355104     426125            1
# 1              Bahamas_Lucayan_AbacoIsl  0.636651     763981            1
# 2              Bahamas_Lucayan_AbacoIsl  0.423868     508641            1
# 3            Bahamas_Lucayan_CrookedIsl  0.725698     870838            1
# 4            Bahamas_Lucayan_CrookedIsl  0.687836     825403            1
# 5          Bahamas_Lucayan_EleutheraIsl  0.538762     646514            1
# 6          Bahamas_Lucayan_EleutheraIsl  0.703228     843873            1
# 7          Bahamas_Lucayan_EleutheraIsl  0.713555     856266            1
# 9          Bahamas_Lucayan_EleutheraIsl  0.429352     515223            1
# 11         Bahamas_Lucayan_EleutheraIsl  0.566275     679530            1
# 12              Bahamas_Lucayan_LongIsl  0.711574     853889            1
# 15              Bahamas_Lucayan_LongIsl  0.560737     672884            1
# 18          Bahamas_Lucayan_SouthAndros  0.651554     781865            1
# 19          Bahamas_Lucayan_SouthAndros  0.339268     407122            1
# 21          Bahamas_Lucayan_SouthAndros  0.439288     527146            1
# 22          Bahamas_Lucayan_SouthAndros  0.673672     808406            1
# 24                     Bahamas_Taino.SG  0.958031    1149637            1
# 25                  Cuba_PC_Guanataybes  0.623518     748222            1
# 26                  Cuba_PC_Guanataybes  0.613718     736461            1
# 27           Cuba_PC_Guanataybes_1300BP  0.621566     745879            1
# 28           Cuba_PC_Guanataybes_3000BP  0.622512     747014            1
# 29                         Cuba_unknown  0.442270     530724            1
# 39               Curacao_Ceramic_Savaan  0.649220     779064            1
# 40               Curacao_Ceramic_Savaan  0.687023     824428            1
# 41                   Curacao_Ceramic_SC  0.744322     893186            1
# 42                Curacao_ContactPeriod  0.680363     816436            1
# 43        Dominican_EC_Ostionoid_Andres  0.705519     846623            1
# 44        Dominican_EC_Ostionoid_Andres  0.660243     792291            1
# 45        Dominican_EC_Ostionoid_Andres  0.651173     781407            1
# 46        Dominican_EC_Ostionoid_Andres  0.686701     824041            1
# ..                                  ...       ...        ...          ...
# 171                       Haiti_Meillac  0.814715     977658            1
# 172                       Haiti_Meillac  0.765376     918451            1
# 173             PuertoRico_ElenanOstiod  0.664409     797291            1
# 174                PuertoRico_Esperanza  0.634138     760965            1
# 175                PuertoRico_Esperanza  0.713218     855861            1
# 176                PuertoRico_Esperanza  0.709547     851457            1
# 177                 PuertoRico_Ostiones  0.676143     811372            1
# 178              PuertoRico_Santa_Elena  0.669430     803316            1
# 179              PuertoRico_Santa_Elena  0.666128     799354            1
# 180              PuertoRico_Santa_Elena  0.613470     736164            1
# 182            Venezuela_unknown_1100BP  0.569810     683772            1
# 183            Venezuela_unknown_1100BP  0.591559     709871            1
# 184            Venezuela_unknown_1100BP  0.551557     661868            1
# 185            Venezuela_unknown_1100BP  0.549610     659532            1
# 186            Venezuela_unknown_1100BP  0.545637     654765            1
# 187            Venezuela_unknown_1100BP  0.557151     668581            1
# 188            Venezuela_unknown_1100BP  0.548312     657975            1
# 189  Venezuela_unknown_1100BP_Boulevard  0.555423     666507            1
# 190            Venezuela_unknown_1700BP  0.772183     926620            1
# 191            Venezuela_unknown_1700BP  0.701017     841220            1
# 194            Venezuela_unknown_1700BP  0.385496     462595            1
# 195            Venezuela_unknown_1700BP  0.688255     825906            1
# 198            Venezuela_unknown_1700BP  0.521111     625333            1
# 200            Venezuela_unknown_1700BP  0.495148     594177            1
# 201            Venezuela_unknown_1700BP  0.337994     405593            1
# 204            Venezuela_unknown_1700BP  0.533258     639910            1
# 205            Venezuela_unknown_1700BP  0.589207     707049            1
# 206            Venezuela_unknown_1700BP  0.389241     467089            1
# 208             Venezuela_unknown_900BP  0.579592     695510            1
# 209                  Venezuela_Valencia  0.698635     838362            1
#
# [170 rows x 10 columns]
