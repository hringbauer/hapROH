# %% [markdown]
# This notebook is to try a few functions of hapROH to get started. Also to play around with a few file formats.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os
import sys as sys
import multiprocessing as mp

print(f"CPU Count: {mp.cpu_count()}")

###use local version and not  pip installed version
#sys.path.append("/mnt/archgen/users/yilei/tools/hapROH/package") # Append local Hapsburg Folder
sys.path.insert(0, "/mnt/archgen/users/yilei/tools/hapROH/package")  # hack to get local package first in path [FROM HARALD - DELETE!!!]

### Fill in your own path here!
path = "/mnt/archgen/users/yilei"   # The Path on Yilei's remote space
os.chdir(path)  # Set the right Path (in line with Atom default)
print(f"Set path to: {os.getcwd()}") # Show the current working directory.
# Out:
# CPU Count: 40
# Set path to: /mnt/archgen/users/yilei

# %% [markdown]
# The first is to run hapROH on a normal autosome. Should be straightforward.

# %%
from hapsburg.PackagesSupport.hapsburg_run import hapsb_ind  # Need this import

# %%
hapsb_ind(iid="I6696", chs=range(17,18), 
          path_targets='./Data/1240K/v44.3_1240K_public', # The path before the .ind, .snp, .geno
          h5_path1000g='./Data/1000G/1000g1240khdf5/all1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out='', 
          e_model='haploid', p_model='Eigenstrat', 
          post_model='Standard', processes=1, delete=False, output=True, save=True, 
          save_fp=False, n_ref=2504, exclude_pops=[], readcounts=False, random_allele=True, 
          roh_in=1, roh_out=20, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, roh_min_l=0.01, 
          logfile=False, combine=False, file_result='_roh_full.csv')
# Out:
# Doing Individual I6696...
# Running 1 total jobs; 1 in parallel.
# Running single process...
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: I6696
#
# Loaded 29314 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr17.hdf5
# Eigenstrat packed: True
# 3 Eigenstrat Files with 9275 Individuals and 1233013 SNPs
#
# Intersection on Positions: 29314
# Nr of Matching Refs: 29314 / 29314
# Ref/Alt Matching: 29292 / 29314
# Flipped Ref/Alt Matching: 0
# Together: 29292 / 29314
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 22918 / 29292
# Fraction SNPs covered: 0.7824
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 22918)
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr17/
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr17/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	I6696
# ch	17
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	./Data/1240K/v44.3_1240K_public
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: -0.0003 Morgan
# Maximum Genetic Map: 1.2847 Morgan
# Gaps bigger than 0.1 cM: 152
# Maximum Gap: 1.2341 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 22918)
# Loaded Observations:
# (2, 22918)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1264.914432 mB
# Total Log likelihood: -9070.009
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/I6696/chr17/.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/I6696/chr17/
# Fraction Markers in ROH: 0.1732
# Merged n=0 gaps < 0 M
# Called n=4 ROH Blocks > 1.0 cM
# Longest Block: 2.03 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/I6696/chr17/roh.csv
# Run finished successfully!

# %% [markdown]
# The following is to try to run hapROH on chrX. chrX is by definition "ROH" everywhere for male (Villabruna is a male individual).
#
# 1. The first run uses the default transition model.
#
#
# 2. The second run uses a transition model that prohibits transition out of ROH state. A hack is to set the transition rate out of ROH to be 0. (also need to set initial prob accordingly?)

# %%
hapsb_ind(iid="I6696", chs=range(23,24), 
          path_targets='./Data/1240K/v44.3_1240K_public', # The path before the .ind, .snp, .geno
          h5_path1000g='./Data/1000G/1000g1240khdf5/chX1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out='default_tran', 
          e_model='haploid', p_model='Eigenstrat', 
          post_model='Standard', processes=1, delete=False, output=True, save=True, 
          save_fp=False, n_ref=2504, exclude_pops=[], readcounts=False, random_allele=True, 
          roh_in=1, roh_out=20, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, roh_min_l=0.01, 
          logfile=False, combine=False, file_result='_roh_full.csv')
# Out:
# Doing Individual I6696...
# Running 1 total jobs; 1 in parallel.
# Running single process...
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: I6696
#
# Loaded 47898 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/chX1240/chr23.hdf5
# Eigenstrat packed: True
# 3 Eigenstrat Files with 9275 Individuals and 1233013 SNPs
#
# Intersection on Positions: 47895
# Nr of Matching Refs: 47895 / 47895
# Ref/Alt Matching: 47766 / 47895
# Flipped Ref/Alt Matching: 0
# Together: 47766 / 47895
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 23276 / 47766
# Fraction SNPs covered: 0.4873
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 23276)
# Extraction of 3775 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/default_tran
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/default_tran
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	I6696
# ch	23
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	./Data/1240K/v44.3_1240K_public
# h5_path1000g	./Data/1000G/1000g1240khdf5/chX1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.2085 Morgan
# Maximum Genetic Map: 2.0206 Morgan
# Gaps bigger than 0.1 cM: 322
# Maximum Gap: 1.1490 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (3776, 23276)
# Loaded Observations:
# (2, 23276)
# Reference Number: 3775
# Memory Usage at end of HMM:
# Memory Usage: 1041.682432 mB
# Total Log likelihood: -2037.192
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/default_tran.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/default_tran
# Fraction Markers in ROH: 0.9939
# Merged n=0 gaps < 0 M
# Called n=5 ROH Blocks > 1.0 cM
# Longest Block: 98.39 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/default_tran/roh.csv
# Run finished successfully!

# %%
hapsb_ind(iid="I6696", chs=range(23,24), 
          path_targets='./Data/1240K/v44.3_1240K_public', # The path before the .ind, .snp, .geno
          h5_path1000g='./Data/1000G/1000g1240khdf5/chX1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out='chrX_tran', 
          e_model='haploid', p_model='Eigenstrat', 
          post_model='Standard', processes=1, delete=False, output=True, save=True, 
          save_fp=False, n_ref=2504, exclude_pops=[], readcounts=False, random_allele=True, 
          roh_in=1, roh_out=0, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, roh_min_l=0.01, 
          logfile=False, combine=False, file_result='_roh_full.csv')
# Out:
# Doing Individual I6696...
# Running 1 total jobs; 1 in parallel.
# Running single process...
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: I6696
#
# Loaded 47898 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/chX1240/chr23.hdf5
# Eigenstrat packed: True
# 3 Eigenstrat Files with 9275 Individuals and 1233013 SNPs
#
# Intersection on Positions: 47895
# Nr of Matching Refs: 47895 / 47895
# Ref/Alt Matching: 47766 / 47895
# Flipped Ref/Alt Matching: 0
# Together: 47766 / 47895
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 23276 / 47766
# Fraction SNPs covered: 0.4873
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 23276)
# Extraction of 3775 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/chrX_tran
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/chrX_tran
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	I6696
# ch	23
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	./Data/1240K/v44.3_1240K_public
# h5_path1000g	./Data/1000G/1000g1240khdf5/chX1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	chrX_tran
# roh_in	1
# roh_out	0
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.2085 Morgan
# Maximum Genetic Map: 2.0206 Morgan
# Gaps bigger than 0.1 cM: 322
# Maximum Gap: 1.1490 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (3776, 23276)
# Loaded Observations:
# (2, 23276)
# Reference Number: 3775
# Memory Usage at end of HMM:
# Memory Usage: 1032.368128 mB
# Total Log likelihood: -2002.640
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/chrX_tran.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/chrX_tran
# Fraction Markers in ROH: 0.9979
# Merged n=0 gaps < 0 M
# Called n=1 ROH Blocks > 1.0 cM
# Longest Block: 179.97 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/I6696/chr23/chrX_tran/roh.csv
# Run finished successfully!

# %% [markdown]
# Now let's use readcount data.

# %%
hapsb_ind(iid="SUC005", chs=range(17,18), 
          path_targets='/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5',
          h5_path1000g='./Data/1000G/1000g1240khdf5/all1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out='default_tran_SA_rc_', 
          e_model='readcount', p_model='SardHDF5', 
          post_model='Standard', processes=1, delete=False, output=True, save=True, 
          save_fp=False, n_ref=2504, exclude_pops=[], readcounts=True, random_allele=False, 
          roh_in=1, roh_out=10, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, roh_min_l=0.01, 
          logfile=False, combine=False, file_result='_roh_full.csv')
# Out:
# Doing Individual SUC005...
# Running 1 total jobs; 1 in parallel.
# Running single process...
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC005
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 29314 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr17.hdf5
#
# Intersection on Positions: 29313
# Nr of Matching Refs: 29159 / 29313
# Ref/Alt Allele Matching: 29124 / 29313
# Flipped Ref/Alt Alleles for 37 SNPs
# Together: 29161 / 29313
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 29161)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 37 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 29161)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 21019 / 29161
# Fraction SNPs covered: 0.7208
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr17/default_tran_SA_rc_
# Loading Readcounts...
# Mean Readcount on markers with data: 2.61578
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr17/default_tran_SA_rc_
# Loaded Emission Model: readcount
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC005
# ch	17
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	readcount
# p_model	SardHDF5
# readcounts	True
# random_allele	False
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_rc_
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: -0.0002 Morgan
# Maximum Genetic Map: 1.2847 Morgan
# Gaps bigger than 0.1 cM: 152
# Maximum Gap: 1.2341 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 21019)
# Loaded Observations:
# (2, 21019)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1180.024832 mB
# Total Log likelihood: -14136.773
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr17/default_tran_SA_rc_.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr17/default_tran_SA_rc_
# Fraction Markers in ROH: 0.1347
# Called n=0 ROH Blocks > 1.0 cM
# Longest Block: nan cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr17/default_tran_SA_rc_/roh.csv
# Run finished successfully!

# %%
hapsb_ind(iid="SUC001", chs=range(1, 23), 
          path_targets='/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5',
          h5_path1000g='./Data/1000G/1000g1240khdf5/all1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out='default_tran_SA_haploid', 
          e_model='haploid', p_model='SardHDF5', 
          post_model='Standard', processes=1, delete=False, output=True, save=True, 
          save_fp=False, n_ref=2504, exclude_pops=[], readcounts=False, random_allele=True, 
          roh_in=1, roh_out=10, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, roh_min_l=0.01, 
          logfile=False, combine=True, file_result='_roh_full.csv')
# Out:
# Doing Individual SUC001...
# Running 22 total jobs; 1 in parallel.
# Starting Pool of multiple workers...
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 89147 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr1.hdf5
#
# Intersection on Positions: 89143
# Nr of Matching Refs: 89143 / 89143
# Ref/Alt Allele Matching: 89079 / 89143
# Flipped Ref/Alt Alleles for 0 SNPs
# Together: 89079 / 89143
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 89079)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 0 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 89079)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 57717 / 89079
# Fraction SNPs covered: 0.6479
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr1/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr1/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	1
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0201 Morgan
# Maximum Genetic Map: 2.8627 Morgan
# Gaps bigger than 0.1 cM: 354
# Maximum Gap: 2.9245 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 57717)
# Loaded Observations:
# (2, 57717)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2812.366848 mB
# Total Log likelihood: -21431.672
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr1/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr1/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2394
# Merged n=0 gaps < 0 M
# Called n=11 ROH Blocks > 1.0 cM
# Longest Block: 1.74 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr1/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 94239 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr2.hdf5
#
# Intersection on Positions: 94237
# Nr of Matching Refs: 94205 / 94237
# Ref/Alt Allele Matching: 94137 / 94237
# Flipped Ref/Alt Alleles for 8 SNPs
# Together: 94145 / 94237
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 94145)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 8 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 94145)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 59123 / 94145
# Fraction SNPs covered: 0.6280
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr2/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr2/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	2
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0001 Morgan
# Maximum Genetic Map: 2.6883 Morgan
# Gaps bigger than 0.1 cM: 321
# Maximum Gap: 2.9097 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 59123)
# Loaded Observations:
# (2, 59123)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2879.131648 mB
# Total Log likelihood: -21430.639
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr2/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr2/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2861
# Merged n=0 gaps < 0 M
# Called n=16 ROH Blocks > 1.0 cM
# Longest Block: 3.15 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr2/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 77652 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr3.hdf5
#
# Intersection on Positions: 77650
# Nr of Matching Refs: 77606 / 77650
# Ref/Alt Allele Matching: 77553 / 77650
# Flipped Ref/Alt Alleles for 10 SNPs
# Together: 77563 / 77650
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 77563)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 10 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 77563)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 48504 / 77563
# Fraction SNPs covered: 0.6253
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr3/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr3/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	3
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 2.2326 Morgan
# Gaps bigger than 0.1 cM: 294
# Maximum Gap: 0.4131 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 48504)
# Loaded Observations:
# (2, 48504)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2408.972288 mB
# Total Log likelihood: -18468.931
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr3/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr3/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2235
# Merged n=0 gaps < 0 M
# Called n=7 ROH Blocks > 1.0 cM
# Longest Block: 3.04 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr3/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 68759 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr4.hdf5
#
# Intersection on Positions: 68759
# Nr of Matching Refs: 68709 / 68759
# Ref/Alt Allele Matching: 68663 / 68759
# Flipped Ref/Alt Alleles for 11 SNPs
# Together: 68674 / 68759
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 68674)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 11 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 68674)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 40955 / 68674
# Fraction SNPs covered: 0.5964
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr4/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr4/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	4
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0034 Morgan
# Maximum Genetic Map: 2.1454 Morgan
# Gaps bigger than 0.1 cM: 292
# Maximum Gap: 2.0513 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 40955)
# Loaded Observations:
# (2, 40955)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2068.836352 mB
# Total Log likelihood: -15444.225
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr4/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr4/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2272
# Merged n=0 gaps < 0 M
# Called n=7 ROH Blocks > 1.0 cM
# Longest Block: 1.84 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr4/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 69399 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr5.hdf5
#
# Intersection on Positions: 69394
# Nr of Matching Refs: 69307 / 69394
# Ref/Alt Allele Matching: 69252 / 69394
# Flipped Ref/Alt Alleles for 16 SNPs
# Together: 69268 / 69394
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 69268)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 16 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 69268)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 43002 / 69268
# Fraction SNPs covered: 0.6208
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr5/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr5/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	5
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0004 Morgan
# Maximum Genetic Map: 2.0409 Morgan
# Gaps bigger than 0.1 cM: 280
# Maximum Gap: 1.1070 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 43002)
# Loaded Observations:
# (2, 43002)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2161.278976 mB
# Total Log likelihood: -16419.668
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr5/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr5/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2176
# Merged n=0 gaps < 0 M
# Called n=7 ROH Blocks > 1.0 cM
# Longest Block: 1.36 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr5/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 75870 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr6.hdf5
#
# Intersection on Positions: 75866
# Nr of Matching Refs: 75743 / 75866
# Ref/Alt Allele Matching: 75675 / 75866
# Flipped Ref/Alt Alleles for 33 SNPs
# Together: 75708 / 75866
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 75708)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 33 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 75708)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 47409 / 75708
# Fraction SNPs covered: 0.6262
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr6/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr6/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	6
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0035 Morgan
# Maximum Genetic Map: 1.9203 Morgan
# Gaps bigger than 0.1 cM: 235
# Maximum Gap: 0.5090 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 47409)
# Loaded Observations:
# (2, 47409)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2360.393728 mB
# Total Log likelihood: -17548.611
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr6/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr6/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2602
# Merged n=0 gaps < 0 M
# Called n=5 ROH Blocks > 1.0 cM
# Longest Block: 1.69 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr6/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 59890 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr7.hdf5
#
# Intersection on Positions: 59889
# Nr of Matching Refs: 59781 / 59889
# Ref/Alt Allele Matching: 59715 / 59889
# Flipped Ref/Alt Alleles for 31 SNPs
# Together: 59746 / 59889
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 59746)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 31 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 59746)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 37077 / 59746
# Fraction SNPs covered: 0.6206
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr7/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr7/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	7
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.8715 Morgan
# Gaps bigger than 0.1 cM: 273
# Maximum Gap: 0.8416 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 37077)
# Loaded Observations:
# (2, 37077)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1894.641664 mB
# Total Log likelihood: -14385.436
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr7/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr7/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2306
# Merged n=0 gaps < 0 M
# Called n=6 ROH Blocks > 1.0 cM
# Longest Block: 1.82 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr7/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 61133 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr8.hdf5
#
# Intersection on Positions: 61130
# Nr of Matching Refs: 61022 / 61130
# Ref/Alt Allele Matching: 60960 / 61130
# Flipped Ref/Alt Alleles for 27 SNPs
# Together: 60987 / 61130
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 60987)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 27 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 60987)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 38333 / 60987
# Fraction SNPs covered: 0.6285
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr8/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr8/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	8
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.6800 Morgan
# Gaps bigger than 0.1 cM: 198
# Maximum Gap: 1.8932 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 38333)
# Loaded Observations:
# (2, 38333)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1951.268864 mB
# Total Log likelihood: -14671.750
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr8/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr8/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2449
# Merged n=0 gaps < 0 M
# Called n=9 ROH Blocks > 1.0 cM
# Longest Block: 2.81 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr8/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 50668 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr9.hdf5
#
# Intersection on Positions: 50668
# Nr of Matching Refs: 50539 / 50668
# Ref/Alt Allele Matching: 50493 / 50668
# Flipped Ref/Alt Alleles for 28 SNPs
# Together: 50521 / 50668
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 50521)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 28 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 50521)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 31971 / 50521
# Fraction SNPs covered: 0.6328
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr9/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr9/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	9
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0017 Morgan
# Maximum Genetic Map: 1.6630 Morgan
# Gaps bigger than 0.1 cM: 234
# Maximum Gap: 2.3088 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 31971)
# Loaded Observations:
# (2, 31971)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1665.294336 mB
# Total Log likelihood: -11816.356
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr9/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr9/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2726
# Merged n=0 gaps < 0 M
# Called n=6 ROH Blocks > 1.0 cM
# Longest Block: 2.63 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr9/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 58804 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr10.hdf5
#
# Intersection on Positions: 58803
# Nr of Matching Refs: 58657 / 58803
# Ref/Alt Allele Matching: 58591 / 58803
# Flipped Ref/Alt Alleles for 30 SNPs
# Together: 58621 / 58803
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 58621)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 30 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 58621)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 38013 / 58621
# Fraction SNPs covered: 0.6485
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr10/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr10/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	10
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0001 Morgan
# Maximum Genetic Map: 1.8091 Morgan
# Gaps bigger than 0.1 cM: 244
# Maximum Gap: 2.0340 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 38013)
# Loaded Observations:
# (2, 38013)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1937.67424 mB
# Total Log likelihood: -14207.495
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr10/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr10/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2463
# Merged n=0 gaps < 0 M
# Called n=6 ROH Blocks > 1.0 cM
# Longest Block: 1.63 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr10/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 54833 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr11.hdf5
#
# Intersection on Positions: 54831
# Nr of Matching Refs: 54669 / 54831
# Ref/Alt Allele Matching: 54616 / 54831
# Flipped Ref/Alt Alleles for 33 SNPs
# Together: 54649 / 54831
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 54649)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 33 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 54649)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 34698 / 54649
# Fraction SNPs covered: 0.6349
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr11/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr11/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	11
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.5822 Morgan
# Gaps bigger than 0.1 cM: 215
# Maximum Gap: 0.5672 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 34698)
# Loaded Observations:
# (2, 34698)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1788.301312 mB
# Total Log likelihood: -13016.822
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr11/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr11/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2502
# Merged n=0 gaps < 0 M
# Called n=6 ROH Blocks > 1.0 cM
# Longest Block: 2.04 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr11/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 53911 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr12.hdf5
#
# Intersection on Positions: 53911
# Nr of Matching Refs: 53713 / 53911
# Ref/Alt Allele Matching: 53672 / 53911
# Flipped Ref/Alt Alleles for 38 SNPs
# Together: 53710 / 53911
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 53710)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 38 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 53710)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 33764 / 53710
# Fraction SNPs covered: 0.6286
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr12/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr12/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	12
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0017 Morgan
# Maximum Genetic Map: 1.7468 Morgan
# Gaps bigger than 0.1 cM: 230
# Maximum Gap: 0.8437 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 33764)
# Loaded Observations:
# (2, 33764)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1746.259968 mB
# Total Log likelihood: -12563.367
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr12/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr12/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2742
# Merged n=0 gaps < 0 M
# Called n=9 ROH Blocks > 1.0 cM
# Longest Block: 1.84 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr12/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 39018 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr13.hdf5
#
# Intersection on Positions: 39015
# Nr of Matching Refs: 38885 / 39015
# Ref/Alt Allele Matching: 38841 / 39015
# Flipped Ref/Alt Alleles for 30 SNPs
# Together: 38871 / 39015
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 38871)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 30 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 38871)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 23559 / 38871
# Fraction SNPs covered: 0.6061
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr13/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr13/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	13
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0021 Morgan
# Maximum Genetic Map: 1.2570 Morgan
# Gaps bigger than 0.1 cM: 185
# Maximum Gap: 1.2216 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 23559)
# Loaded Observations:
# (2, 23559)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1286.32832 mB
# Total Log likelihood: -9027.037
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr13/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr13/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2186
# Merged n=0 gaps < 0 M
# Called n=4 ROH Blocks > 1.0 cM
# Longest Block: 3.27 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr13/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 36301 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr14.hdf5
#
# Intersection on Positions: 36301
# Nr of Matching Refs: 36166 / 36301
# Ref/Alt Allele Matching: 36126 / 36301
# Flipped Ref/Alt Alleles for 33 SNPs
# Together: 36159 / 36301
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 36159)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 33 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 36159)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 22658 / 36159
# Fraction SNPs covered: 0.6266
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr14/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr14/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	14
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0161 Morgan
# Maximum Genetic Map: 1.2020 Morgan
# Gaps bigger than 0.1 cM: 168
# Maximum Gap: 2.8973 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 22658)
# Loaded Observations:
# (2, 22658)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1245.708288 mB
# Total Log likelihood: -8551.630
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr14/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr14/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2515
# Merged n=0 gaps < 0 M
# Called n=4 ROH Blocks > 1.0 cM
# Longest Block: 1.61 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr14/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 34429 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr15.hdf5
#
# Intersection on Positions: 34425
# Nr of Matching Refs: 34285 / 34425
# Ref/Alt Allele Matching: 34249 / 34425
# Flipped Ref/Alt Alleles for 24 SNPs
# Together: 34273 / 34425
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 34273)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 24 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 34273)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 22442 / 34273
# Fraction SNPs covered: 0.6548
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr15/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr15/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	15
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.4134 Morgan
# Gaps bigger than 0.1 cM: 166
# Maximum Gap: 11.4957 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 22442)
# Loaded Observations:
# (2, 22442)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1235.972096 mB
# Total Log likelihood: -8244.191
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr15/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr15/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2806
# Merged n=0 gaps < 0 M
# Called n=6 ROH Blocks > 1.0 cM
# Longest Block: 2.13 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr15/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 34402 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr16.hdf5
#
# Intersection on Positions: 34399
# Nr of Matching Refs: 34254 / 34399
# Ref/Alt Allele Matching: 34201 / 34399
# Flipped Ref/Alt Alleles for 30 SNPs
# Together: 34231 / 34399
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 34231)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 30 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 34231)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 23035 / 34231
# Fraction SNPs covered: 0.6729
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr16/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr16/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	16
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: -0.0000 Morgan
# Maximum Genetic Map: 1.3403 Morgan
# Gaps bigger than 0.1 cM: 189
# Maximum Gap: 0.8458 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 23035)
# Loaded Observations:
# (2, 23035)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1262.743552 mB
# Total Log likelihood: -8978.467
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr16/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr16/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2045
# Merged n=0 gaps < 0 M
# Called n=4 ROH Blocks > 1.0 cM
# Longest Block: 2.02 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr16/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 29314 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr17.hdf5
#
# Intersection on Positions: 29313
# Nr of Matching Refs: 29159 / 29313
# Ref/Alt Allele Matching: 29124 / 29313
# Flipped Ref/Alt Alleles for 37 SNPs
# Together: 29161 / 29313
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 29161)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 37 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 29161)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 19860 / 29161
# Fraction SNPs covered: 0.6810
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr17/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr17/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	17
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0002 Morgan
# Maximum Genetic Map: 1.2847 Morgan
# Gaps bigger than 0.1 cM: 170
# Maximum Gap: 1.2341 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 19860)
# Loaded Observations:
# (2, 19860)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1119.62112 mB
# Total Log likelihood: -7268.437
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr17/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr17/default_tran_SA_haploid
# Fraction Markers in ROH: 0.3017
# Merged n=0 gaps < 0 M
# Called n=8 ROH Blocks > 1.0 cM
# Longest Block: 2.40 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr17/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 33917 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr18.hdf5
#
# Intersection on Positions: 33916
# Nr of Matching Refs: 33774 / 33916
# Ref/Alt Allele Matching: 33746 / 33916
# Flipped Ref/Alt Alleles for 43 SNPs
# Together: 33789 / 33916
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 33789)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 43 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 33789)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 20921 / 33789
# Fraction SNPs covered: 0.6192
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr18/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr18/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	18
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0025 Morgan
# Maximum Genetic Map: 1.1771 Morgan
# Gaps bigger than 0.1 cM: 181
# Maximum Gap: 0.4827 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 20921)
# Loaded Observations:
# (2, 20921)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1167.568896 mB
# Total Log likelihood: -7922.491
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr18/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr18/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2339
# Merged n=0 gaps < 0 M
# Called n=5 ROH Blocks > 1.0 cM
# Longest Block: 2.05 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr18/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 18460 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr19.hdf5
#
# Intersection on Positions: 18459
# Nr of Matching Refs: 18381 / 18459
# Ref/Alt Allele Matching: 18340 / 18459
# Flipped Ref/Alt Alleles for 23 SNPs
# Together: 18363 / 18459
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 18363)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 23 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 18363)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 12802 / 18363
# Fraction SNPs covered: 0.6972
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr19/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr19/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	19
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.0773 Morgan
# Gaps bigger than 0.1 cM: 171
# Maximum Gap: 0.6534 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 12802)
# Loaded Observations:
# (2, 12802)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 801.562624 mB
# Total Log likelihood: -5188.666
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr19/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr19/default_tran_SA_haploid
# Fraction Markers in ROH: 0.1618
# Merged n=0 gaps < 0 M
# Called n=2 ROH Blocks > 1.0 cM
# Longest Block: 1.65 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr19/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 29078 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr20.hdf5
#
# Intersection on Positions: 29077
# Nr of Matching Refs: 28908 / 29077
# Ref/Alt Allele Matching: 28864 / 29077
# Flipped Ref/Alt Alleles for 43 SNPs
# Together: 28907 / 29077
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 28907)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 43 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 28907)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 19679 / 28907
# Fraction SNPs covered: 0.6808
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr20/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr20/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	20
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.0821 Morgan
# Gaps bigger than 0.1 cM: 166
# Maximum Gap: 0.5887 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 19679)
# Loaded Observations:
# (2, 19679)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1111.584768 mB
# Total Log likelihood: -7465.910
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr20/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr20/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2443
# Merged n=0 gaps < 0 M
# Called n=3 ROH Blocks > 1.0 cM
# Longest Block: 1.86 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr20/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 16038 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr21.hdf5
#
# Intersection on Positions: 16036
# Nr of Matching Refs: 15949 / 16036
# Ref/Alt Allele Matching: 15930 / 16036
# Flipped Ref/Alt Alleles for 18 SNPs
# Together: 15948 / 16036
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 15948)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 18 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 15948)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 10096 / 15948
# Fraction SNPs covered: 0.6331
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr21/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr21/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	21
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: -0.0085 Morgan
# Maximum Genetic Map: 0.6277 Morgan
# Gaps bigger than 0.1 cM: 103
# Maximum Gap: 1.7139 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 10096)
# Loaded Observations:
# (2, 10096)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 679.583744 mB
# Total Log likelihood: -4007.056
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr21/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr21/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2168
# Merged n=0 gaps < 0 M
# Called n=3 ROH Blocks > 1.0 cM
# Longest Block: 1.81 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr21/default_tran_SA_haploid/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC001
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 15802 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr22.hdf5
#
# Intersection on Positions: 15802
# Nr of Matching Refs: 15704 / 15802
# Ref/Alt Allele Matching: 15684 / 15802
# Flipped Ref/Alt Alleles for 21 SNPs
# Together: 15705 / 15802
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 15705)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 21 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 15705)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 11177 / 15705
# Fraction SNPs covered: 0.7117
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr22/default_tran_SA_haploid
# Shuffling phase of target...
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr22/default_tran_SA_haploid
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC001
# ch	22
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	SardHDF5
# readcounts	False
# random_allele	True
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out	default_tran_SA_haploid
# roh_in	1
# roh_out	10
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0178 Morgan
# Maximum Genetic Map: 0.7408 Morgan
# Gaps bigger than 0.1 cM: 101
# Maximum Gap: 1.6277 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 11177)
# Loaded Observations:
# (2, 11177)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 728.313856 mB
# Total Log likelihood: -4344.601
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr22/default_tran_SA_haploid.
# Successfully loaded for PP. from ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr22/default_tran_SA_haploid
# Fraction Markers in ROH: 0.2664
# Merged n=0 gaps < 0 M
# Called n=4 ROH Blocks > 1.0 cM
# Longest Block: 2.30 cM
# Successfully saved to ./tools/hapROH/test_output/contaminate/first_try/SUC001/chr22/default_tran_SA_haploid/roh.csv
# Combining Information for 22 Chromosomes...
# Run finished successfully!
