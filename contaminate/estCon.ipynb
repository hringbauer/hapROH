# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os
import sys as sys
import multiprocessing as mp

print(f"CPU Count: {mp.cpu_count()}")
sys.path.insert(0, "/mnt/archgen/users/yilei/tools/hapROH/package")
path = "/mnt/archgen/users/yilei"   # The Path on Yilei's remote space
os.chdir(path)  # Set the right Path (in line with Atom default)
print(f"Set path to: {os.getcwd()}") # Show the current working directory.

from hapsburg.PackagesSupport.hapsburg_run import hapCon_chrom  # Need this import
from hapsburg.PackagesSupport.hapsburg_run import hapCon_ind
# Out:
# CPU Count: 40
# Set path to: /mnt/archgen/users/yilei

# %%
hapCon_chrom(iid="SUC005", ch=1, save=True, save_fp=False, n_ref=2504, diploid_ref=True, exclude_pops=[], 
                e_model="readcount_contam", p_model="SardHDF5", readcounts=True,random_allele=False, post_model="Standard", 
                path_targets='/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5',
          h5_path1000g='./Data/1000G/1000g1240khdf5/all1240/chr',
          meta_path_ref='./Data/1000G/meta_df_all.csv', 
          folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out="",
                c=0.05, roh_in=1, roh_out=20, roh_jump=300, e_rate=0.01, e_rate_ref=0.0,
                max_gap=0, cutoff_post = 0.999, roh_min_l = 0.01, logfile=False)
# Out:
# Using Rescaled HMM.
# Loaded Pre Processing Model: SardHDF5
# Loading Individual: SUC005
#
# Loaded 1145647 variants
# Loaded 3039 individuals
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
# Loaded 89147 variants
# Loaded 2504 individuals
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr1.hdf5
#
# Intersection on Positions: 89143
# Nr of Matching Refs: 89143 / 89143
# Ref/Alt Allele Matching: 89079 / 89143
# Flipped Ref/Alt Alleles for 0 SNPs
# Together: 89079 / 89143
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 89079)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 0 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 89079)
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 60218 / 89079
# Fraction SNPs covered: 0.6760
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr1/
# Loading Readcounts...
# Mean Readcount on markers with data: 2.44575
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr1/
# Loaded Emission Model: readcount_contam
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC005
# ch	1
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	readcount_contam
# p_model	SardHDF5
# readcounts	True
# random_allele	False
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out
# c	0.05
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0201 Morgan
# Maximum Genetic Map: 2.8627 Morgan
# Gaps bigger than 0.1 cM: 329
# Maximum Gap: 3.1359 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 60218)
# Loaded Observations:
# (2, 60218)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 2954.743808 mB
# Total Log likelihood: -35783.111
# Total Log likelihood: -35783.111
# hapcon_chr returns result: -35783.111073376574
# -35783.111073376574

# %%
hapCon_ind("SUC005", chs=range(20,23), 
            path_targets='/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5',
            h5_path1000g='./Data/1000G/1000g1240khdf5/all1240/chr',
            meta_path_ref='./Data/1000G/meta_df_all.csv', 
            folder_out='./tools/hapROH/test_output/contaminate/first_try/', prefix_out="",
            e_model="readcount_contam", p_model="SardHDF5", post_model="Standard",
            processes=3, delete=False, output=False, save=True, save_fp=False, 
            n_ref=2504, diploid_ref=True, exclude_pops=[], readcounts=True, random_allele=False,
            c=0.05, roh_in=1, roh_out=20, roh_jump=300, e_rate=0.01, e_rate_ref=0.00, 
            cutoff_post = 0.999, max_gap=0, roh_min_l = 0.01, logfile=False)
# Out:
# Running 3 total jobs; 3 in parallel.
# Starting Pool of multiple workers...
# Using Rescaled HMM.Using Rescaled HMM.Using Rescaled HMM.
#
#
# Loaded Pre Processing Model: SardHDF5Loaded Pre Processing Model: SardHDF5Loaded Pre Processing Model: SardHDF5
#
#
# Loading Individual: SUC005Loading Individual: SUC005Loading Individual: SUC005
#
#
#
# Loaded 1145647 variants
# Loaded 1145647 variants
# Loaded 1145647 variants
#
#
# Loaded 3039 individualsLoaded 3039 individualsLoaded 3039 individuals
#
#
# HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5HDF5 loaded from /mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
#
#
#
# Loaded 29078 variants
# Loaded 16038 variants
# Loaded 15802 variants
#
#
# Loaded 2504 individualsLoaded 2504 individualsLoaded 2504 individuals
#
#
# HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr20.hdf5HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr22.hdf5HDF5 loaded from ./Data/1000G/1000g1240khdf5/all1240/chr21.hdf5
#
#
#
# Intersection on Positions: 15802
# Nr of Matching Refs: 15704 / 15802
# Ref/Alt Allele Matching: 15684 / 15802
# Flipped Ref/Alt Alleles for 21 SNPs
# Intersection on Positions: 16036
#
# Together: 15705 / 15802Nr of Matching Refs: 15949 / 16036
#
# Ref/Alt Allele Matching: 15930 / 16036
# Flipped Ref/Alt Alleles for 18 SNPs
# Together: 15948 / 16036
#
# Intersection on Positions: 29077
# 2504 / 2504 Individuals included in ReferenceNr of Matching Refs: 28908 / 29077
#
# Ref/Alt Allele Matching: 28864 / 29077Extracting up to 2504 Individuals
#
# 2504 / 2504 Individuals included in ReferenceFlipped Ref/Alt Alleles for 43 SNPs
#
# Extracting up to 2504 IndividualsTogether: 28907 / 29077
#
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 15705)
# Extraction of 2 Haplotypes complete
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (2, 28907)
# Exctraction of hdf5 done. Subsetting...!Extraction of 2 Haplotypes complete
#
# size of gts matrix: (2, 15948)
# Extraction of 2 Haplotypes complete
# Flipping Ref/Alt Allele in target for 21 SNPs...
# Flipping Ref/Alt Allele in target for 43 SNPs...
# Flipping Ref/Alt Allele in target for 18 SNPs...
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 15705)
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 15948)
# Exctraction of hdf5 done. Subsetting...!
# size of gts matrix: (5008, 28907)
# Extraction of 5008 Haplotypes complete
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 11848 / 15705
# Fraction SNPs covered: 0.7544
# Subset to markers with data: 10511 / 15948
# Fraction SNPs covered: 0.6591
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr22/
# Loading Readcounts...
# Mean Readcount on markers with data: 2.77338
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr21/
# Loading Readcounts...
# Mean Readcount on markers with data: 2.43802
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr22/
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr21/
# Loaded Emission Model: readcount_contam
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC005
# ch	22
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	readcount_contam
# p_model	SardHDF5
# readcounts	True
# random_allele	False
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out
# c	0.05
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0169 Morgan
# Maximum Genetic Map: 0.7408 Morgan
# Gaps bigger than 0.1 cM: 92
# Maximum Gap: 1.6949 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Emission Model: readcount_contam
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC005
# ch	21
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	readcount_contam
# p_model	SardHDF5
# readcounts	True
# random_allele	False
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out
# c	0.05
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0089 Morgan
# Maximum Genetic Map: 0.6277 Morgan
# Gaps bigger than 0.1 cM: 102
# Maximum Gap: 0.5653 cM
# Upper Gap Cutoff: 5.0000 cM
# Extraction of 5008 Haplotypes complete
# Subset to markers with data: 20607 / 28907
# Fraction SNPs covered: 0.7129
# Successfully saved target individual data to: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr20/
# Loading Readcounts...
# Mean Readcount on markers with data: 2.55607
# Successfully loaded Data from: ./tools/hapROH/test_output/contaminate/first_try/SUC005/chr20/
# Loaded Emission Model: readcount_contam
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	SUC005
# ch	20
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	readcount_contam
# p_model	SardHDF5
# readcounts	True
# random_allele	False
# post_model	Standard
# path_targets	/mnt/archgen/users/yilei/Data/SA_1240KHDF5/marcus2020.h5
# h5_path1000g	./Data/1000G/1000g1240khdf5/all1240/chr
# meta_path_ref	./Data/1000G/meta_df_all.csv
# folder_out	./tools/hapROH/test_output/contaminate/first_try/
# prefix_out
# c	0.05
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# cutoff_post	0.999
# roh_min_l	0.01
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.0821 Morgan
# Gaps bigger than 0.1 cM: 160
# Maximum Gap: 0.6809 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 10511)
# Loaded Observations:
# (2, 10511)
# Reference Number: 5008
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 11848)
# Loaded Observations:
# (2, 11848)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 736.41984 mB
# Total Log likelihood: -7581.730
# Total Log likelihood: -7581.730
# hapcon_chr returns result: -7581.730432295715
# Memory Usage at end of HMM:
# Memory Usage: 676.192256 mB
# Total Log likelihood: -6797.848
# Total Log likelihood: -6797.848
# hapcon_chr returns result: -6797.84840291573
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 20607)
# Loaded Observations:
# (2, 20607)
# Reference Number: 5008
# Memory Usage at end of HMM:
# Memory Usage: 1132.990464 mB
# Total Log likelihood: -13148.607
# Total Log likelihood: -13148.607
# hapcon_chr returns result: -13148.607398623777
# results of multiprocess: None
